# %%
import os
from typing import Any, Dict, Optional, Literal

import httpx # for returning more understandable errors
import logging
from mcp.server.fastmcp import FastMCP

# the 3 lines below are only for jupyter notebook 
# (to prevent printing the INFO logs out with full URL (as API key is inside URL)
httpx_logger = logging.getLogger("httpx")
httpx_logger.setLevel(logging.WARNING)
httpx_logger.propagate = False

FMP_BASE_URL = "https://financialmodelingprep.com/stable"

# you need to get the FMP API key and store it in the FMP_API_KEY variable
api_key = os.environ['FMP_API_KEY']

# %%
# Core HTTP helper
# This is not a MCP tool, just a helper function that makes a request to FMP API via different endpoints
# It also returns any errors that occur in a more detailed way that an LLM understands thanks to the httpx library
async def fmp_api_request(endpoint: str, params: Optional[Dict] = None) -> Dict:
    """Make a request to the Financial Modeling Prep API under /stable.

    Automatically appends the API key, returns parsed JSON, and surfaces errors
    as a small error dict so MCP clients receive an explainable result instead
    of raising.
    """
    url = f"{FMP_BASE_URL}/{endpoint.lstrip('/')}"
    params = params.copy() if params else {}
    params["apikey"] = api_key

    try:
         async with httpx.AsyncClient() as client:
            resp = await client.get(url, params=params, timeout=30.0)
            resp.raise_for_status()
            data = resp.json()

            ## wrap the response in a consistent structure for the LLM, this is used in the actual server script
            # return {
            #     "success": True,
            #     "data": data,
            #     "count": len(data) if isinstance(data, list) else 1
            # }

            return data # this is only used in the explanation notebook to print the data more cleanly
             
    except httpx.HTTPStatusError as e:
        return {"error": f"HTTP error: {e.response.status_code}", "message": str(e)}
    except httpx.RequestError as e:
        return {"error": "Request error", "message": str(e)}
    except Exception as e:
        return {"error": "Unknown error", "message": str(e)}

# %%
mcp = FastMCP("fmp")

# %%
@mcp.tool()
async def company_profile(symbol: str) -> Any:
    """Company Profile Data API — detailed fundamentals for a single symbol.

    Use this when:
      • You need a company’s *current snapshot* (price, marketCap, beta, identifiers).
      • You’re building a profile card or prepping context before deeper statement pulls.

    Don’t use when:
      • You need periodized statements (use income_statement / balance_sheet / cash_flow).
      • You want multi-period ratios (use financial_ratios).

    Endpoint: `/stable/profile`

    What it provides (high-level):
      • **Stock Price & Market Cap**: Current `price` and `marketCap` for the symbol.
      • **Company Details**: `companyName`, long `description`, `CEO`, `industry`, `sector`, exchange info.
      • **Financial Metrics**: `beta`, `lastDividend`, trading `range` (e.g., 52-week), `volume`, `averageVolume`.
      • **Global Identifiers**: `cik`, `isin`, `cusip` to track the entity across platforms.
      • **Contact Information**: `address`, `city`, `state`, `zip`, `phone`, and `website`.
      • **IPO & Trading Flags**: `ipoDate`, `isActivelyTrading`, `isEtf`, `isAdr`, `isFund`.

    Typical uses:
      • Research a company’s **current financial snapshot** (e.g., Apple) and extract
        key metrics for investment due diligence or profile cards.

    Args:
      symbol: Ticker symbol (e.g., "AAPL").

    Returns:
      A 1-element list with the profile object as shown in your example.
    """
    return await fmp_api_request("profile", {"symbol": symbol})

# %%
await company_profile("AAPL")
# Out:
# [{'symbol': 'AAPL',
#   'price': 286.19,
#   'marketCap': 4228844465070,
#   'beta': 1.109,
#   'lastDividend': 1.03,
#   'range': '169.21-287.4',
#   'change': 3.09,
#   'changePercentage': 1.09149,
#   'volume': 53666636,
#   'averageVolume': 51471580,
#   'companyName': 'Apple Inc.',
#   'currency': 'USD',
#   'cik': '0000320193',
#   'isin': 'US0378331005',
#   'cusip': '037833100',
#   'exchangeFullName': 'NASDAQ Global Select',
#   'exchange': 'NASDAQ',
#   'industry': 'Consumer Electronics',
#   'website': 'https://www.apple.com',
#   'description': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#   'ceo': 'Timothy D. Cook',
#   'sector': 'Technology',
#   'country': 'US',
#   'fullTimeEmployees': '164000',
#   'phone': '(408) 996-1010',
#   'address': 'One Apple Park Way',
#   'city': 'Cupertino',
#   'state': 'CA',
#   'zip': '95014',
#   'image': 'https://images.financialmodelingprep.com/symbol/AAPL.png',
#   'ipoDate': '1980-12-12',
#   'defaultImage': False,
#   'isEtf': False,
#   'isActivelyTrading': True,
#   'isAdr': False,
#   'isFund': False}]

# %%
@mcp.tool()
async def income_statement(symbol: str, limit: int = 5, period: str = "annual") -> Any:
    """Income Statement API — real-time & historical profitability view.

    Use this when:
      • You need revenue, cost, margins, EPS across periods (annual/quarterly).
      • You’re computing profitability ratios or analyzing earnings trends.

    Don’t use when:
      • You need assets/liabilities/equity (use balance_sheet).
      • You want cash flow specifics/FCF (use cash_flow).

    Endpoint: `/stable/income-statement`

    What it provides:
      • **Profitability Tracking**: `revenue`, `costOfRevenue`, `grossProfit`, `operatingIncome`, `netIncome`,
        `eps`, `epsDiluted`, etc., by period.
      • **Trend Identification**: Pull multiple periods (`limit`) to observe changes in revenue and expenses
        (e.g., FY vs. Q1–Q4).
      • **Comparative Analysis**: Use with peers to compare margins and earnings power.

    Example use:
      • Compute ratios like **P/E**, **gross margin**, or analyze **surprise vs. trend**.

    Args:
      symbol: Ticker symbol (e.g., "AAPL").
      limit: Number of periods to return (max 1000 per request).
      period: One of `annual` / `quarter` or explicit tags like `Q1`..`Q4`, `FY`.

    Returns:
      A list of income statement rows as in your example (currency as reported).
    """
    return await fmp_api_request("income-statement", {"symbol": symbol, "limit": limit, "period": period})

# %%
await income_statement("UNH")
# Out:
# [{'date': '2024-12-31',
#   'symbol': 'UNH',
#   'reportedCurrency': 'USD',
#   'cik': '0000731766',
#   'filingDate': '2025-02-27',
#   'acceptedDate': '2025-02-27 17:16:21',
#   'fiscalYear': '2024',
#   'period': 'FY',
#   'revenue': 400278000000,
#   'costOfRevenue': 310879000000,
#   'grossProfit': 89399000000,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 0,
#   'otherExpenses': 57112000000,
#   'operatingExpenses': 57112000000,
#   'costAndExpenses': 367991000000,
#   'netInterestIncome': -3906000000,
#   'interestIncome': 0,
#   'interestExpense': 3906000000,
#   'depreciationAndAmortization': 4099000000,
#   'ebitda': 28076000000,
#   'ebit': 23977000000,
#   'nonOperatingIncomeExcludingInterest': 8310000000,
#   'operatingIncome': 32287000000,
#   'totalOtherIncomeExpensesNet': -12216000000,
#   'incomeBeforeTax': 20071000000,
#   'incomeTaxExpense': 4829000000,
#   'netIncomeFromContinuingOperations': 15242000000,
#   'netIncomeFromDiscontinuedOperations': 0,
#   'otherAdjustmentsToNetIncome': 0,
#   'netIncome': 14405000000,
#   'netIncomeDeductions': 0,
#   'bottomLineNetIncome': 14405000000,
#   'eps': 15.64,
#   'epsDiluted': 15.51,
#   'weightedAverageShsOut': 929000000,
#   'weightedAverageShsOutDil': 929000000},
#  {'date': '2023-12-31',
#   'symbol': 'UNH',
#   'reportedCurrency': 'USD',
#   'cik': '0000731766',
#   'filingDate': '2023-12-31',
#   'acceptedDate': '2023-12-29 19:00:00',
#   'fiscalYear': '2023',
#   'period': 'FY',
#   'revenue': 371622000000,
#   'costOfRevenue': 280664000000,
#   'grossProfit': 90958000000,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 0,
#   'otherExpenses': 58600000000,
#   'operatingExpenses': 58600000000,
#   'costAndExpenses': 339264000000,
#   'netInterestIncome': -3246000000,
#   'interestIncome': 0,
#   'interestExpense': 3246000000,
#   'depreciationAndAmortization': 3972000000,
#   'ebitda': 36330000000,
#   'ebit': 32358000000,
#   'nonOperatingIncomeExcludingInterest': 0,
#   'operatingIncome': 32358000000,
#   'totalOtherIncomeExpensesNet': -3246000000,
#   'incomeBeforeTax': 29112000000,
#   'incomeTaxExpense': 5968000000,
#   'netIncomeFromContinuingOperations': 23144000000,
#   'netIncomeFromDiscontinuedOperations': 0,
#   'otherAdjustmentsToNetIncome': 0,
#   'netIncome': 22381000000,
#   'netIncomeDeductions': 0,
#   'bottomLineNetIncome': 22381000000,
#   'eps': 24.12,
#   'epsDiluted': 23.86,
#   'weightedAverageShsOut': 928000000,
#   'weightedAverageShsOutDil': 938000000},
#  {'date': '2022-12-31',
#   'symbol': 'UNH',
#   'reportedCurrency': 'USD',
#   'cik': '0000731766',
#   'filingDate': '2023-02-24',
#   'acceptedDate': '2023-02-24 17:28:40',
#   'fiscalYear': '2022',
#   'period': 'FY',
#   'revenue': 324162000000,
#   'costOfRevenue': 244545000000,
#   'grossProfit': 79617000000,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 0,
#   'otherExpenses': 51182000000,
#   'operatingExpenses': 51182000000,
#   'costAndExpenses': 295727000000,
#   'netInterestIncome': -2092000000,
#   'interestIncome': 0,
#   'interestExpense': 2092000000,
#   'depreciationAndAmortization': 3400000000,
#   'ebitda': 31835000000,
#   'ebit': 28435000000,
#   'nonOperatingIncomeExcludingInterest': 0,
#   'operatingIncome': 28435000000,
#   'totalOtherIncomeExpensesNet': -2092000000,
#   'incomeBeforeTax': 26343000000,
#   'incomeTaxExpense': 5704000000,
#   'netIncomeFromContinuingOperations': 20639000000,
#   'netIncomeFromDiscontinuedOperations': 0,
#   'otherAdjustmentsToNetIncome': 0,
#   'netIncome': 20120000000,
#   'netIncomeDeductions': 0,
#   'bottomLineNetIncome': 20120000000,
#   'eps': 21.54,
#   'epsDiluted': 21.18,
#   'weightedAverageShsOut': 934000000,
#   'weightedAverageShsOutDil': 950000000},
#  {'date': '2021-12-31',
#   'symbol': 'UNH',
#   'reportedCurrency': 'USD',
#   'cik': '0000731766',
#   'filingDate': '2022-02-15',
#   'acceptedDate': '2022-02-15 16:50:18',
#   'fiscalYear': '2021',
#   'period': 'FY',
#   'revenue': 287597000000,
#   'costOfRevenue': 217945000000,
#   'grossProfit': 69652000000,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 0,
#   'otherExpenses': 45682000000,
#   'operatingExpenses': 45682000000,
#   'costAndExpenses': 263627000000,
#   'netInterestIncome': -1660000000,
#   'interestIncome': 0,
#   'interestExpense': 1660000000,
#   'depreciationAndAmortization': 3103000000,
#   'ebitda': 27073000000,
#   'ebit': 23970000000,
#   'nonOperatingIncomeExcludingInterest': 0,
#   'operatingIncome': 23970000000,
#   'totalOtherIncomeExpensesNet': -1660000000,
#   'incomeBeforeTax': 22310000000,
#   'incomeTaxExpense': 4578000000,
#   'netIncomeFromContinuingOperations': 17732000000,
#   'netIncomeFromDiscontinuedOperations': 0,
#   'otherAdjustmentsToNetIncome': 0,
#   'netIncome': 17285000000,
#   'netIncomeDeductions': 0,
#   'bottomLineNetIncome': 17285000000,
#   'eps': 18.33,
#   'epsDiluted': 18.08,
#   'weightedAverageShsOut': 943000000,
#   'weightedAverageShsOutDil': 956000000},
#  {'date': '2020-12-31',
#   'symbol': 'UNH',
#   'reportedCurrency': 'USD',
#   'cik': '0000731766',
#   'filingDate': '2021-03-01',
#   'acceptedDate': '2021-03-01 16:02:27',
#   'fiscalYear': '2020',
#   'period': 'FY',
#   'revenue': 257141000000,
#   'costOfRevenue': 190141000000,
#   'grossProfit': 67000000000,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 0,
#   'otherExpenses': 44595000000,
#   'operatingExpenses': 44595000000,
#   'costAndExpenses': 234736000000,
#   'netInterestIncome': -1663000000,
#   'interestIncome': 0,
#   'interestExpense': 1663000000,
#   'depreciationAndAmortization': 2891000000,
#   'ebitda': 25296000000,
#   'ebit': 22405000000,
#   'nonOperatingIncomeExcludingInterest': 0,
#   'operatingIncome': 22405000000,
#   'totalOtherIncomeExpensesNet': -1663000000,
#   'incomeBeforeTax': 20742000000,
#   'incomeTaxExpense': 4973000000,
#   'netIncomeFromContinuingOperations': 15769000000,
#   'netIncomeFromDiscontinuedOperations': 0,
#   'otherAdjustmentsToNetIncome': 0,
#   'netIncome': 15403000000,
#   'netIncomeDeductions': 0,
#   'bottomLineNetIncome': 15403000000,
#   'eps': 16.28,
#   'epsDiluted': 16.03,
#   'weightedAverageShsOut': 946000000,
#   'weightedAverageShsOutDil': 961000000}]

# %%
@mcp.tool()
async def balance_sheet(symbol: str, limit: int = 5, period: str = "annual") -> Any:
    """Balance Sheet Statement API — assets, liabilities, and equity structure.

    Use this when:
      • You need capital structure, leverage, liquidity, or working-capital inputs.
      • You’re comparing balance sheet strength across peers/time.

    Don’t use when:
      • You want income/profitability flows (use income_statement).
      • You want cash generation/FCF (use cash_flow).

    Endpoint: `/stable/balance-sheet-statement`

    What it provides:
      • **Assets**: Current & noncurrent (e.g., `cashAndCashEquivalents`, `longTermInvestments`, `totalAssets`).
      • **Liabilities**: Short/long-term debts, `totalLiabilities`, deferred items.
      • **Equity**: `commonStock`, `retainedEarnings`, `totalStockholdersEquity`.
      • **Solvency/Liquidity Inputs**: Values to compute leverage and working-capital metrics.

    Example use:
      • Assess **liquidity & leverage** and compare structure across peers or over time.

    Args:
      symbol: Ticker symbol.
      limit: Number of periods to return.
      period: `annual` / `quarter` (also supports `Q1`..`Q4`, `FY`).

    Returns:
      A list of balance sheet rows (currency as reported).
    """
    return await fmp_api_request("balance-sheet-statement", {"symbol": symbol, "limit": limit, "period": period})

@mcp.tool()
async def cash_flow(symbol: str, limit: int = 5, period: str = "annual") -> Any:
    """Cash Flow Statement API — operating, investing, and financing cash flows.

    Use this when:
      • You need cash generation/usage details or to compute FCF.
      • You’re analyzing sustainability of dividends/buybacks or financing activity.

    Don’t use when:
      • You want margin/earnings lines (use income_statement).
      • You need capital structure snapshots (use balance_sheet).

    Endpoint: `/stable/cash-flow-statement`

    What it provides:
      • **Operating Cash Flow**: `netCashProvidedByOperatingActivities`, `operatingCashFlow`.
      • **Investing & Financing**: Capex, acquisitions, debt issuance/repayment, dividends, buybacks.
      • **Free Cash Flow**: `freeCashFlow` and components (`capitalExpenditure`).

    Example use:
      • Evaluate **cash generation** and **financial flexibility**, compare FCF across time.

    Args:
      symbol: Ticker symbol.
      limit: Number of periods to return.
      period: `annual` / `quarter` (also supports `Q1`..`Q4`, `FY`).

    Returns:
      A list of cash flow rows as in your example (currency as reported).
    """
    return await fmp_api_request("cash-flow-statement", {"symbol": symbol, "limit": limit, "period": period})

# %%
@mcp.tool()
async def financial_ratios(symbol: str, limit: int = 5, period: str = "annual") -> Any:
    """Financial Ratios API — profitability, liquidity, efficiency, leverage.

    Use this when:
      • You want ready-made valuation, liquidity, efficiency, and leverage ratios.
      • You need quick multi-period ratio comparison for screening/peer comps.

    Don’t use when:
      • You need raw statement lines (use income_statement / balance_sheet / cash_flow) to compute custom metrics.
      • You’re requesting intraday/realtime multiples (daily snapshots only).

    Endpoint: `/stable/ratios`

    What it provides:
      • **Profitability**: `grossProfitMargin`, `netProfitMargin`, `ROE` proxies via margins and equity metrics.
      • **Liquidity**: `currentRatio`, `quickRatio`, `cashRatio`.
      • **Efficiency**: `assetTurnover`, `inventoryTurnover`, `receivablesTurnover`.
      • **Valuation & Debt**: `priceToEarningsRatio`, `priceToBookRatio`, `debtToEquityRatio`, `enterpriseValueMultiple`.

    Example use:
      • Cross-company **ratio comparisons** within a sector to evaluate stability and efficiency.

    Args:
      symbol: Ticker symbol.
      limit: Number of periods to return.
      period: `annual` / `quarter` (also supports `Q1`..`Q4`, `FY`).

    Returns:
      A list of ratio snapshots per period.
    """
    return await fmp_api_request("ratios", {"symbol": symbol, "limit": limit, "period": period})

# %%
await financial_ratios("AMZN")
# Out:
# [{'symbol': 'AMZN',
#   'date': '2024-12-31',
#   'fiscalYear': '2024',
#   'period': 'FY',
#   'reportedCurrency': 'USD',
#   'grossProfitMargin': 0.48854393464156787,
#   'ebitMargin': 0.1113237684553396,
#   'ebitdaMargin': 0.194079870336495,
#   'operatingProfitMargin': 0.1075194487420038,
#   'pretaxProfitMargin': 0.10739404883385922,
#   'continuousOperationsProfitMargin': 0.09287117197186653,
#   'netProfitMargin': 0.09287117197186653,
#   'bottomLineProfitMargin': 0.09287117197186653,
#   'receivablesTurnover': 11.504914248615895,
#   'payablesTurnover': 3.4577959581615674,
#   'inventoryTurnover': 9.536680890863389,
#   'fixedAssetTurnover': 1.9402291928979398,
#   'assetTurnover': 1.020907545919788,
#   'currentRatio': 1.063734806137178,
#   'quickRatio': 0.8730542659852534,
#   'solvencyRatio': 0.3305844378090663,
#   'cashRatio': 0.43904899376361944,
#   'priceToEarningsRatio': 38.78057436537942,
#   'priceToEarningsGrowthRatio': 0.4221501637559753,
#   'forwardPriceToEarningsGrowthRatio': 0.4221501637559753,
#   'priceToBookRatio': 8.034659125083051,
#   'priceToSalesRatio': 3.601597391054911,
#   'priceToFreeCashFlowRatio': 69.88477005900602,
#   'priceToOperatingCashFlowRatio': 19.828537759866066,
#   'debtToAssetsRatio': 0.20947552704938757,
#   'debtToEquityRatio': 0.45774032241144175,
#   'debtToCapitalRatio': 0.314006764698827,
#   'longTermDebtToCapitalRatio': 0.15541668020307567,
#   'financialLeverageRatio': 2.1851732699234185,
#   'workingCapitalTurnoverRatio': 67.61621621621622,
#   'operatingCashFlowRatio': 0.645802564774203,
#   'operatingCashFlowSalesRatio': 0.1816370644508503,
#   'freeCashFlowOperatingCashFlowRatio': 0.28373188812275085,
#   'debtServiceCoverageRatio': 14.525741820948516,
#   'interestCoverageRatio': 28.509143807148796,
#   'shortTermOperatingCashFlowCoverageRatio': 21.14543795620438,
#   'operatingCashFlowCoverageRatio': 0.8852330022918258,
#   'capitalExpenditureCoverageRatio': 1.396125254521139,
#   'dividendPaidAndCapexCoverageRatio': 1.396125254521139,
#   'dividendPayoutRatio': 0,
#   'dividendYield': 0,
#   'dividendYieldPercentage': 0,
#   'revenuePerShare': 60.9146376396448,
#   'netIncomePerShare': 5.657213787835386,
#   'interestDebtPerShare': 12.728540055380503,
#   'cashPerShare': 9.663133772558007,
#   'bookValuePerShare': 27.305452114962282,
#   'tangibleBookValuePerShare': 24.280912823450777,
#   'shareholdersEquityPerShare': 27.305452114962282,
#   'operatingCashFlowPerShare': 11.064355962952353,
#   'capexPerShare': 7.925045354721665,
#   'freeCashFlowPerShare': 3.1393106082306885,
#   'netIncomePerEBT': 0.8647701895990542,
#   'ebtPerEbit': 0.9988337002318021,
#   'priceToFairValue': 8.034659125083051,
#   'debtToMarketCap': 0.025287775366771646,
#   'effectiveTaxRate': 0.1352298104009458,
#   'enterpriseValueMultiple': 18.97825360416751,
#   'dividendPerShare': 0},
#  {'symbol': 'AMZN',
#   'date': '2023-12-31',
#   'fiscalYear': '2023',
#   'period': 'FY',
#   'reportedCurrency': 'USD',
#   'grossProfitMargin': 0.46982088955000567,
#   'ebitMargin': 0.07087693659368285,
#   'ebitdaMargin': 0.15553989752690137,
#   'operatingProfitMargin': 0.0641144079960333,
#   'pretaxProfitMargin': 0.06534095357394504,
#   'continuousOperationsProfitMargin': 0.05293283575597832,
#   'netProfitMargin': 0.05293283575597832,
#   'bottomLineProfitMargin': 0.05293283575597832,
#   'receivablesTurnover': 11.000038275314337,
#   'payablesTurnover': 3.5859662748143704,
#   'inventoryTurnover': 9.146377333573444,
#   'fixedAssetTurnover': 2.0773609454624307,
#   'assetTurnover': 1.0889090543976174,
#   'currentRatio': 1.0450772206625152,
#   'quickRatio': 0.8430483212767634,
#   'solvencyRatio': 0.2426168556870228,
#   'cashRatio': 0.4449935422060794,
#   'priceToEarningsRatio': 51.45734626129828,
#   'priceToEarningsGrowthRatio': -0.04314746425636812,
#   'forwardPriceToEarningsGrowthRatio': -0.04314746425636812,
#   'priceToBookRatio': 7.755243393188854,
#   'priceToSalesRatio': 2.7237832580878067,
#   'priceToFreeCashFlowRatio': 48.59514417853928,
#   'priceToOperatingCashFlowRatio': 18.430411791020177,
#   'debtToAssetsRatio': 0.25691005467420913,
#   'debtToEquityRatio': 0.6717572755417957,
#   'debtToCapitalRatio': 0.4018270387512371,
#   'longTermDebtToCapitalRatio': 0.22412169615164362,
#   'financialLeverageRatio': 2.6147566563467493,
#   'workingCapitalTurnoverRatio': -984.2208904109589,
#   'operatingCashFlowRatio': 0.5150833449553411,
#   'operatingCashFlowSalesRatio': 0.14778743356211452,
#   'freeCashFlowOperatingCashFlowRatio': 0.37926447390106655,
#   'debtServiceCoverageRatio': 25.8585795097423,
#   'interestCoverageRatio': 11.581395348837209,
#   'shortTermOperatingCashFlowCoverageRatio': 0,
#   'operatingCashFlowCoverageRatio': 0.6263946140062384,
#   'capitalExpenditureCoverageRatio': 1.6109920537085853,
#   'dividendPaidAndCapexCoverageRatio': 1.6109920537085853,
#   'dividendPayoutRatio': 0,
#   'dividendYield': 0,
#   'dividendYieldPercentage': 0,
#   'revenuePerShare': 55.782705745341616,
#   'netIncomePerShare': 2.952736801242236,
#   'interestDebtPerShare': 13.469817546583851,
#   'cashPerShare': 8.42197204968944,
#   'bookValuePerShare': 19.591906055900623,
#   'tangibleBookValuePerShare': 16.634219720496894,
#   'shareholdersEquityPerShare': 19.591906055900623,
#   'operatingCashFlowPerShare': 8.243982919254659,
#   'capexPerShare': 5.117333074534161,
#   'freeCashFlowPerShare': 3.1266498447204967,
#   'netIncomePerEBT': 0.8101019783262774,
#   'ebtPerEbit': 1.019130576359492,
#   'priceToFairValue': 7.755243393188854,
#   'debtToMarketCap': 0.03724730544992834,
#   'effectiveTaxRate': 0.18957850733551668,
#   'enterpriseValueMultiple': 18.207800272924544,
#   'dividendPerShare': 0},
#  {'symbol': 'AMZN',
#   'date': '2022-12-31',
#   'fiscalYear': '2022',
#   'period': 'FY',
#   'reportedCurrency': 'USD',
#   'grossProfitMargin': 0.43805339865326287,
#   'ebitMargin': -0.00694380942560357,
#   'ebitdaMargin': 0.07461725387804655,
#   'operatingProfitMargin': 0.023829581912242232,
#   'pretaxProfitMargin': -0.011549020103777752,
#   'continuousOperationsProfitMargin': -0.005295895000418302,
#   'netProfitMargin': -0.005295895000418302,
#   'bottomLineProfitMargin': -0.005295895000418302,
#   'receivablesTurnover': 12.133687440982058,
#   'payablesTurnover': 3.628530150753769,
#   'inventoryTurnover': 8.395029792181369,
#   'fixedAssetTurnover': 2.0328550297028136,
#   'assetTurnover': 1.1108942562273734,
#   'currentRatio': 0.9446435811136924,
#   'quickRatio': 0.7232372114574016,
#   'solvencyRatio': 0.12379986861719598,
#   'cashRatio': 0.3467852477267316,
#   'priceToEarningsRatio': -314.42909625275536,
#   'priceToEarningsGrowthRatio': 2.906487444353201,
#   'forwardPriceToEarningsGrowthRatio': 2.906487444353201,
#   'priceToBookRatio': 5.860438364043467,
#   'priceToSalesRatio': 1.6651834788310118,
#   'priceToFreeCashFlowRatio': -50.66453560646421,
#   'priceToOperatingCashFlowRatio': 18.306724845995895,
#   'debtToAssetsRatio': 0.3028432485005674,
#   'debtToEquityRatio': 0.9594297569893798,
#   'debtToCapitalRatio': 0.48964743623344903,
#   'longTermDebtToCapitalRatio': 0.31497281805687805,
#   'financialLeverageRatio': 3.1680737864875415,
#   'workingCapitalTurnoverRatio': 95.96396564600448,
#   'operatingCashFlowRatio': 0.3008629732356026,
#   'operatingCashFlowSalesRatio': 0.09096020685509054,
#   'freeCashFlowOperatingCashFlowRatio': -0.361332135523614,
#   'debtServiceCoverageRatio': 17.561892691170257,
#   'interestCoverageRatio': 5.174482467258133,
#   'shortTermOperatingCashFlowCoverageRatio': 0,
#   'operatingCashFlowCoverageRatio': 0.3336616280563525,
#   'capitalExpenditureCoverageRatio': 0.734574593448032,
#   'dividendPaidAndCapexCoverageRatio': 0.734574593448032,
#   'dividendPayoutRatio': 0,
#   'dividendYield': 0,
#   'dividendYieldPercentage': 0,
#   'revenuePerShare': 50.44489154971047,
#   'netIncomePerShare': -0.2671508489547551,
#   'interestDebtPerShare': 13.984198645598195,
#   'cashPerShare': 6.872705859259987,
#   'bookValuePerShare': 14.333398763372264,
#   'tangibleBookValuePerShare': 11.743841397585632,
#   'shareholdersEquityPerShare': 14.333398763372264,
#   'operatingCashFlowPerShare': 4.588477770144273,
#   'capexPerShare': 6.246442241633134,
#   'freeCashFlowPerShare': -1.6579644714888606,
#   'netIncomePerEBT': 0.4585579514824798,
#   'ebtPerEbit': -0.4846505551926845,
#   'priceToFairValue': 5.860438364043467,
#   'debtToMarketCap': 0.07845762703943095,
#   'effectiveTaxRate': 0.5419474393530997,
#   'enterpriseValueMultiple': 24.56471631205674,
#   'dividendPerShare': 0},
#  {'symbol': 'AMZN',
#   'date': '2021-12-31',
#   'fiscalYear': '2021',
#   'period': 'FY',
#   'reportedCurrency': 'USD',
#   'grossProfitMargin': 0.420325144416396,
#   'ebitMargin': 0.0850534883423935,
#   'ebitdaMargin': 0.15834294690329528,
#   'operatingProfitMargin': 0.052954097509269465,
#   'pretaxProfitMargin': 0.08120309393770407,
#   'continuousOperationsProfitMargin': 0.07101412875514557,
#   'netProfitMargin': 0.07101412875514557,
#   'bottomLineProfitMargin': 0.07101412875514557,
#   'receivablesTurnover': 14.284211486424859,
#   'payablesTurnover': 3.4621173599105055,
#   'inventoryTurnover': 8.343872549019608,
#   'fixedAssetTurnover': 2.1714526051127043,
#   'assetTurnover': 1.1171635172120253,
#   'currentRatio': 1.1357597739445826,
#   'quickRatio': 0.9063303951752352,
#   'solvencyRatio': 0.24015600204035367,
#   'cashRatio': 0.2545935079358385,
#   'priceToEarningsRatio': 50.56966790552692,
#   'priceToEarningsGrowthRatio': 0.9206272875108747,
#   'forwardPriceToEarningsGrowthRatio': 0.9206272875108747,
#   'priceToBookRatio': 12.20446598430323,
#   'priceToSalesRatio': 3.5911609077480406,
#   'priceToFreeCashFlowRatio': -114.57329892706777,
#   'priceToOperatingCashFlowRatio': 36.419504824400455,
#   'debtToAssetsRatio': 0.2767691755300809,
#   'debtToEquityRatio': 0.8419472675322797,
#   'debtToCapitalRatio': 0.4570962928055294,
#   'longTermDebtToCapitalRatio': 0.26067843562990334,
#   'financialLeverageRatio': 3.04205577055228,
#   'workingCapitalTurnoverRatio': 36.61616397786611,
#   'operatingCashFlowRatio': 0.3256364837698396,
#   'operatingCashFlowSalesRatio': 0.09860542929024184,
#   'freeCashFlowOperatingCashFlowRatio': -0.3178707880933365,
#   'debtServiceCoverageRatio': 38.475400773908234,
#   'interestCoverageRatio': 13.75290215588723,
#   'shortTermOperatingCashFlowCoverageRatio': 0,
#   'operatingCashFlowCoverageRatio': 0.39801537866746856,
#   'capitalExpenditureCoverageRatio': 0.7587997313809314,
#   'dividendPaidAndCapexCoverageRatio': 0.7587997313809314,
#   'dividendPayoutRatio': 0,
#   'dividendYield': 0,
#   'dividendYieldPercentage': 0,
#   'revenuePerShare': 46.42509881422925,
#   'netIncomePerShare': 3.2968379446640315,
#   'interestDebtPerShare': 11.680237154150198,
#   'cashPerShare': 9.49100790513834,
#   'bookValuePerShare': 13.660573122529645,
#   'tangibleBookValuePerShare': 11.637055335968379,
#   'shareholdersEquityPerShare': 13.660573122529645,
#   'operatingCashFlowPerShare': 4.577766798418972,
#   'capexPerShare': 6.032905138339921,
#   'freeCashFlowPerShare': -1.4551383399209485,
#   'netIncomePerEBT': 0.8745249141569028,
#   'ebtPerEbit': 1.5334619558663933,
#   'priceToFairValue': 12.20446598430323,
#   'debtToMarketCap': 0.028890359827938063,
#   'effectiveTaxRate': 0.12557993237398757,
#   'enterpriseValueMultiple': 23.757361579718523,
#   'dividendPerShare': 0},
#  {'symbol': 'AMZN',
#   'date': '2020-12-31',
#   'fiscalYear': '2020',
#   'period': 'FY',
#   'reportedCurrency': 'USD',
#   'grossProfitMargin': 0.3956779186870571,
#   'ebitMargin': 0.06689305400140909,
#   'ebitdaMargin': 0.13211540055534834,
#   'operatingProfitMargin': 0.05931399975133657,
#   'pretaxProfitMargin': 0.06266836586679929,
#   'continuousOperationsProfitMargin': 0.05525249699531684,
#   'netProfitMargin': 0.05525249699531684,
#   'bottomLineProfitMargin': 0.05525249699531684,
#   'receivablesTurnover': 15.730747290359384,
#   'payablesTurnover': 3.216297439997794,
#   'inventoryTurnover': 9.804874973733977,
#   'fixedAssetTurnover': 2.562366012464574,
#   'assetTurnover': 1.2019614253023865,
#   'currentRatio': 1.0502274795268425,
#   'quickRatio': 0.8619535546148672,
#   'solvencyRatio': 0.20418278158487385,
#   'cashRatio': 0.33328322190133325,
#   'priceToEarningsRatio': 76.34428765646241,
#   'priceToEarningsGrowthRatio': 0.9304460058131357,
#   'forwardPriceToEarningsGrowthRatio': 0.9304460058131357,
#   'priceToBookRatio': 17.435013489786304,
#   'priceToSalesRatio': 4.218212524348295,
#   'priceToFreeCashFlowRatio': 62.81823792624595,
#   'priceToOperatingCashFlowRatio': 24.650339065148945,
#   'debtToAssetsRatio': 0.2627344759414063,
#   'debtToEquityRatio': 0.9034837908440752,
#   'debtToCapitalRatio': 0.47464748330924167,
#   'longTermDebtToCapitalRatio': 0.2540808177607411,
#   'financialLeverageRatio': 3.4387713588283155,
#   'workingCapitalTurnoverRatio': 51.92521856086079,
#   'operatingCashFlowRatio': 0.5227202595244689,
#   'operatingCashFlowSalesRatio': 0.17112188652658628,
#   'freeCashFlowOperatingCashFlowRatio': 0.39240736255751996,
#   'debtServiceCoverageRatio': 29.230115361262904,
#   'interestCoverageRatio': 13.903460837887067,
#   'shortTermOperatingCashFlowCoverageRatio': 0,
#   'operatingCashFlowCoverageRatio': 0.782850845489341,
#   'capitalExpenditureCoverageRatio': 1.6458395615346288,
#   'dividendPaidAndCapexCoverageRatio': 1.6458395615346288,
#   'dividendPayoutRatio': 0,
#   'dividendYield': 0,
#   'dividendYieldPercentage': 0,
#   'revenuePerShare': 38.6064,
#   'netIncomePerShare': 2.1331,
#   'interestDebtPerShare': 8.6036,
#   'cashPerShare': 8.4396,
#   'bookValuePerShare': 9.3404,
#   'tangibleBookValuePerShare': 7.3406,
#   'shareholdersEquityPerShare': 9.3404,
#   'operatingCashFlowPerShare': 6.6064,
#   'capexPerShare': 4.014,
#   'freeCashFlowPerShare': 2.5924,
#   'netIncomePerEBT': 0.881664875588989,
#   'ebtPerEbit': 1.0565526878903009,
#   'priceToFairValue': 17.435013489786304,
#   'debtToMarketCap': 0.019536997236720907,
#   'effectiveTaxRate': 0.11833512441101099,
#   'enterpriseValueMultiple': 32.75692579158906,
#   'dividendPerShare': 0}]

# %%
@mcp.tool()
async def historical_price_eod_full(symbol: str, date_from: Optional[str] = None, date_to: Optional[str] = None) -> Any:
    """Stock Price & Volume Data API — full daily OHLCV + VWAP with changes.

    Use this when:
      • You need historical daily bars (OHLCV) and changes (with optional range).
      • You’re doing backtests, trend analysis, or liquidity studies.

    Don’t use when:
      • You need intraday/minute or realtime ticks (not provided here).
      • You’re asking for corporate actions/adjustment events (use other endpoints).

    Endpoint: `/stable/historical-price-eod/full`

    What it provides:
      • **Detailed Price Series**: `open`, `high`, `low`, `close` per trading day.
      • **Volume & Liquidity**: Daily `volume` values for activity analysis.
      • **Price Dynamics**: Day-over-day `change` and `changePercent`.
      • **VWAP**: `vwap` to contextualize intraday weighted average price.

    Example use:
      • Analyze trends and liquidity over multi-month ranges for a symbol.

    Args:
      symbol: Ticker symbol.
      date_from: Optional start date `YYYY-MM-DD` (<= 5000 records per request).
      date_to: Optional end date `YYYY-MM-DD`.

    Returns:
      A list of daily bars with OHLCV, change, changePercent, and vwap.
    """
    params: Dict[str, Any] = {"symbol": symbol}
    if date_from:
        params["from"] = date_from
    if date_to:
        params["to"] = date_to
    return await fmp_api_request("historical-price-eod/full", params)

# %%
await historical_price_eod_full("MSFT")
# Out:
# [{'symbol': 'MSFT',
#   'date': '2025-12-02',
#   'open': 486.68,
#   'high': 493.4999,
#   'low': 486.32,
#   'close': 490,
#   'volume': 19561352,
#   'change': 3.32,
#   'changePercent': 0.68217309,
#   'vwap': 489.94},
#  {'symbol': 'MSFT',
#   'date': '2025-12-01',
#   'open': 488.44,
#   'high': 489.86,
#   'low': 484.65,
#   'close': 486.74,
#   'volume': 23964000,
#   'change': -1.7,
#   'changePercent': -0.34805,
#   'vwap': 487.42},
#  {'symbol': 'MSFT',
#   'date': '2025-11-28',
#   'open': 487.6,
#   'high': 492.63,
#   'low': 486.65,
#   'close': 492.01,
#   'volume': 14386730,
#   'change': 4.41,
#   'changePercent': 0.90443,
#   'vwap': 489.72},
#  {'symbol': 'MSFT',
#   'date': '2025-11-26',
#   'open': 486.31,
#   'high': 488.31,
#   'low': 481.2,
#   'close': 485.5,
#   'volume': 25709100,
#   'change': -0.81,
#   'changePercent': -0.16656,
#   'vwap': 485.33},
#  {'symbol': 'MSFT',
#   'date': '2025-11-25',
#   'open': 474.07,
#   'high': 479.15,
#   'low': 464.89,
#   'close': 476.99,
#   'volume': 28019800,
#   'change': 2.92,
#   'changePercent': 0.61594,
#   'vwap': 473.78},
#  {'symbol': 'MSFT',
#   'date': '2025-11-24',
#   'open': 475,
#   'high': 476.9,
#   'low': 468.02,
#   'close': 474,
#   'volume': 34421046,
#   'change': -1,
#   'changePercent': -0.21053,
#   'vwap': 473.48},
#  {'symbol': 'MSFT',
#   'date': '2025-11-21',
#   'open': 478.5,
#   'high': 478.92,
#   'low': 468.27,
#   'close': 472.12,
#   'volume': 31769248,
#   'change': -6.38,
#   'changePercent': -1.33,
#   'vwap': 474.4525},
#  {'symbol': 'MSFT',
#   'date': '2025-11-20',
#   'open': 492.71,
#   'high': 493.57,
#   'low': 475.5,
#   'close': 478.43,
#   'volume': 26802542,
#   'change': -14.28,
#   'changePercent': -2.9,
#   'vwap': 485.0525},
#  {'symbol': 'MSFT',
#   'date': '2025-11-19',
#   'open': 490.1,
#   'high': 495.19,
#   'low': 482.83,
#   'close': 487.12,
#   'volume': 23245314,
#   'change': -2.98,
#   'changePercent': -0.60804,
#   'vwap': 488.81},
#  {'symbol': 'MSFT',
#   'date': '2025-11-18',
#   'open': 495.37,
#   'high': 502.98,
#   'low': 486.78,
#   'close': 493.79,
#   'volume': 33815114,
#   'change': -1.57,
#   'changePercent': -0.31895,
#   'vwap': 494.73},
#  {'symbol': 'MSFT',
#   'date': '2025-11-17',
#   'open': 508.45,
#   'high': 512.12,
#   'low': 504.91,
#   'close': 507.49,
#   'volume': 19092800,
#   'change': -0.96,
#   'changePercent': -0.18881,
#   'vwap': 508.2425},
#  {'symbol': 'MSFT',
#   'date': '2025-11-14',
#   'open': 498.23,
#   'high': 511.6,
#   'low': 497.44,
#   'close': 510.18,
#   'volume': 28505746,
#   'change': 11.95,
#   'changePercent': 2.4,
#   'vwap': 504.3625},
#  {'symbol': 'MSFT',
#   'date': '2025-11-13',
#   'open': 510.31,
#   'high': 513.5,
#   'low': 501.29,
#   'close': 503.29,
#   'volume': 25273114,
#   'change': -7.02,
#   'changePercent': -1.38,
#   'vwap': 507.0975},
#  {'symbol': 'MSFT',
#   'date': '2025-11-12',
#   'open': 509.36,
#   'high': 511.67,
#   'low': 499.12,
#   'close': 511.14,
#   'volume': 26574900,
#   'change': 1.78,
#   'changePercent': 0.34946,
#   'vwap': 507.8225},
#  {'symbol': 'MSFT',
#   'date': '2025-11-11',
#   'open': 504.8,
#   'high': 509.6,
#   'low': 502.35,
#   'close': 508.68,
#   'volume': 17980020,
#   'change': 3.88,
#   'changePercent': 0.76862,
#   'vwap': 506.3575},
#  {'symbol': 'MSFT',
#   'date': '2025-11-10',
#   'open': 500.04,
#   'high': 506.85,
#   'low': 498.8,
#   'close': 506,
#   'volume': 26101500,
#   'change': 5.96,
#   'changePercent': 1.19,
#   'vwap': 502.9225},
#  {'symbol': 'MSFT',
#   'date': '2025-11-07',
#   'open': 496.95,
#   'high': 499.38,
#   'low': 493.25,
#   'close': 496.82,
#   'volume': 24019800,
#   'change': -0.125,
#   'changePercent': -0.02615957,
#   'vwap': 496.6},
#  {'symbol': 'MSFT',
#   'date': '2025-11-06',
#   'open': 505.66,
#   'high': 505.7,
#   'low': 495.81,
#   'close': 497.1,
#   'volume': 27406500,
#   'change': -8.56,
#   'changePercent': -1.69,
#   'vwap': 501.0675},
#  {'symbol': 'MSFT',
#   'date': '2025-11-05',
#   'open': 513.3,
#   'high': 514.83,
#   'low': 506.58,
#   'close': 507.16,
#   'volume': 23024342,
#   'change': -6.14,
#   'changePercent': -1.2,
#   'vwap': 510.4675},
#  {'symbol': 'MSFT',
#   'date': '2025-11-04',
#   'open': 511.76,
#   'high': 515.55,
#   'low': 507.84,
#   'close': 514.33,
#   'volume': 20958700,
#   'change': 2.57,
#   'changePercent': 0.50219,
#   'vwap': 512.37},
#  {'symbol': 'MSFT',
#   'date': '2025-11-03',
#   'open': 519.8,
#   'high': 524.96,
#   'low': 514.59,
#   'close': 517.03,
#   'volume': 22374742,
#   'change': -2.77,
#   'changePercent': -0.5329,
#   'vwap': 519.095},
#  {'symbol': 'MSFT',
#   'date': '2025-10-31',
#   'open': 528.88,
#   'high': 529.32,
#   'low': 515.1,
#   'close': 517.81,
#   'volume': 34006424,
#   'change': -11.07,
#   'changePercent': -2.09,
#   'vwap': 522.7775},
#  {'symbol': 'MSFT',
#   'date': '2025-10-30',
#   'open': 530.48,
#   'high': 534.97,
#   'low': 522.12,
#   'close': 525.76,
#   'volume': 41023100,
#   'change': -4.72,
#   'changePercent': -0.88976,
#   'vwap': 528.3325},
#  {'symbol': 'MSFT',
#   'date': '2025-10-29',
#   'open': 544.94,
#   'high': 546.27,
#   'low': 536.73,
#   'close': 541.55,
#   'volume': 36023004,
#   'change': -3.39,
#   'changePercent': -0.62209,
#   'vwap': 542.3725},
#  {'symbol': 'MSFT',
#   'date': '2025-10-28',
#   'open': 550,
#   'high': 553.72,
#   'low': 540.77,
#   'close': 542.07,
#   'volume': 29986700,
#   'change': -7.93,
#   'changePercent': -1.44,
#   'vwap': 546.64},
#  {'symbol': 'MSFT',
#   'date': '2025-10-27',
#   'open': 531.78,
#   'high': 534.58,
#   'low': 529.01,
#   'close': 531.52,
#   'volume': 18734716,
#   'change': -0.26,
#   'changePercent': -0.0488924,
#   'vwap': 531.7225},
#  {'symbol': 'MSFT',
#   'date': '2025-10-24',
#   'open': 522.79,
#   'high': 525.35,
#   'low': 520.71,
#   'close': 523.61,
#   'volume': 15532400,
#   'change': 0.82,
#   'changePercent': 0.15685,
#   'vwap': 523.115},
#  {'symbol': 'MSFT',
#   'date': '2025-10-23',
#   'open': 522.46,
#   'high': 523.95,
#   'low': 518.61,
#   'close': 520.56,
#   'volume': 14023532,
#   'change': -1.9,
#   'changePercent': -0.36366,
#   'vwap': 521.395},
#  {'symbol': 'MSFT',
#   'date': '2025-10-22',
#   'open': 521.15,
#   'high': 525.23,
#   'low': 517.71,
#   'close': 520.54,
#   'volume': 18962700,
#   'change': -0.61,
#   'changePercent': -0.11705,
#   'vwap': 521.1575},
#  {'symbol': 'MSFT',
#   'date': '2025-10-21',
#   'open': 517.5,
#   'high': 518.69,
#   'low': 513.04,
#   'close': 517.66,
#   'volume': 15586204,
#   'change': 0.16,
#   'changePercent': 0.03091787,
#   'vwap': 516.7225},
#  {'symbol': 'MSFT',
#   'date': '2025-10-20',
#   'open': 514.61,
#   'high': 518.7,
#   'low': 513.43,
#   'close': 516.79,
#   'volume': 14665620,
#   'change': 2.18,
#   'changePercent': 0.42362,
#   'vwap': 515.8825},
#  {'symbol': 'MSFT',
#   'date': '2025-10-17',
#   'open': 509.04,
#   'high': 515.48,
#   'low': 507.31,
#   'close': 513.58,
#   'volume': 19867800,
#   'change': 4.54,
#   'changePercent': 0.89187,
#   'vwap': 511.3525},
#  {'symbol': 'MSFT',
#   'date': '2025-10-16',
#   'open': 512.58,
#   'high': 516.85,
#   'low': 508.13,
#   'close': 511.61,
#   'volume': 15559600,
#   'change': -0.97,
#   'changePercent': -0.18924,
#   'vwap': 512.2925},
#  {'symbol': 'MSFT',
#   'date': '2025-10-15',
#   'open': 514.96,
#   'high': 517.19,
#   'low': 510,
#   'close': 513.43,
#   'volume': 14694700,
#   'change': -1.53,
#   'changePercent': -0.29711,
#   'vwap': 513.895},
#  {'symbol': 'MSFT',
#   'date': '2025-10-14',
#   'open': 510.23,
#   'high': 515.28,
#   'low': 506,
#   'close': 513.57,
#   'volume': 14684300,
#   'change': 3.35,
#   'changePercent': 0.65461,
#   'vwap': 511.27},
#  {'symbol': 'MSFT',
#   'date': '2025-10-13',
#   'open': 516.41,
#   'high': 516.41,
#   'low': 511.68,
#   'close': 514.05,
#   'volume': 14284238,
#   'change': -2.36,
#   'changePercent': -0.457,
#   'vwap': 514.6375},
#  {'symbol': 'MSFT',
#   'date': '2025-10-10',
#   'open': 519.64,
#   'high': 523.58,
#   'low': 509.63,
#   'close': 510.96,
#   'volume': 24133840,
#   'change': -8.68,
#   'changePercent': -1.67,
#   'vwap': 515.9525},
#  {'symbol': 'MSFT',
#   'date': '2025-10-09',
#   'open': 522.34,
#   'high': 524.33,
#   'low': 517.4,
#   'close': 522.4,
#   'volume': 18343602,
#   'change': 0.065,
#   'changePercent': 0.01148677,
#   'vwap': 521.6175},
#  {'symbol': 'MSFT',
#   'date': '2025-10-08',
#   'open': 523.28,
#   'high': 526.95,
#   'low': 523.09,
#   'close': 524.85,
#   'volume': 13363447,
#   'change': 1.57,
#   'changePercent': 0.30003,
#   'vwap': 524.5425},
#  {'symbol': 'MSFT',
#   'date': '2025-10-07',
#   'open': 528.29,
#   'high': 529.8,
#   'low': 521.44,
#   'close': 523.98,
#   'volume': 14615208,
#   'change': -4.3,
#   'changePercent': -0.81584,
#   'vwap': 525.8775},
#  {'symbol': 'MSFT',
#   'date': '2025-10-06',
#   'open': 518.61,
#   'high': 531.03,
#   'low': 518.2,
#   'close': 528.57,
#   'volume': 21388600,
#   'change': 9.96,
#   'changePercent': 1.92,
#   'vwap': 524.1025},
#  {'symbol': 'MSFT',
#   'date': '2025-10-03',
#   'open': 517.1,
#   'high': 520.49,
#   'low': 515,
#   'close': 517.35,
#   'volume': 15112321,
#   'change': 0.25,
#   'changePercent': 0.04834655,
#   'vwap': 517.485},
#  {'symbol': 'MSFT',
#   'date': '2025-10-02',
#   'open': 517.64,
#   'high': 521.6,
#   'low': 510.68,
#   'close': 515.74,
#   'volume': 21222900,
#   'change': -1.9,
#   'changePercent': -0.36705,
#   'vwap': 516.415},
#  {'symbol': 'MSFT',
#   'date': '2025-10-01',
#   'open': 514.8,
#   'high': 520.51,
#   'low': 511.69,
#   'close': 519.71,
#   'volume': 22632336,
#   'change': 4.91,
#   'changePercent': 0.95377,
#   'vwap': 516.6775},
#  {'symbol': 'MSFT',
#   'date': '2025-09-30',
#   'open': 513.24,
#   'high': 518.16,
#   'low': 509.66,
#   'close': 517.95,
#   'volume': 19728229,
#   'change': 4.71,
#   'changePercent': 0.9177,
#   'vwap': 514.7525},
#  {'symbol': 'MSFT',
#   'date': '2025-09-29',
#   'open': 511.5,
#   'high': 516.85,
#   'low': 508.88,
#   'close': 514.6,
#   'volume': 17617800,
#   'change': 3.1,
#   'changePercent': 0.60606,
#   'vwap': 512.9575},
#  {'symbol': 'MSFT',
#   'date': '2025-09-26',
#   'open': 510.06,
#   'high': 513.94,
#   'low': 506.62,
#   'close': 511.46,
#   'volume': 16213129,
#   'change': 1.4,
#   'changePercent': 0.27448,
#   'vwap': 510.52},
#  {'symbol': 'MSFT',
#   'date': '2025-09-25',
#   'open': 508.3,
#   'high': 510.01,
#   'low': 505.04,
#   'close': 507.03,
#   'volume': 15786500,
#   'change': -1.27,
#   'changePercent': -0.24985,
#   'vwap': 507.595},
#  {'symbol': 'MSFT',
#   'date': '2025-09-24',
#   'open': 510.38,
#   'high': 512.48,
#   'low': 506.92,
#   'close': 510.15,
#   'volume': 13533711,
#   'change': -0.23,
#   'changePercent': -0.04506446,
#   'vwap': 509.9825},
#  {'symbol': 'MSFT',
#   'date': '2025-09-23',
#   'open': 513.8,
#   'high': 514.59,
#   'low': 507.31,
#   'close': 509.23,
#   'volume': 19799600,
#   'change': -4.57,
#   'changePercent': -0.88945,
#   'vwap': 511.2325},
#  {'symbol': 'MSFT',
#   'date': '2025-09-22',
#   'open': 515.59,
#   'high': 517.74,
#   'low': 512.54,
#   'close': 514.45,
#   'volume': 20009314,
#   'change': -1.14,
#   'changePercent': -0.22111,
#   'vwap': 515.08},
#  {'symbol': 'MSFT',
#   'date': '2025-09-19',
#   'open': 510.56,
#   'high': 519.3,
#   'low': 510.31,
#   'close': 517.93,
#   'volume': 52474100,
#   'change': 7.37,
#   'changePercent': 1.44,
#   'vwap': 514.525},
#  {'symbol': 'MSFT',
#   'date': '2025-09-18',
#   'open': 511.49,
#   'high': 513.07,
#   'low': 507.66,
#   'close': 508.45,
#   'volume': 18913700,
#   'change': -3.04,
#   'changePercent': -0.59434,
#   'vwap': 510.1675},
#  {'symbol': 'MSFT',
#   'date': '2025-09-17',
#   'open': 510.62,
#   'high': 511.29,
#   'low': 505.93,
#   'close': 510.02,
#   'volume': 15816600,
#   'change': -0.6,
#   'changePercent': -0.1175,
#   'vwap': 509.465},
#  {'symbol': 'MSFT',
#   'date': '2025-09-16',
#   'open': 516.88,
#   'high': 517.23,
#   'low': 508.6,
#   'close': 509.04,
#   'volume': 19711922,
#   'change': -7.84,
#   'changePercent': -1.52,
#   'vwap': 512.9375},
#  {'symbol': 'MSFT',
#   'date': '2025-09-15',
#   'open': 508.79,
#   'high': 515.47,
#   'low': 507,
#   'close': 515.36,
#   'volume': 17143800,
#   'change': 6.57,
#   'changePercent': 1.29,
#   'vwap': 511.655},
#  {'symbol': 'MSFT',
#   'date': '2025-09-12',
#   'open': 506.65,
#   'high': 512.55,
#   'low': 503.85,
#   'close': 509.9,
#   'volume': 23624900,
#   'change': 3.25,
#   'changePercent': 0.64147,
#   'vwap': 508.2375},
#  {'symbol': 'MSFT',
#   'date': '2025-09-11',
#   'open': 502.25,
#   'high': 503.17,
#   'low': 497.88,
#   'close': 501.01,
#   'volume': 18881608,
#   'change': -1.24,
#   'changePercent': -0.24689,
#   'vwap': 501.0775},
#  {'symbol': 'MSFT',
#   'date': '2025-09-10',
#   'open': 502.98,
#   'high': 503.23,
#   'low': 496.72,
#   'close': 500.37,
#   'volume': 21611816,
#   'change': -2.61,
#   'changePercent': -0.51891,
#   'vwap': 500.825},
#  {'symbol': 'MSFT',
#   'date': '2025-09-09',
#   'open': 501.43,
#   'high': 502.25,
#   'low': 497.7,
#   'close': 498.41,
#   'volume': 14410542,
#   'change': -3.02,
#   'changePercent': -0.60228,
#   'vwap': 499.9475},
#  {'symbol': 'MSFT',
#   'date': '2025-09-08',
#   'open': 498.11,
#   'high': 501.2,
#   'low': 495.03,
#   'close': 498.2,
#   'volume': 16771015,
#   'change': 0.095,
#   'changePercent': 0.0180683,
#   'vwap': 498.135},
#  {'symbol': 'MSFT',
#   'date': '2025-09-05',
#   'open': 509.07,
#   'high': 511.97,
#   'low': 492.37,
#   'close': 495,
#   'volume': 31994846,
#   'change': -14.07,
#   'changePercent': -2.76,
#   'vwap': 502.1025},
#  {'symbol': 'MSFT',
#   'date': '2025-09-04',
#   'open': 504.3,
#   'high': 508.15,
#   'low': 503.15,
#   'close': 507.97,
#   'volume': 15509500,
#   'change': 3.67,
#   'changePercent': 0.72774,
#   'vwap': 505.8925},
#  {'symbol': 'MSFT',
#   'date': '2025-09-03',
#   'open': 503.79,
#   'high': 507.79,
#   'low': 502.32,
#   'close': 505.35,
#   'volume': 16345100,
#   'change': 1.56,
#   'changePercent': 0.30965,
#   'vwap': 504.8125},
#  {'symbol': 'MSFT',
#   'date': '2025-09-02',
#   'open': 500.47,
#   'high': 506,
#   'low': 496.81,
#   'close': 505.12,
#   'volume': 18128000,
#   'change': 4.66,
#   'changePercent': 0.92913,
#   'vwap': 502.1},
#  {'symbol': 'MSFT',
#   'date': '2025-08-29',
#   'open': 508.66,
#   'high': 509.6,
#   'low': 504.49,
#   'close': 506.69,
#   'volume': 20961600,
#   'change': -1.97,
#   'changePercent': -0.38729,
#   'vwap': 507.36},
#  {'symbol': 'MSFT',
#   'date': '2025-08-28',
#   'open': 507.09,
#   'high': 511.09,
#   'low': 505.5,
#   'close': 509.64,
#   'volume': 18015600,
#   'change': 2.55,
#   'changePercent': 0.50287,
#   'vwap': 508.33},
#  {'symbol': 'MSFT',
#   'date': '2025-08-27',
#   'open': 502,
#   'high': 507.29,
#   'low': 499.9,
#   'close': 506.74,
#   'volume': 17277900,
#   'change': 4.74,
#   'changePercent': 0.94422,
#   'vwap': 503.9825},
#  {'symbol': 'MSFT',
#   'date': '2025-08-26',
#   'open': 504.36,
#   'high': 504.98,
#   'low': 498.51,
#   'close': 502.04,
#   'volume': 30835709,
#   'change': -2.31,
#   'changePercent': -0.45999,
#   'vwap': 502.4725},
#  {'symbol': 'MSFT',
#   'date': '2025-08-25',
#   'open': 506.63,
#   'high': 508.19,
#   'low': 504.12,
#   'close': 504.26,
#   'volume': 21638600,
#   'change': -2.37,
#   'changePercent': -0.4678,
#   'vwap': 505.8},
#  {'symbol': 'MSFT',
#   'date': '2025-08-22',
#   'open': 504.25,
#   'high': 510.73,
#   'low': 502.41,
#   'close': 507.23,
#   'volume': 24324200,
#   'change': 2.98,
#   'changePercent': 0.59098,
#   'vwap': 506.155},
#  {'symbol': 'MSFT',
#   'date': '2025-08-21',
#   'open': 503.69,
#   'high': 507.63,
#   'low': 502.72,
#   'close': 504.24,
#   'volume': 18443300,
#   'change': 0.55,
#   'changePercent': 0.10919,
#   'vwap': 504.57},
#  {'symbol': 'MSFT',
#   'date': '2025-08-20',
#   'open': 509.87,
#   'high': 511,
#   'low': 504.44,
#   'close': 505.72,
#   'volume': 27723025,
#   'change': -4.14,
#   'changePercent': -0.81393,
#   'vwap': 507.7575},
#  {'symbol': 'MSFT',
#   'date': '2025-08-19',
#   'open': 515,
#   'high': 515.16,
#   'low': 508.55,
#   'close': 509.77,
#   'volume': 21481016,
#   'change': -5.23,
#   'changePercent': -1.02,
#   'vwap': 512.12},
#  {'symbol': 'MSFT',
#   'date': '2025-08-18',
#   'open': 521.59,
#   'high': 522.82,
#   'low': 514.02,
#   'close': 517.1,
#   'volume': 23760600,
#   'change': -4.49,
#   'changePercent': -0.86083,
#   'vwap': 518.8825},
#  {'symbol': 'MSFT',
#   'date': '2025-08-15',
#   'open': 522.77,
#   'high': 526.1,
#   'low': 519.08,
#   'close': 520.17,
#   'volume': 25213300,
#   'change': -2.6,
#   'changePercent': -0.49735,
#   'vwap': 522.03},
#  {'symbol': 'MSFT',
#   'date': '2025-08-14',
#   'open': 522.56,
#   'high': 525.95,
#   'low': 520.14,
#   'close': 522.48,
#   'volume': 20269100,
#   'change': -0.08,
#   'changePercent': -0.01530925,
#   'vwap': 522.7825},
#  {'symbol': 'MSFT',
#   'date': '2025-08-13',
#   'open': 532.11,
#   'high': 532.7,
#   'low': 519.37,
#   'close': 520.58,
#   'volume': 19619200,
#   'change': -11.53,
#   'changePercent': -2.17,
#   'vwap': 526.19},
#  {'symbol': 'MSFT',
#   'date': '2025-08-12',
#   'open': 523.75,
#   'high': 530.98,
#   'low': 522.7,
#   'close': 529.24,
#   'volume': 18688921,
#   'change': 5.49,
#   'changePercent': 1.05,
#   'vwap': 526.6675},
#  {'symbol': 'MSFT',
#   'date': '2025-08-11',
#   'open': 522.3,
#   'high': 527.59,
#   'low': 519.72,
#   'close': 521.77,
#   'volume': 20194400,
#   'change': -0.53,
#   'changePercent': -0.10147,
#   'vwap': 522.845},
#  {'symbol': 'MSFT',
#   'date': '2025-08-08',
#   'open': 522.6,
#   'high': 524.66,
#   'low': 519.41,
#   'close': 522.04,
#   'volume': 15531009,
#   'change': -0.56,
#   'changePercent': -0.10716,
#   'vwap': 522.1775},
#  {'symbol': 'MSFT',
#   'date': '2025-08-07',
#   'open': 526.8,
#   'high': 528.09,
#   'low': 517.55,
#   'close': 520.84,
#   'volume': 16079144,
#   'change': -5.96,
#   'changePercent': -1.13,
#   'vwap': 523.32},
#  {'symbol': 'MSFT',
#   'date': '2025-08-06',
#   'open': 530.9,
#   'high': 531.7,
#   'low': 524.03,
#   'close': 524.94,
#   'volume': 21355702,
#   'change': -5.96,
#   'changePercent': -1.12,
#   'vwap': 527.8925},
#  {'symbol': 'MSFT',
#   'date': '2025-08-05',
#   'open': 537.18,
#   'high': 537.3,
#   'low': 527.24,
#   'close': 527.75,
#   'volume': 19171600,
#   'change': -9.43,
#   'changePercent': -1.76,
#   'vwap': 532.3675},
#  {'symbol': 'MSFT',
#   'date': '2025-08-04',
#   'open': 528.27,
#   'high': 538.25,
#   'low': 528.13,
#   'close': 535.64,
#   'volume': 25349004,
#   'change': 7.37,
#   'changePercent': 1.4,
#   'vwap': 532.5725},
#  {'symbol': 'MSFT',
#   'date': '2025-08-01',
#   'open': 535,
#   'high': 535.8,
#   'low': 520.86,
#   'close': 524.11,
#   'volume': 28977628,
#   'change': -10.89,
#   'changePercent': -2.04,
#   'vwap': 528.9425},
#  {'symbol': 'MSFT',
#   'date': '2025-07-31',
#   'open': 555.23,
#   'high': 555.45,
#   'low': 531.9,
#   'close': 533.5,
#   'volume': 51617326,
#   'change': -21.73,
#   'changePercent': -3.91,
#   'vwap': 544.02},
#  {'symbol': 'MSFT',
#   'date': '2025-07-30',
#   'open': 515.17,
#   'high': 515.95,
#   'low': 509.44,
#   'close': 513.24,
#   'volume': 26380434,
#   'change': -1.93,
#   'changePercent': -0.37463,
#   'vwap': 513.45},
#  {'symbol': 'MSFT',
#   'date': '2025-07-29',
#   'open': 515.53,
#   'high': 517.62,
#   'low': 511.56,
#   'close': 512.57,
#   'volume': 16469235,
#   'change': -2.96,
#   'changePercent': -0.57417,
#   'vwap': 514.32},
#  {'symbol': 'MSFT',
#   'date': '2025-07-28',
#   'open': 514.08,
#   'high': 515,
#   'low': 510.12,
#   'close': 512.5,
#   'volume': 14308027,
#   'change': -1.58,
#   'changePercent': -0.30735,
#   'vwap': 512.925},
#  {'symbol': 'MSFT',
#   'date': '2025-07-25',
#   'open': 512.47,
#   'high': 518.29,
#   'low': 510.36,
#   'close': 513.71,
#   'volume': 19125700,
#   'change': 1.25,
#   'changePercent': 0.24197,
#   'vwap': 513.7075},
#  {'symbol': 'MSFT',
#   'date': '2025-07-24',
#   'open': 508.77,
#   'high': 513.67,
#   'low': 507.3,
#   'close': 510.88,
#   'volume': 16107000,
#   'change': 2.11,
#   'changePercent': 0.41473,
#   'vwap': 510.155},
#  {'symbol': 'MSFT',
#   'date': '2025-07-23',
#   'open': 506.75,
#   'high': 506.79,
#   'low': 500.7,
#   'close': 505.87,
#   'volume': 16396600,
#   'change': -0.88,
#   'changePercent': -0.17366,
#   'vwap': 505.0275},
#  {'symbol': 'MSFT',
#   'date': '2025-07-22',
#   'open': 510.97,
#   'high': 511.2,
#   'low': 505.27,
#   'close': 505.27,
#   'volume': 13868644,
#   'change': -5.7,
#   'changePercent': -1.12,
#   'vwap': 508.1775},
#  {'symbol': 'MSFT',
#   'date': '2025-07-21',
#   'open': 506.71,
#   'high': 512.09,
#   'low': 505.55,
#   'close': 510.06,
#   'volume': 14066805,
#   'change': 3.36,
#   'changePercent': 0.66113,
#   'vwap': 508.6025},
#  {'symbol': 'MSFT',
#   'date': '2025-07-18',
#   'open': 514.48,
#   'high': 514.64,
#   'low': 507.43,
#   'close': 510.05,
#   'volume': 21209700,
#   'change': -4.43,
#   'changePercent': -0.86106,
#   'vwap': 511.65},
#  {'symbol': 'MSFT',
#   'date': '2025-07-17',
#   'open': 505.68,
#   'high': 513.37,
#   'low': 505.62,
#   'close': 511.7,
#   'volume': 17503129,
#   'change': 6.02,
#   'changePercent': 1.19,
#   'vwap': 509.0925},
#  {'symbol': 'MSFT',
#   'date': '2025-07-16',
#   'open': 505.18,
#   'high': 506.72,
#   'low': 501.89,
#   'close': 505.62,
#   'volume': 15154400,
#   'change': 0.44,
#   'changePercent': 0.08709767,
#   'vwap': 504.8525},
#  {'symbol': 'MSFT',
#   'date': '2025-07-15',
#   'open': 503.02,
#   'high': 508.3,
#   'low': 502.79,
#   'close': 505.82,
#   'volume': 14927202,
#   'change': 2.8,
#   'changePercent': 0.55664,
#   'vwap': 504.9825},
#  {'symbol': 'MSFT',
#   'date': '2025-07-14',
#   'open': 501.52,
#   'high': 503.97,
#   'low': 501.03,
#   'close': 503.02,
#   'volume': 12058848,
#   'change': 1.5,
#   'changePercent': 0.29909,
#   'vwap': 502.385},
#  {'symbol': 'MSFT',
#   'date': '2025-07-11',
#   'open': 498.47,
#   'high': 505.03,
#   'low': 497.8,
#   'close': 503.32,
#   'volume': 16459512,
#   'change': 4.85,
#   'changePercent': 0.97298,
#   'vwap': 501.155},
#  {'symbol': 'MSFT',
#   'date': '2025-07-10',
#   'open': 503.05,
#   'high': 504.44,
#   'low': 497.75,
#   'close': 501.48,
#   'volume': 16498740,
#   'change': -1.57,
#   'changePercent': -0.3121,
#   'vwap': 501.68},
#  {'symbol': 'MSFT',
#   'date': '2025-07-09',
#   'open': 500.3,
#   'high': 506.78,
#   'low': 499.74,
#   'close': 503.51,
#   'volume': 18659538,
#   'change': 3.21,
#   'changePercent': 0.64162,
#   'vwap': 502.5825},
#  {'symbol': 'MSFT',
#   'date': '2025-07-08',
#   'open': 497.24,
#   'high': 498.2,
#   'low': 494.11,
#   'close': 496.62,
#   'volume': 11846600,
#   'change': -0.62,
#   'changePercent': -0.12469,
#   'vwap': 496.5425},
#  {'symbol': 'MSFT',
#   'date': '2025-07-07',
#   'open': 497.38,
#   'high': 498.75,
#   'low': 495.23,
#   'close': 497.72,
#   'volume': 13981605,
#   'change': 0.34,
#   'changePercent': 0.0683582,
#   'vwap': 497.27},
#  {'symbol': 'MSFT',
#   'date': '2025-07-03',
#   'open': 493.81,
#   'high': 500.13,
#   'low': 493.44,
#   'close': 498.84,
#   'volume': 13984829,
#   'change': 5.03,
#   'changePercent': 1.02,
#   'vwap': 496.555},
#  {'symbol': 'MSFT',
#   'date': '2025-07-02',
#   'open': 489.99,
#   'high': 493.5,
#   'low': 488.7,
#   'close': 491.09,
#   'volume': 16319641,
#   'change': 1.1,
#   'changePercent': 0.22449,
#   'vwap': 490.82},
#  {'symbol': 'MSFT',
#   'date': '2025-07-01',
#   'open': 496.47,
#   'high': 498.05,
#   'low': 490.98,
#   'close': 492.05,
#   'volume': 19945400,
#   'change': -4.42,
#   'changePercent': -0.89029,
#   'vwap': 494.3875},
#  {'symbol': 'MSFT',
#   'date': '2025-06-30',
#   'open': 497.04,
#   'high': 500.76,
#   'low': 495.33,
#   'close': 497.41,
#   'volume': 28369000,
#   'change': 0.37,
#   'changePercent': 0.07444069,
#   'vwap': 497.635},
#  {'symbol': 'MSFT',
#   'date': '2025-06-27',
#   'open': 497.55,
#   'high': 499.3,
#   'low': 493.03,
#   'close': 495.94,
#   'volume': 34539236,
#   'change': -1.61,
#   'changePercent': -0.32359,
#   'vwap': 496.455},
#  {'symbol': 'MSFT',
#   'date': '2025-06-26',
#   'open': 492.98,
#   'high': 498.04,
#   'low': 492.81,
#   'close': 497.45,
#   'volume': 21578900,
#   'change': 4.47,
#   'changePercent': 0.90673,
#   'vwap': 495.32},
#  {'symbol': 'MSFT',
#   'date': '2025-06-25',
#   'open': 492.04,
#   'high': 494.56,
#   'low': 489.39,
#   'close': 492.27,
#   'volume': 17495100,
#   'change': 0.23,
#   'changePercent': 0.04674417,
#   'vwap': 492.065},
#  {'symbol': 'MSFT',
#   'date': '2025-06-24',
#   'open': 488.95,
#   'high': 491.85,
#   'low': 486.8,
#   'close': 490.11,
#   'volume': 22305642,
#   'change': 1.16,
#   'changePercent': 0.23724,
#   'vwap': 489.4275},
#  {'symbol': 'MSFT',
#   'date': '2025-06-23',
#   'open': 478.21,
#   'high': 487.75,
#   'low': 472.51,
#   'close': 486,
#   'volume': 24864000,
#   'change': 7.79,
#   'changePercent': 1.63,
#   'vwap': 481.1175},
#  {'symbol': 'MSFT',
#   'date': '2025-06-20',
#   'open': 482.23,
#   'high': 483.46,
#   'low': 476.87,
#   'close': 477.4,
#   'volume': 37576206,
#   'change': -4.83,
#   'changePercent': -1,
#   'vwap': 479.99},
#  {'symbol': 'MSFT',
#   'date': '2025-06-18',
#   'open': 478,
#   'high': 481,
#   'low': 474.46,
#   'close': 480.24,
#   'volume': 17526500,
#   'change': 2.24,
#   'changePercent': 0.46862,
#   'vwap': 478.425},
#  {'symbol': 'MSFT',
#   'date': '2025-06-17',
#   'open': 475.4,
#   'high': 478.74,
#   'low': 474.08,
#   'close': 478.04,
#   'volume': 15414128,
#   'change': 2.65,
#   'changePercent': 0.55532,
#   'vwap': 476.565},
#  {'symbol': 'MSFT',
#   'date': '2025-06-16',
#   'open': 475.21,
#   'high': 480.69,
#   'low': 475,
#   'close': 479.14,
#   'volume': 15626104,
#   'change': 3.93,
#   'changePercent': 0.827,
#   'vwap': 477.51},
#  {'symbol': 'MSFT',
#   'date': '2025-06-13',
#   'open': 476.41,
#   'high': 479.18,
#   'low': 472.76,
#   'close': 474.96,
#   'volume': 16814500,
#   'change': -1.45,
#   'changePercent': -0.30436,
#   'vwap': 475.8275},
#  {'symbol': 'MSFT',
#   'date': '2025-06-12',
#   'open': 475.02,
#   'high': 480.42,
#   'low': 473.52,
#   'close': 478.87,
#   'volume': 18950600,
#   'change': 3.85,
#   'changePercent': 0.81049,
#   'vwap': 476.9575},
#  {'symbol': 'MSFT',
#   'date': '2025-06-11',
#   'open': 470.02,
#   'high': 475.47,
#   'low': 469.66,
#   'close': 472.62,
#   'volume': 16399200,
#   'change': 2.6,
#   'changePercent': 0.55317,
#   'vwap': 471.9425},
#  {'symbol': 'MSFT',
#   'date': '2025-06-10',
#   'open': 471.19,
#   'high': 472.8,
#   'low': 466.96,
#   'close': 470.92,
#   'volume': 15375944,
#   'change': -0.265,
#   'changePercent': -0.05730173,
#   'vwap': 470.4675},
#  {'symbol': 'MSFT',
#   'date': '2025-06-09',
#   'open': 469.7,
#   'high': 473.43,
#   'low': 468.62,
#   'close': 472.75,
#   'volume': 16469932,
#   'change': 3.05,
#   'changePercent': 0.64935,
#   'vwap': 471.125},
#  {'symbol': 'MSFT',
#   'date': '2025-06-06',
#   'open': 470.09,
#   'high': 473.34,
#   'low': 468.78,
#   'close': 470.38,
#   'volume': 15285624,
#   'change': 0.295,
#   'changePercent': 0.06169031,
#   'vwap': 470.6475},
#  {'symbol': 'MSFT',
#   'date': '2025-06-05',
#   'open': 464.96,
#   'high': 469.65,
#   'low': 464.03,
#   'close': 467.68,
#   'volume': 20154460,
#   'change': 2.73,
#   'changePercent': 0.585,
#   'vwap': 466.58},
#  {'symbol': 'MSFT',
#   'date': '2025-06-04',
#   'open': 464,
#   'high': 465.69,
#   'low': 463.02,
#   'close': 463.87,
#   'volume': 14162700,
#   'change': -0.13,
#   'changePercent': -0.02801724,
#   'vwap': 464.145},
#  {'symbol': 'MSFT',
#   'date': '2025-06-03',
#   'open': 461.47,
#   'high': 464.14,
#   'low': 460.86,
#   'close': 462.97,
#   'volume': 15743800,
#   'change': 1.5,
#   'changePercent': 0.32505,
#   'vwap': 462.36},
#  {'symbol': 'MSFT',
#   'date': '2025-06-02',
#   'open': 457.14,
#   'high': 462.11,
#   'low': 456.89,
#   'close': 461.97,
#   'volume': 16626500,
#   'change': 4.83,
#   'changePercent': 1.06,
#   'vwap': 459.5275},
#  {'symbol': 'MSFT',
#   'date': '2025-05-30',
#   'open': 459.72,
#   'high': 461.68,
#   'low': 455.54,
#   'close': 460.36,
#   'volume': 34770500,
#   'change': 0.645,
#   'changePercent': 0.13922,
#   'vwap': 459.325},
#  {'symbol': 'MSFT',
#   'date': '2025-05-29',
#   'open': 461.55,
#   'high': 461.72,
#   'low': 455.31,
#   'close': 458.68,
#   'volume': 13982211,
#   'change': -2.87,
#   'changePercent': -0.62182,
#   'vwap': 459.315},
#  {'symbol': 'MSFT',
#   'date': '2025-05-28',
#   'open': 461.22,
#   'high': 462.52,
#   'low': 456.93,
#   'close': 457.36,
#   'volume': 17086300,
#   'change': -3.86,
#   'changePercent': -0.83691,
#   'vwap': 459.5075},
#  {'symbol': 'MSFT',
#   'date': '2025-05-27',
#   'open': 456.48,
#   'high': 460.95,
#   'low': 456.12,
#   'close': 460.69,
#   'volume': 20974300,
#   'change': 4.21,
#   'changePercent': 0.92227,
#   'vwap': 458.56},
#  {'symbol': 'MSFT',
#   'date': '2025-05-23',
#   'open': 449.98,
#   'high': 453.69,
#   'low': 448.91,
#   'close': 450.18,
#   'volume': 16883509,
#   'change': 0.2,
#   'changePercent': 0.04444642,
#   'vwap': 450.69},
#  {'symbol': 'MSFT',
#   'date': '2025-05-22',
#   'open': 454.95,
#   'high': 460.25,
#   'low': 453.9,
#   'close': 454.86,
#   'volume': 18025612,
#   'change': -0.09,
#   'changePercent': -0.01978239,
#   'vwap': 455.99},
#  {'symbol': 'MSFT',
#   'date': '2025-05-21',
#   'open': 454.57,
#   'high': 457.78,
#   'low': 451.81,
#   'close': 452.57,
#   'volume': 19216906,
#   'change': -2,
#   'changePercent': -0.43998,
#   'vwap': 454.1825},
#  {'symbol': 'MSFT',
#   'date': '2025-05-20',
#   'open': 455.59,
#   'high': 458.34,
#   'low': 454.32,
#   'close': 458.17,
#   'volume': 15441808,
#   'change': 2.58,
#   'changePercent': 0.5663,
#   'vwap': 456.605},
#  {'symbol': 'MSFT',
#   'date': '2025-05-19',
#   'open': 450.88,
#   'high': 459.59,
#   'low': 450.8,
#   'close': 458.87,
#   'volume': 21336509,
#   'change': 8,
#   'changePercent': 1.77,
#   'vwap': 455.035},
#  {'symbol': 'MSFT',
#   'date': '2025-05-16',
#   'open': 452.05,
#   'high': 454.36,
#   'low': 448.73,
#   'close': 454.27,
#   'volume': 23849800,
#   'change': 2.22,
#   'changePercent': 0.4911,
#   'vwap': 452.3525},
#  {'symbol': 'MSFT',
#   'date': '2025-05-15',
#   'open': 450.77,
#   'high': 456.19,
#   'low': 450.43,
#   'close': 453.13,
#   'volume': 21992323,
#   'change': 2.37,
#   'changePercent': 0.52355,
#   'vwap': 452.63},
#  {'symbol': 'MSFT',
#   'date': '2025-05-14',
#   'open': 448.14,
#   'high': 453.9,
#   'low': 448.14,
#   'close': 452.94,
#   'volume': 19902800,
#   'change': 4.8,
#   'changePercent': 1.07,
#   'vwap': 450.78},
#  {'symbol': 'MSFT',
#   'date': '2025-05-13',
#   'open': 447.78,
#   'high': 450.67,
#   'low': 445.36,
#   'close': 449.14,
#   'volume': 23618819,
#   'change': 1.36,
#   'changePercent': 0.30372,
#   'vwap': 448.2375},
#  {'symbol': 'MSFT',
#   'date': '2025-05-12',
#   'open': 445.94,
#   'high': 449.37,
#   'low': 439.78,
#   'close': 449.26,
#   'volume': 22821935,
#   'change': 3.32,
#   'changePercent': 0.74449,
#   'vwap': 446.0875},
#  {'symbol': 'MSFT',
#   'date': '2025-05-09',
#   'open': 440,
#   'high': 440.74,
#   'low': 435.88,
#   'close': 438.73,
#   'volume': 15324233,
#   'change': -1.27,
#   'changePercent': -0.28864,
#   'vwap': 438.8375},
#  {'symbol': 'MSFT',
#   'date': '2025-05-08',
#   'open': 437.93,
#   'high': 443.67,
#   'low': 435.66,
#   'close': 438.17,
#   'volume': 23491330,
#   'change': 0.24,
#   'changePercent': 0.05480328,
#   'vwap': 438.8575},
#  {'symbol': 'MSFT',
#   'date': '2025-05-07',
#   'open': 433.84,
#   'high': 438.12,
#   'low': 431.11,
#   'close': 433.35,
#   'volume': 23307241,
#   'change': -0.49,
#   'changePercent': -0.11294,
#   'vwap': 434.105},
#  {'symbol': 'MSFT',
#   'date': '2025-05-06',
#   'open': 432.2,
#   'high': 437.73,
#   'low': 431.17,
#   'close': 433.31,
#   'volume': 15104204,
#   'change': 1.11,
#   'changePercent': 0.25683,
#   'vwap': 433.6025},
#  {'symbol': 'MSFT',
#   'date': '2025-05-05',
#   'open': 432.87,
#   'high': 439.5,
#   'low': 432.11,
#   'close': 436.17,
#   'volume': 20136100,
#   'change': 3.3,
#   'changePercent': 0.76235,
#   'vwap': 435.1625},
#  {'symbol': 'MSFT',
#   'date': '2025-05-02',
#   'open': 431.74,
#   'high': 439.44,
#   'low': 429.99,
#   'close': 435.28,
#   'volume': 30757434,
#   'change': 3.54,
#   'changePercent': 0.81994,
#   'vwap': 434.1125},
#  {'symbol': 'MSFT',
#   'date': '2025-05-01',
#   'open': 431.11,
#   'high': 436.99,
#   'low': 424.9,
#   'close': 425.4,
#   'volume': 58938100,
#   'change': -5.71,
#   'changePercent': -1.32,
#   'vwap': 429.6},
#  {'symbol': 'MSFT',
#   'date': '2025-04-30',
#   'open': 390.3,
#   'high': 396.66,
#   'low': 384.44,
#   'close': 395.26,
#   'volume': 36461100,
#   'change': 4.96,
#   'changePercent': 1.27,
#   'vwap': 391.665},
#  {'symbol': 'MSFT',
#   'date': '2025-04-29',
#   'open': 391.3,
#   'high': 395.1,
#   'low': 390.38,
#   'close': 394.04,
#   'volume': 14974000,
#   'change': 2.74,
#   'changePercent': 0.70023,
#   'vwap': 392.705},
#  {'symbol': 'MSFT',
#   'date': '2025-04-28',
#   'open': 391.96,
#   'high': 392.74,
#   'low': 386.64,
#   'close': 391.16,
#   'volume': 16579430,
#   'change': -0.795,
#   'changePercent': -0.2041,
#   'vwap': 390.625},
#  {'symbol': 'MSFT',
#   'date': '2025-04-25',
#   'open': 387,
#   'high': 392.16,
#   'low': 384.6,
#   'close': 391.85,
#   'volume': 18973200,
#   'change': 4.85,
#   'changePercent': 1.25,
#   'vwap': 388.9025},
#  {'symbol': 'MSFT',
#   'date': '2025-04-24',
#   'open': 375.7,
#   'high': 388.45,
#   'low': 375.19,
#   'close': 387.3,
#   'volume': 22232300,
#   'change': 11.61,
#   'changePercent': 3.09,
#   'vwap': 381.66},
#  {'symbol': 'MSFT',
#   'date': '2025-04-23',
#   'open': 376.06,
#   'high': 380.39,
#   'low': 373.02,
#   'close': 374.39,
#   'volume': 20545526,
#   'change': -1.67,
#   'changePercent': -0.44408,
#   'vwap': 375.965},
#  {'symbol': 'MSFT',
#   'date': '2025-04-22',
#   'open': 363.38,
#   'high': 367.77,
#   'low': 359.86,
#   'close': 366.82,
#   'volume': 19485000,
#   'change': 3.44,
#   'changePercent': 0.94667,
#   'vwap': 364.4575},
#  {'symbol': 'MSFT',
#   'date': '2025-04-21',
#   'open': 362.82,
#   'high': 364.48,
#   'low': 355.67,
#   'close': 359.12,
#   'volume': 20807300,
#   'change': -3.69,
#   'changePercent': -1.02,
#   'vwap': 360.5225},
#  {'symbol': 'MSFT',
#   'date': '2025-04-17',
#   'open': 373.75,
#   'high': 374.32,
#   'low': 366.89,
#   'close': 367.78,
#   'volume': 21120200,
#   'change': -5.97,
#   'changePercent': -1.6,
#   'vwap': 370.685},
#  {'symbol': 'MSFT',
#   'date': '2025-04-16',
#   'open': 380.67,
#   'high': 381.61,
#   'low': 368,
#   'close': 371.61,
#   'volume': 21967826,
#   'change': -9.06,
#   'changePercent': -2.38,
#   'vwap': 375.4725},
#  {'symbol': 'MSFT',
#   'date': '2025-04-15',
#   'open': 388.51,
#   'high': 391.89,
#   'low': 384.16,
#   'close': 385.73,
#   'volume': 17199900,
#   'change': -2.77,
#   'changePercent': -0.71555,
#   'vwap': 387.5725},
#  {'symbol': 'MSFT',
#   'date': '2025-04-14',
#   'open': 393.22,
#   'high': 394.65,
#   'low': 384.21,
#   'close': 387.81,
#   'volume': 19251200,
#   'change': -5.41,
#   'changePercent': -1.38,
#   'vwap': 389.9725},
#  {'symbol': 'MSFT',
#   'date': '2025-04-11',
#   'open': 380.64,
#   'high': 390.05,
#   'low': 378.89,
#   'close': 388.45,
#   'volume': 23839220,
#   'change': 7.81,
#   'changePercent': 2.05,
#   'vwap': 384.5075},
#  {'symbol': 'MSFT',
#   'date': '2025-04-10',
#   'open': 382.06,
#   'high': 383.9,
#   'low': 367.8,
#   'close': 381.35,
#   'volume': 38024400,
#   'change': -0.71,
#   'changePercent': -0.18583,
#   'vwap': 378.7775},
#  {'symbol': 'MSFT',
#   'date': '2025-04-09',
#   'open': 353.54,
#   'high': 393.23,
#   'low': 353.1,
#   'close': 390.49,
#   'volume': 50199700,
#   'change': 36.95,
#   'changePercent': 10.45,
#   'vwap': 372.59},
#  {'symbol': 'MSFT',
#   'date': '2025-04-08',
#   'open': 368.26,
#   'high': 373.65,
#   'low': 350.25,
#   'close': 354.56,
#   'volume': 35868918,
#   'change': -13.69,
#   'changePercent': -3.72,
#   'vwap': 361.68},
#  {'symbol': 'MSFT',
#   'date': '2025-04-07',
#   'open': 350.88,
#   'high': 371,
#   'low': 344.79,
#   'close': 357.86,
#   'volume': 50425000,
#   'change': 6.98,
#   'changePercent': 1.99,
#   'vwap': 356.1325},
#  {'symbol': 'MSFT',
#   'date': '2025-04-04',
#   'open': 364.13,
#   'high': 374.59,
#   'low': 359.48,
#   'close': 359.84,
#   'volume': 49209900,
#   'change': -4.29,
#   'changePercent': -1.18,
#   'vwap': 364.51},
#  {'symbol': 'MSFT',
#   'date': '2025-04-03',
#   'open': 374.79,
#   'high': 377.48,
#   'low': 369.35,
#   'close': 373.11,
#   'volume': 30198000,
#   'change': -1.68,
#   'changePercent': -0.44825,
#   'vwap': 373.6825},
#  {'symbol': 'MSFT',
#   'date': '2025-04-02',
#   'open': 377.97,
#   'high': 385.08,
#   'low': 376.62,
#   'close': 382.14,
#   'volume': 16092600,
#   'change': 4.18,
#   'changePercent': 1.1,
#   'vwap': 380.4525},
#  {'symbol': 'MSFT',
#   'date': '2025-04-01',
#   'open': 374.65,
#   'high': 382.85,
#   'low': 373.23,
#   'close': 382.19,
#   'volume': 19689503,
#   'change': 7.54,
#   'changePercent': 2.01,
#   'vwap': 378.23},
#  {'symbol': 'MSFT',
#   'date': '2025-03-31',
#   'open': 372.54,
#   'high': 377.07,
#   'low': 367.24,
#   'close': 375.39,
#   'volume': 35184700,
#   'change': 2.85,
#   'changePercent': 0.76502,
#   'vwap': 373.06},
#  {'symbol': 'MSFT',
#   'date': '2025-03-28',
#   'open': 388.08,
#   'high': 389.13,
#   'low': 376.93,
#   'close': 378.8,
#   'volume': 21632016,
#   'change': -9.28,
#   'changePercent': -2.39,
#   'vwap': 383.235},
#  {'symbol': 'MSFT',
#   'date': '2025-03-27',
#   'open': 390.13,
#   'high': 392.24,
#   'low': 387.4,
#   'close': 390.58,
#   'volume': 13766800,
#   'change': 0.45,
#   'changePercent': 0.11535,
#   'vwap': 390.0875},
#  {'symbol': 'MSFT',
#   'date': '2025-03-26',
#   'open': 395,
#   'high': 395.31,
#   'low': 388.57,
#   'close': 389.97,
#   'volume': 16132906,
#   'change': -5.03,
#   'changePercent': -1.27,
#   'vwap': 392.2125},
#  {'symbol': 'MSFT',
#   'date': '2025-03-25',
#   'open': 393.92,
#   'high': 396.36,
#   'low': 392.64,
#   'close': 395.16,
#   'volume': 15775000,
#   'change': 1.25,
#   'changePercent': 0.31478,
#   'vwap': 394.52},
#  {'symbol': 'MSFT',
#   'date': '2025-03-24',
#   'open': 395.4,
#   'high': 395.4,
#   'low': 389.81,
#   'close': 393.08,
#   'volume': 21004548,
#   'change': -2.32,
#   'changePercent': -0.58675,
#   'vwap': 393.4225},
#  {'symbol': 'MSFT',
#   'date': '2025-03-21',
#   'open': 383.22,
#   'high': 391.74,
#   'low': 382.8,
#   'close': 391.26,
#   'volume': 39675928,
#   'change': 8.05,
#   'changePercent': 2.1,
#   'vwap': 387.255},
#  {'symbol': 'MSFT',
#   'date': '2025-03-20',
#   'open': 385.74,
#   'high': 391.79,
#   'low': 383.28,
#   'close': 386.84,
#   'volume': 18470542,
#   'change': 1.1,
#   'changePercent': 0.28517,
#   'vwap': 386.9125},
#  {'symbol': 'MSFT',
#   'date': '2025-03-19',
#   'open': 385.53,
#   'high': 389.68,
#   'low': 384,
#   'close': 387.82,
#   'volume': 19185532,
#   'change': 2.3,
#   'changePercent': 0.59399,
#   'vwap': 386.7575},
#  {'symbol': 'MSFT',
#   'date': '2025-03-18',
#   'open': 387.07,
#   'high': 387.37,
#   'low': 381.1,
#   'close': 383.52,
#   'volume': 19486900,
#   'change': -3.55,
#   'changePercent': -0.91715,
#   'vwap': 384.765},
#  {'symbol': 'MSFT',
#   'date': '2025-03-17',
#   'open': 386.7,
#   'high': 392.71,
#   'low': 385.57,
#   'close': 388.7,
#   'volume': 22474300,
#   'change': 2,
#   'changePercent': 0.5172,
#   'vwap': 388.42},
#  {'symbol': 'MSFT',
#   'date': '2025-03-14',
#   'open': 379.78,
#   'high': 390.23,
#   'low': 379.51,
#   'close': 388.56,
#   'volume': 19952846,
#   'change': 8.79,
#   'changePercent': 2.31,
#   'vwap': 384.52},
#  {'symbol': 'MSFT',
#   'date': '2025-03-13',
#   'open': 383.16,
#   'high': 385.32,
#   'low': 377.45,
#   'close': 378.77,
#   'volume': 20473017,
#   'change': -4.38,
#   'changePercent': -1.15,
#   'vwap': 381.175},
#  {'symbol': 'MSFT',
#   'date': '2025-03-12',
#   'open': 382.95,
#   'high': 385.22,
#   'low': 378.95,
#   'close': 383.27,
#   'volume': 24253600,
#   'change': 0.32,
#   'changePercent': 0.08356182,
#   'vwap': 382.5975},
#  {'symbol': 'MSFT',
#   'date': '2025-03-11',
#   'open': 379,
#   'high': 386,
#   'low': 376.91,
#   'close': 380.45,
#   'volume': 30380200,
#   'change': 1.45,
#   'changePercent': 0.38259,
#   'vwap': 380.59},
#  {'symbol': 'MSFT',
#   'date': '2025-03-10',
#   'open': 385.84,
#   'high': 386.4,
#   'low': 377.22,
#   'close': 380.16,
#   'volume': 32840134,
#   'change': -5.68,
#   'changePercent': -1.47,
#   'vwap': 382.405},
#  {'symbol': 'MSFT',
#   'date': '2025-03-07',
#   'open': 392.32,
#   'high': 394.8,
#   'low': 385.54,
#   'close': 393.31,
#   'volume': 22034100,
#   'change': 0.99,
#   'changePercent': 0.25235,
#   'vwap': 391.4925},
#  {'symbol': 'MSFT',
#   'date': '2025-03-06',
#   'open': 394.28,
#   'high': 402.15,
#   'low': 392.68,
#   'close': 396.89,
#   'volume': 23304625,
#   'change': 2.61,
#   'changePercent': 0.66197,
#   'vwap': 396.5},
#  {'symbol': 'MSFT',
#   'date': '2025-03-05',
#   'open': 389.34,
#   'high': 401.67,
#   'low': 388.81,
#   'close': 401.02,
#   'volume': 23433132,
#   'change': 11.68,
#   'changePercent': 3,
#   'vwap': 395.21},
#  {'symbol': 'MSFT',
#   'date': '2025-03-04',
#   'open': 383.4,
#   'high': 392.58,
#   'low': 381,
#   'close': 388.61,
#   'volume': 29342923,
#   'change': 5.21,
#   'changePercent': 1.36,
#   'vwap': 386.3975},
#  {'symbol': 'MSFT',
#   'date': '2025-03-03',
#   'open': 398.82,
#   'high': 398.82,
#   'low': 386.16,
#   'close': 388.49,
#   'volume': 23007726,
#   'change': -10.33,
#   'changePercent': -2.59,
#   'vwap': 393.0725},
#  {'symbol': 'MSFT',
#   'date': '2025-02-28',
#   'open': 392.66,
#   'high': 397.63,
#   'low': 386.57,
#   'close': 396.99,
#   'volume': 32845700,
#   'change': 4.34,
#   'changePercent': 1.1,
#   'vwap': 393.4625},
#  {'symbol': 'MSFT',
#   'date': '2025-02-27',
#   'open': 401.27,
#   'high': 405.74,
#   'low': 392.17,
#   'close': 392.53,
#   'volume': 21127406,
#   'change': -8.74,
#   'changePercent': -2.18,
#   'vwap': 397.9275},
#  {'symbol': 'MSFT',
#   'date': '2025-02-26',
#   'open': 398.01,
#   'high': 403.6,
#   'low': 394.25,
#   'close': 399.73,
#   'volume': 19619000,
#   'change': 1.72,
#   'changePercent': 0.43215,
#   'vwap': 398.8975},
#  {'symbol': 'MSFT',
#   'date': '2025-02-25',
#   'open': 401.1,
#   'high': 401.92,
#   'low': 396.7,
#   'close': 397.9,
#   'volume': 29387402,
#   'change': -3.2,
#   'changePercent': -0.79781,
#   'vwap': 399.405},
#  {'symbol': 'MSFT',
#   'date': '2025-02-24',
#   'open': 408.51,
#   'high': 409.37,
#   'low': 399.32,
#   'close': 404,
#   'volume': 26443700,
#   'change': -4.51,
#   'changePercent': -1.1,
#   'vwap': 405.3},
#  {'symbol': 'MSFT',
#   'date': '2025-02-21',
#   'open': 417.34,
#   'high': 418.05,
#   'low': 407.89,
#   'close': 408.21,
#   'volume': 27524800,
#   'change': -9.12,
#   'changePercent': -2.19,
#   'vwap': 412.8725},
#  {'symbol': 'MSFT',
#   'date': '2025-02-20',
#   'open': 415.29,
#   'high': 419.31,
#   'low': 412.54,
#   'close': 416.13,
#   'volume': 23508728,
#   'change': 0.84,
#   'changePercent': 0.20227,
#   'vwap': 415.8175},
#  {'symbol': 'MSFT',
#   'date': '2025-02-19',
#   'open': 407.88,
#   'high': 415.49,
#   'low': 407.65,
#   'close': 414.77,
#   'volume': 24114200,
#   'change': 6.89,
#   'changePercent': 1.69,
#   'vwap': 411.4475},
#  {'symbol': 'MSFT',
#   'date': '2025-02-18',
#   'open': 408,
#   'high': 410.6,
#   'low': 406.5,
#   'close': 409.64,
#   'volume': 21423100,
#   'change': 1.64,
#   'changePercent': 0.40196,
#   'vwap': 408.685},
#  {'symbol': 'MSFT',
#   'date': '2025-02-14',
#   'open': 407.79,
#   'high': 408.91,
#   'low': 405.88,
#   'close': 408.43,
#   'volume': 22758500,
#   'change': 0.64,
#   'changePercent': 0.15694,
#   'vwap': 407.7525},
#  {'symbol': 'MSFT',
#   'date': '2025-02-13',
#   'open': 407,
#   'high': 411,
#   'low': 406.36,
#   'close': 410.54,
#   'volume': 23891731,
#   'change': 3.54,
#   'changePercent': 0.86978,
#   'vwap': 408.725},
#  {'symbol': 'MSFT',
#   'date': '2025-02-12',
#   'open': 407.21,
#   'high': 410.75,
#   'low': 404.37,
#   'close': 409.04,
#   'volume': 19121734,
#   'change': 1.83,
#   'changePercent': 0.4494,
#   'vwap': 407.8425},
#  {'symbol': 'MSFT',
#   'date': '2025-02-11',
#   'open': 409.64,
#   'high': 412.49,
#   'low': 409.3,
#   'close': 411.44,
#   'volume': 18140600,
#   'change': 1.8,
#   'changePercent': 0.43941,
#   'vwap': 410.7175},
#  {'symbol': 'MSFT',
#   'date': '2025-02-10',
#   'open': 413.71,
#   'high': 415.46,
#   'low': 410.92,
#   'close': 412.22,
#   'volume': 20817919,
#   'change': -1.49,
#   'changePercent': -0.36016,
#   'vwap': 413.0775},
#  {'symbol': 'MSFT',
#   'date': '2025-02-07',
#   'open': 416.48,
#   'high': 418.65,
#   'low': 408.1,
#   'close': 409.75,
#   'volume': 22886844,
#   'change': -6.73,
#   'changePercent': -1.62,
#   'vwap': 413.245},
#  {'symbol': 'MSFT',
#   'date': '2025-02-06',
#   'open': 414,
#   'high': 418.2,
#   'low': 414,
#   'close': 415.82,
#   'volume': 16309800,
#   'change': 1.82,
#   'changePercent': 0.43961,
#   'vwap': 415.505},
#  {'symbol': 'MSFT',
#   'date': '2025-02-05',
#   'open': 412.35,
#   'high': 413.83,
#   'low': 410.4,
#   'close': 413.29,
#   'volume': 16336188,
#   'change': 0.94,
#   'changePercent': 0.22796,
#   'vwap': 412.4675},
#  {'symbol': 'MSFT',
#   'date': '2025-02-04',
#   'open': 412.69,
#   'high': 413.92,
#   'low': 409.74,
#   'close': 412.37,
#   'volume': 20532100,
#   'change': -0.315,
#   'changePercent': -0.07754004,
#   'vwap': 412.18},
#  {'symbol': 'MSFT',
#   'date': '2025-02-03',
#   'open': 411.6,
#   'high': 415.41,
#   'low': 408.66,
#   'close': 410.92,
#   'volume': 25679149,
#   'change': -0.68,
#   'changePercent': -0.16521,
#   'vwap': 411.6475},
#  {'symbol': 'MSFT',
#   'date': '2025-01-31',
#   'open': 418.98,
#   'high': 420.69,
#   'low': 414.91,
#   'close': 415.06,
#   'volume': 34223388,
#   'change': -3.92,
#   'changePercent': -0.93561,
#   'vwap': 417.41},
#  {'symbol': 'MSFT',
#   'date': '2025-01-30',
#   'open': 418.77,
#   'high': 422.86,
#   'low': 413.16,
#   'close': 414.99,
#   'volume': 54586300,
#   'change': -3.78,
#   'changePercent': -0.90264,
#   'vwap': 417.445},
#  {'symbol': 'MSFT',
#   'date': '2025-01-29',
#   'open': 446.69,
#   'high': 446.88,
#   'low': 440.4,
#   'close': 442.33,
#   'volume': 23581400,
#   'change': -4.36,
#   'changePercent': -0.97607,
#   'vwap': 444.075},
#  {'symbol': 'MSFT',
#   'date': '2025-01-28',
#   'open': 434.6,
#   'high': 448.38,
#   'low': 431.38,
#   'close': 447.2,
#   'volume': 23491703,
#   'change': 12.6,
#   'changePercent': 2.9,
#   'vwap': 440.39},
#  {'symbol': 'MSFT',
#   'date': '2025-01-27',
#   'open': 424.01,
#   'high': 435.2,
#   'low': 423.5,
#   'close': 434.56,
#   'volume': 35647805,
#   'change': 10.55,
#   'changePercent': 2.49,
#   'vwap': 429.3175},
#  {'symbol': 'MSFT',
#   'date': '2025-01-24',
#   'open': 445.16,
#   'high': 446.65,
#   'low': 441.4,
#   'close': 444.06,
#   'volume': 15549500,
#   'change': -1.1,
#   'changePercent': -0.2471,
#   'vwap': 444.3175},
#  {'symbol': 'MSFT',
#   'date': '2025-01-23',
#   'open': 442,
#   'high': 446.75,
#   'low': 441.5,
#   'close': 446.71,
#   'volume': 18389300,
#   'change': 4.71,
#   'changePercent': 1.07,
#   'vwap': 444.24},
#  {'symbol': 'MSFT',
#   'date': '2025-01-22',
#   'open': 437.56,
#   'high': 447.27,
#   'low': 436,
#   'close': 446.2,
#   'volume': 27803811,
#   'change': 8.64,
#   'changePercent': 1.97,
#   'vwap': 441.7575},
#  {'symbol': 'MSFT',
#   'date': '2025-01-21',
#   'open': 430.2,
#   'high': 430.9,
#   'low': 425.6,
#   'close': 428.5,
#   'volume': 26085703,
#   'change': -1.7,
#   'changePercent': -0.39517,
#   'vwap': 428.8},
#  {'symbol': 'MSFT',
#   'date': '2025-01-17',
#   'open': 434.09,
#   'high': 434.48,
#   'low': 428.17,
#   'close': 429.03,
#   'volume': 26197507,
#   'change': -5.06,
#   'changePercent': -1.17,
#   'vwap': 431.4425},
#  {'symbol': 'MSFT',
#   'date': '2025-01-16',
#   'open': 428.7,
#   'high': 429.49,
#   'low': 424.39,
#   'close': 424.58,
#   'volume': 15300023,
#   'change': -4.12,
#   'changePercent': -0.96105,
#   'vwap': 426.79},
#  {'symbol': 'MSFT',
#   'date': '2025-01-15',
#   'open': 419.13,
#   'high': 428.15,
#   'low': 418.27,
#   'close': 426.31,
#   'volume': 19637838,
#   'change': 7.18,
#   'changePercent': 1.71,
#   'vwap': 422.965},
#  {'symbol': 'MSFT',
#   'date': '2025-01-14',
#   'open': 417.81,
#   'high': 419.74,
#   'low': 410.72,
#   'close': 415.67,
#   'volume': 16935900,
#   'change': -2.14,
#   'changePercent': -0.51219,
#   'vwap': 415.985},
#  {'symbol': 'MSFT',
#   'date': '2025-01-13',
#   'open': 415.24,
#   'high': 418.5,
#   'low': 412.29,
#   'close': 417.19,
#   'volume': 17604800,
#   'change': 1.95,
#   'changePercent': 0.46961,
#   'vwap': 415.805},
#  {'symbol': 'MSFT',
#   'date': '2025-01-10',
#   'open': 424.63,
#   'high': 424.71,
#   'low': 415.02,
#   'close': 418.95,
#   'volume': 20201132,
#   'change': -5.68,
#   'changePercent': -1.34,
#   'vwap': 420.8275},
#  {'symbol': 'MSFT',
#   'date': '2025-01-08',
#   'open': 423.46,
#   'high': 426.97,
#   'low': 421.54,
#   'close': 424.56,
#   'volume': 15054600,
#   'change': 1.1,
#   'changePercent': 0.25976,
#   'vwap': 424.1325},
#  {'symbol': 'MSFT',
#   'date': '2025-01-07',
#   'open': 429,
#   'high': 430.65,
#   'low': 420.8,
#   'close': 422.37,
#   'volume': 18139100,
#   'change': -6.63,
#   'changePercent': -1.55,
#   'vwap': 425.705},
#  {'symbol': 'MSFT',
#   'date': '2025-01-06',
#   'open': 428,
#   'high': 434.32,
#   'low': 425.48,
#   'close': 427.85,
#   'volume': 20573648,
#   'change': -0.15,
#   'changePercent': -0.03504673,
#   'vwap': 428.9125},
#  {'symbol': 'MSFT',
#   'date': '2025-01-03',
#   'open': 421.08,
#   'high': 424.03,
#   'low': 419.54,
#   'close': 423.35,
#   'volume': 16662943,
#   'change': 2.27,
#   'changePercent': 0.53909,
#   'vwap': 422},
#  {'symbol': 'MSFT',
#   'date': '2025-01-02',
#   'open': 425.53,
#   'high': 426.07,
#   'low': 414.85,
#   'close': 418.58,
#   'volume': 16896500,
#   'change': -6.95,
#   'changePercent': -1.63,
#   'vwap': 421.2575},
#  {'symbol': 'MSFT',
#   'date': '2024-12-31',
#   'open': 426.1,
#   'high': 426.73,
#   'low': 420.66,
#   'close': 421.5,
#   'volume': 13246509,
#   'change': -4.6,
#   'changePercent': -1.08,
#   'vwap': 423.7475},
#  {'symbol': 'MSFT',
#   'date': '2024-12-30',
#   'open': 426.06,
#   'high': 427.55,
#   'low': 421.9,
#   'close': 424.83,
#   'volume': 13158703,
#   'change': -1.23,
#   'changePercent': -0.28869,
#   'vwap': 425.085},
#  {'symbol': 'MSFT',
#   'date': '2024-12-27',
#   'open': 434.6,
#   'high': 435.22,
#   'low': 426.35,
#   'close': 430.53,
#   'volume': 18117713,
#   'change': -4.07,
#   'changePercent': -0.93649,
#   'vwap': 431.675},
#  {'symbol': 'MSFT',
#   'date': '2024-12-26',
#   'open': 439.08,
#   'high': 440.94,
#   'low': 436.63,
#   'close': 438.11,
#   'volume': 8199927,
#   'change': -0.97,
#   'changePercent': -0.22092,
#   'vwap': 438.69},
#  {'symbol': 'MSFT',
#   'date': '2024-12-24',
#   'open': 434.65,
#   'high': 439.6,
#   'low': 434.19,
#   'close': 439.33,
#   'volume': 7164543,
#   'change': 4.68,
#   'changePercent': 1.08,
#   'vwap': 436.9425},
#  {'symbol': 'MSFT',
#   'date': '2024-12-23',
#   'open': 436.74,
#   'high': 437.65,
#   'low': 432.83,
#   'close': 435.25,
#   'volume': 19152519,
#   'change': -1.49,
#   'changePercent': -0.34116,
#   'vwap': 435.6175},
#  {'symbol': 'MSFT',
# ...
#   'date': '2022-03-31',
#   'open': 313.9,
#   'high': 315.14,
#   'low': 307.89,
#   'close': 308.31,
#   'volume': 33422100,
#   'change': -5.59,
#   'changePercent': -1.78,
#   'vwap': 311.31},
#  {'symbol': 'MSFT',
#   'date': '2022-03-30',
#   'open': 313.76,
#   'high': 315.95,
#   'low': 311.58,
#   'close': 313.86,
#   'volume': 28163600,
#   'change': 0.1,
#   'changePercent': 0.03187149,
#   'vwap': 313.7875},
#  {'symbol': 'MSFT',
#   'date': '2022-03-29',
#   'open': 313.91,
#   'high': 315.82,
#   'low': 309.05,
#   'close': 315.41,
#   'volume': 30393403,
#   'change': 1.5,
#   'changePercent': 0.47784,
#   'vwap': 313.5475},
#  {'symbol': 'MSFT',
#   'date': '2022-03-28',
#   'open': 304.33,
#   'high': 310.8,
#   'low': 304.33,
#   'close': 310.7,
#   'volume': 29578200,
#   'change': 6.37,
#   'changePercent': 2.09,
#   'vwap': 307.54},
#  {'symbol': 'MSFT',
#   'date': '2022-03-25',
#   'open': 305.23,
#   'high': 305.5,
#   'low': 299.29,
#   'close': 303.68,
#   'volume': 22566500,
#   'change': -1.55,
#   'changePercent': -0.50781,
#   'vwap': 303.425},
#  {'symbol': 'MSFT',
#   'date': '2022-03-24',
#   'open': 299.14,
#   'high': 304.2,
#   'low': 298.32,
#   'close': 304.1,
#   'volume': 24484500,
#   'change': 4.96,
#   'changePercent': 1.66,
#   'vwap': 301.44},
#  {'symbol': 'MSFT',
#   'date': '2022-03-23',
#   'open': 300.51,
#   'high': 303.23,
#   'low': 297.72,
#   'close': 299.49,
#   'volume': 25715400,
#   'change': -1.02,
#   'changePercent': -0.33942,
#   'vwap': 300.2375},
#  {'symbol': 'MSFT',
#   'date': '2022-03-22',
#   'open': 299.8,
#   'high': 305,
#   'low': 298.77,
#   'close': 304.06,
#   'volume': 27599700,
#   'change': 4.26,
#   'changePercent': 1.42,
#   'vwap': 301.9075},
#  {'symbol': 'MSFT',
#   'date': '2022-03-21',
#   'open': 298.89,
#   'high': 300.14,
#   'low': 294.9,
#   'close': 299.16,
#   'volume': 28351245,
#   'change': 0.27,
#   'changePercent': 0.09033424,
#   'vwap': 298.2725},
#  {'symbol': 'MSFT',
#   'date': '2022-03-18',
#   'open': 295.37,
#   'high': 301,
#   'low': 292.73,
#   'close': 300.43,
#   'volume': 43390625,
#   'change': 5.06,
#   'changePercent': 1.71,
#   'vwap': 297.3825},
#  {'symbol': 'MSFT',
#   'date': '2022-03-17',
#   'open': 293.29,
#   'high': 295.61,
#   'low': 289.37,
#   'close': 295.22,
#   'volume': 30816633,
#   'change': 1.93,
#   'changePercent': 0.65805,
#   'vwap': 293.3725},
#  {'symbol': 'MSFT',
#   'date': '2022-03-16',
#   'open': 289.11,
#   'high': 294.57,
#   'low': 283.2,
#   'close': 294.39,
#   'volume': 37826329,
#   'change': 5.28,
#   'changePercent': 1.83,
#   'vwap': 290.3175},
#  {'symbol': 'MSFT',
#   'date': '2022-03-15',
#   'open': 280.35,
#   'high': 287.82,
#   'low': 278.73,
#   'close': 287.15,
#   'volume': 34245100,
#   'change': 6.8,
#   'changePercent': 2.43,
#   'vwap': 283.5125},
#  {'symbol': 'MSFT',
#   'date': '2022-03-14',
#   'open': 280.34,
#   'high': 285.4,
#   'low': 275.82,
#   'close': 276.44,
#   'volume': 30660747,
#   'change': -3.9,
#   'changePercent': -1.39,
#   'vwap': 279.5},
#  {'symbol': 'MSFT',
#   'date': '2022-03-11',
#   'open': 287.96,
#   'high': 289.51,
#   'low': 279.43,
#   'close': 280.07,
#   'volume': 27209330,
#   'change': -7.89,
#   'changePercent': -2.74,
#   'vwap': 284.2425},
#  {'symbol': 'MSFT',
#   'date': '2022-03-10',
#   'open': 283.02,
#   'high': 286.6,
#   'low': 280.58,
#   'close': 285.59,
#   'volume': 30628012,
#   'change': 2.57,
#   'changePercent': 0.90806,
#   'vwap': 283.9475},
#  {'symbol': 'MSFT',
#   'date': '2022-03-09',
#   'open': 283.44,
#   'high': 289.6,
#   'low': 280.78,
#   'close': 288.5,
#   'volume': 35204500,
#   'change': 5.06,
#   'changePercent': 1.79,
#   'vwap': 285.58},
#  {'symbol': 'MSFT',
#   'date': '2022-03-08',
#   'open': 277.8,
#   'high': 283.96,
#   'low': 270,
#   'close': 275.85,
#   'volume': 48159500,
#   'change': -1.95,
#   'changePercent': -0.70194,
#   'vwap': 276.9025},
#  {'symbol': 'MSFT',
#   'date': '2022-03-07',
#   'open': 288.53,
#   'high': 289.69,
#   'low': 278.53,
#   'close': 278.91,
#   'volume': 43157200,
#   'change': -9.62,
#   'changePercent': -3.33,
#   'vwap': 283.915},
#  {'symbol': 'MSFT',
#   'date': '2022-03-04',
#   'open': 294.29,
#   'high': 295.66,
#   'low': 287.17,
#   'close': 289.86,
#   'volume': 32369655,
#   'change': -4.43,
#   'changePercent': -1.51,
#   'vwap': 291.745},
#  {'symbol': 'MSFT',
#   'date': '2022-03-03',
#   'open': 302.89,
#   'high': 303.13,
#   'low': 294.05,
#   'close': 295.92,
#   'volume': 27314500,
#   'change': -6.97,
#   'changePercent': -2.3,
#   'vwap': 298.9975},
#  {'symbol': 'MSFT',
#   'date': '2022-03-02',
#   'open': 295.36,
#   'high': 301.47,
#   'low': 293.7,
#   'close': 300.19,
#   'volume': 31873007,
#   'change': 4.83,
#   'changePercent': 1.64,
#   'vwap': 297.68},
#  {'symbol': 'MSFT',
#   'date': '2022-03-01',
#   'open': 296.4,
#   'high': 299.97,
#   'low': 292.15,
#   'close': 294.95,
#   'volume': 31217800,
#   'change': -1.45,
#   'changePercent': -0.4892,
#   'vwap': 295.8675},
#  {'symbol': 'MSFT',
#   'date': '2022-02-28',
#   'open': 294.31,
#   'high': 299.14,
#   'low': 293,
#   'close': 298.79,
#   'volume': 34627500,
#   'change': 4.48,
#   'changePercent': 1.52,
#   'vwap': 296.31},
#  {'symbol': 'MSFT',
#   'date': '2022-02-25',
#   'open': 295.14,
#   'high': 297.63,
#   'low': 291.65,
#   'close': 297.31,
#   'volume': 32546721,
#   'change': 2.17,
#   'changePercent': 0.73524,
#   'vwap': 295.4325},
#  {'symbol': 'MSFT',
#   'date': '2022-02-24',
#   'open': 272.51,
#   'high': 295.16,
#   'low': 271.52,
#   'close': 294.59,
#   'volume': 56989700,
#   'change': 22.08,
#   'changePercent': 8.1,
#   'vwap': 283.445},
#  {'symbol': 'MSFT',
#   'date': '2022-02-23',
#   'open': 290.18,
#   'high': 291.7,
#   'low': 280.1,
#   'close': 280.27,
#   'volume': 37811200,
#   'change': -9.91,
#   'changePercent': -3.42,
#   'vwap': 285.5625},
#  {'symbol': 'MSFT',
#   'date': '2022-02-22',
#   'open': 285,
#   'high': 291.54,
#   'low': 284.5,
#   'close': 287.72,
#   'volume': 41736117,
#   'change': 2.72,
#   'changePercent': 0.95439,
#   'vwap': 287.19},
#  {'symbol': 'MSFT',
#   'date': '2022-02-18',
#   'open': 293.05,
#   'high': 293.86,
#   'low': 286.31,
#   'close': 287.93,
#   'volume': 34264008,
#   'change': -5.12,
#   'changePercent': -1.75,
#   'vwap': 290.2875},
#  {'symbol': 'MSFT',
#   'date': '2022-02-17',
#   'open': 296.36,
#   'high': 296.8,
#   'low': 290,
#   'close': 290.73,
#   'volume': 32461600,
#   'change': -5.63,
#   'changePercent': -1.9,
#   'vwap': 293.4725},
#  {'symbol': 'MSFT',
#   'date': '2022-02-16',
#   'open': 298.37,
#   'high': 300.87,
#   'low': 293.68,
#   'close': 299.5,
#   'volume': 29982121,
#   'change': 1.13,
#   'changePercent': 0.37872,
#   'vwap': 298.105},
#  {'symbol': 'MSFT',
#   'date': '2022-02-15',
#   'open': 300.01,
#   'high': 300.8,
#   'low': 297.02,
#   'close': 300.47,
#   'volume': 27379488,
#   'change': 0.462,
#   'changePercent': 0.15333,
#   'vwap': 299.575},
#  {'symbol': 'MSFT',
#   'date': '2022-02-14',
#   'open': 293.77,
#   'high': 296.76,
#   'low': 291.35,
#   'close': 295,
#   'volume': 36359500,
#   'change': 1.23,
#   'changePercent': 0.41869,
#   'vwap': 294.22},
#  {'symbol': 'MSFT',
#   'date': '2022-02-11',
#   'open': 303.19,
#   'high': 304.29,
#   'low': 294.22,
#   'close': 295.04,
#   'volume': 39175620,
#   'change': -8.15,
#   'changePercent': -2.69,
#   'vwap': 299.185},
#  {'symbol': 'MSFT',
#   'date': '2022-02-10',
#   'open': 304.04,
#   'high': 309.12,
#   'low': 300.7,
#   'close': 302.38,
#   'volume': 45386200,
#   'change': -1.66,
#   'changePercent': -0.54598,
#   'vwap': 304.06},
#  {'symbol': 'MSFT',
#   'date': '2022-02-09',
#   'open': 309.87,
#   'high': 311.93,
#   'low': 307.39,
#   'close': 311.21,
#   'volume': 31284700,
#   'change': 1.34,
#   'changePercent': 0.43244,
#   'vwap': 310.1},
#  {'symbol': 'MSFT',
#   'date': '2022-02-08',
#   'open': 301.25,
#   'high': 305.56,
#   'low': 299.95,
#   'close': 304.56,
#   'volume': 32421200,
#   'change': 3.31,
#   'changePercent': 1.1,
#   'vwap': 302.83},
#  {'symbol': 'MSFT',
#   'date': '2022-02-07',
#   'open': 306.17,
#   'high': 307.84,
#   'low': 299.9,
#   'close': 300.95,
#   'volume': 28533300,
#   'change': -5.22,
#   'changePercent': -1.7,
#   'vwap': 303.715},
#  {'symbol': 'MSFT',
#   'date': '2022-02-04',
#   'open': 300.21,
#   'high': 308.8,
#   'low': 299.97,
#   'close': 305.94,
#   'volume': 35096500,
#   'change': 5.73,
#   'changePercent': 1.91,
#   'vwap': 303.73},
#  {'symbol': 'MSFT',
#   'date': '2022-02-03',
#   'open': 309.49,
#   'high': 311.23,
#   'low': 299.96,
#   'close': 301.25,
#   'volume': 43730000,
#   'change': -8.24,
#   'changePercent': -2.66,
#   'vwap': 305.4825},
#  {'symbol': 'MSFT',
#   'date': '2022-02-02',
#   'open': 309.63,
#   'high': 315.12,
#   'low': 308.88,
#   'close': 313.46,
#   'volume': 36636000,
#   'change': 3.83,
#   'changePercent': 1.24,
#   'vwap': 311.7725},
#  {'symbol': 'MSFT',
#   'date': '2022-02-01',
#   'open': 310.41,
#   'high': 310.63,
#   'low': 305.13,
#   'close': 308.76,
#   'volume': 40950400,
#   'change': -1.65,
#   'changePercent': -0.53156,
#   'vwap': 308.7325},
#  {'symbol': 'MSFT',
#   'date': '2022-01-31',
#   'open': 308.95,
#   'high': 312.38,
#   'low': 306.37,
#   'close': 310.98,
#   'volume': 46444536,
#   'change': 2.03,
#   'changePercent': 0.65706,
#   'vwap': 309.67},
#  {'symbol': 'MSFT',
#   'date': '2022-01-28',
#   'open': 300.23,
#   'high': 308.48,
#   'low': 294.45,
#   'close': 308.26,
#   'volume': 49743700,
#   'change': 8.03,
#   'changePercent': 2.67,
#   'vwap': 302.855},
#  {'symbol': 'MSFT',
#   'date': '2022-01-27',
#   'open': 302.66,
#   'high': 307.3,
#   'low': 297.93,
#   'close': 299.84,
#   'volume': 53481317,
#   'change': -2.82,
#   'changePercent': -0.93174,
#   'vwap': 301.9325},
#  {'symbol': 'MSFT',
#   'date': '2022-01-26',
#   'open': 307.99,
#   'high': 308.5,
#   'low': 293.03,
#   'close': 296.71,
#   'volume': 90428900,
#   'change': -11.28,
#   'changePercent': -3.66,
#   'vwap': 301.5575},
#  {'symbol': 'MSFT',
#   'date': '2022-01-25',
#   'open': 291.52,
#   'high': 294.99,
#   'low': 285.17,
#   'close': 288.49,
#   'volume': 72848638,
#   'change': -3.03,
#   'changePercent': -1.04,
#   'vwap': 290.0425},
#  {'symbol': 'MSFT',
#   'date': '2022-01-24',
#   'open': 292.2,
#   'high': 297.11,
#   'low': 276.05,
#   'close': 296.37,
#   'volume': 86035393,
#   'change': 4.17,
#   'changePercent': 1.43,
#   'vwap': 290.4325},
#  {'symbol': 'MSFT',
#   'date': '2022-01-21',
#   'open': 302.69,
#   'high': 304.11,
#   'low': 295.61,
#   'close': 296.03,
#   'volume': 57984403,
#   'change': -6.66,
#   'changePercent': -2.2,
#   'vwap': 299.61},
#  {'symbol': 'MSFT',
#   'date': '2022-01-20',
#   'open': 309.07,
#   'high': 311.65,
#   'low': 301.14,
#   'close': 301.6,
#   'volume': 35380700,
#   'change': -7.47,
#   'changePercent': -2.42,
#   'vwap': 305.865},
#  {'symbol': 'MSFT',
#   'date': '2022-01-19',
#   'open': 306.29,
#   'high': 313.91,
#   'low': 302.7,
#   'close': 303.33,
#   'volume': 45933900,
#   'change': -2.96,
#   'changePercent': -0.9664,
#   'vwap': 306.5575},
#  {'symbol': 'MSFT',
#   'date': '2022-01-18',
#   'open': 304.07,
#   'high': 309.8,
#   'low': 301.74,
#   'close': 302.65,
#   'volume': 42434112,
#   'change': -1.42,
#   'changePercent': -0.467,
#   'vwap': 304.565},
#  {'symbol': 'MSFT',
#   'date': '2022-01-14',
#   'open': 304.25,
#   'high': 310.82,
#   'low': 303.75,
#   'close': 310.2,
#   'volume': 39846414,
#   'change': 5.95,
#   'changePercent': 1.96,
#   'vwap': 307.255},
#  {'symbol': 'MSFT',
#   'date': '2022-01-13',
#   'open': 320.47,
#   'high': 320.88,
#   'low': 304,
#   'close': 304.8,
#   'volume': 45366000,
#   'change': -15.67,
#   'changePercent': -4.89,
#   'vwap': 312.5375},
#  {'symbol': 'MSFT',
#   'date': '2022-01-12',
#   'open': 319.67,
#   'high': 323.41,
#   'low': 317.08,
#   'close': 318.27,
#   'volume': 34372217,
#   'change': -1.4,
#   'changePercent': -0.43795,
#   'vwap': 319.6075},
#  {'symbol': 'MSFT',
#   'date': '2022-01-11',
#   'open': 313.38,
#   'high': 316.61,
#   'low': 309.89,
#   'close': 314.98,
#   'volume': 29386800,
#   'change': 1.6,
#   'changePercent': 0.51056,
#   'vwap': 313.715},
#  {'symbol': 'MSFT',
#   'date': '2022-01-10',
#   'open': 309.49,
#   'high': 314.72,
#   'low': 304.69,
#   'close': 314.27,
#   'volume': 44289500,
#   'change': 4.78,
#   'changePercent': 1.54,
#   'vwap': 310.7925},
#  {'symbol': 'MSFT',
#   'date': '2022-01-07',
#   'open': 314.15,
#   'high': 316.5,
#   'low': 310.09,
#   'close': 314.04,
#   'volume': 32720018,
#   'change': -0.11,
#   'changePercent': -0.03501512,
#   'vwap': 313.695},
#  {'symbol': 'MSFT',
#   'date': '2022-01-06',
#   'open': 313.15,
#   'high': 318.7,
#   'low': 311.49,
#   'close': 313.88,
#   'volume': 39646148,
#   'change': 0.73,
#   'changePercent': 0.23312,
#   'vwap': 314.305},
#  {'symbol': 'MSFT',
#   'date': '2022-01-05',
#   'open': 325.86,
#   'high': 326.07,
#   'low': 315.98,
#   'close': 316.38,
#   'volume': 40054327,
#   'change': -9.48,
#   'changePercent': -2.91,
#   'vwap': 321.0725},
#  {'symbol': 'MSFT',
#   'date': '2022-01-04',
#   'open': 334.83,
#   'high': 335.2,
#   'low': 326.12,
#   'close': 329.01,
#   'volume': 32674306,
#   'change': -5.82,
#   'changePercent': -1.74,
#   'vwap': 331.29},
#  {'symbol': 'MSFT',
#   'date': '2022-01-03',
#   'open': 335.35,
#   'high': 338,
#   'low': 329.78,
#   'close': 334.75,
#   'volume': 28918013,
#   'change': -0.6,
#   'changePercent': -0.17892,
#   'vwap': 334.47},
#  {'symbol': 'MSFT',
#   'date': '2021-12-31',
#   'open': 338.51,
#   'high': 339.36,
#   'low': 335.85,
#   'close': 336.32,
#   'volume': 18000800,
#   'change': -2.19,
#   'changePercent': -0.64695,
#   'vwap': 337.51},
#  {'symbol': 'MSFT',
#   'date': '2021-12-30',
#   'open': 341.91,
#   'high': 343.13,
#   'low': 338.82,
#   'close': 339.32,
#   'volume': 15994500,
#   'change': -2.59,
#   'changePercent': -0.75751,
#   'vwap': 340.795},
#  {'symbol': 'MSFT',
#   'date': '2021-12-29',
#   'open': 341.3,
#   'high': 344.3,
#   'low': 339.68,
#   'close': 341.95,
#   'volume': 15042000,
#   'change': 0.65,
#   'changePercent': 0.19045,
#   'vwap': 341.8075},
#  {'symbol': 'MSFT',
#   'date': '2021-12-28',
#   'open': 343.15,
#   'high': 343.81,
#   'low': 340.32,
#   'close': 341.25,
#   'volume': 15661500,
#   'change': -1.9,
#   'changePercent': -0.55369,
#   'vwap': 342.1325},
#  {'symbol': 'MSFT',
#   'date': '2021-12-27',
#   'open': 335.46,
#   'high': 342.48,
#   'low': 335.43,
#   'close': 342.45,
#   'volume': 19947029,
#   'change': 6.99,
#   'changePercent': 2.08,
#   'vwap': 338.955},
#  {'symbol': 'MSFT',
#   'date': '2021-12-23',
#   'open': 332.75,
#   'high': 336.39,
#   'low': 332.73,
#   'close': 334.69,
#   'volume': 19617848,
#   'change': 1.94,
#   'changePercent': 0.58302,
#   'vwap': 334.14},
#  {'symbol': 'MSFT',
#   'date': '2021-12-22',
#   'open': 328.3,
#   'high': 333.61,
#   'low': 325.75,
#   'close': 333.2,
#   'volume': 24831500,
#   'change': 4.9,
#   'changePercent': 1.49,
#   'vwap': 330.215},
#  {'symbol': 'MSFT',
#   'date': '2021-12-21',
#   'open': 323.29,
#   'high': 327.73,
#   'low': 319.8,
#   'close': 327.29,
#   'volume': 24740600,
#   'change': 4,
#   'changePercent': 1.24,
#   'vwap': 324.5275},
#  {'symbol': 'MSFT',
#   'date': '2021-12-20',
#   'open': 320.05,
#   'high': 322.8,
#   'low': 317.57,
#   'close': 319.91,
#   'volume': 28326532,
#   'change': -0.14,
#   'changePercent': -0.04374317,
#   'vwap': 320.0825},
#  {'symbol': 'MSFT',
#   'date': '2021-12-17',
#   'open': 320.88,
#   'high': 324.92,
#   'low': 317.25,
#   'close': 323.8,
#   'volume': 47983713,
#   'change': 2.92,
#   'changePercent': 0.91,
#   'vwap': 321.7125},
#  {'symbol': 'MSFT',
#   'date': '2021-12-16',
#   'open': 335.71,
#   'high': 336.76,
#   'low': 323.02,
#   'close': 324.9,
#   'volume': 35034831,
#   'change': -10.81,
#   'changePercent': -3.22,
#   'vwap': 330.0975},
#  {'symbol': 'MSFT',
#   'date': '2021-12-15',
#   'open': 328.61,
#   'high': 335.19,
#   'low': 324.5,
#   'close': 334.65,
#   'volume': 35381122,
#   'change': 6.04,
#   'changePercent': 1.84,
#   'vwap': 330.7375},
#  {'symbol': 'MSFT',
#   'date': '2021-12-14',
#   'open': 333.22,
#   'high': 334.64,
#   'low': 324.11,
#   'close': 328.34,
#   'volume': 44438700,
#   'change': -4.88,
#   'changePercent': -1.46,
#   'vwap': 330.0775},
#  {'symbol': 'MSFT',
#   'date': '2021-12-13',
#   'open': 340.68,
#   'high': 343.79,
#   'low': 339.08,
#   'close': 339.4,
#   'volume': 28899431,
#   'change': -1.28,
#   'changePercent': -0.37572,
#   'vwap': 340.7375},
#  {'symbol': 'MSFT',
#   'date': '2021-12-10',
#   'open': 334.98,
#   'high': 343,
#   'low': 334.79,
#   'close': 342.54,
#   'volume': 38095700,
#   'change': 7.56,
#   'changePercent': 2.26,
#   'vwap': 338.8275},
#  {'symbol': 'MSFT',
#   'date': '2021-12-09',
#   'open': 334.41,
#   'high': 336.49,
#   'low': 332.12,
#   'close': 333.1,
#   'volume': 22214200,
#   'change': -1.31,
#   'changePercent': -0.39173,
#   'vwap': 334.03},
#  {'symbol': 'MSFT',
#   'date': '2021-12-08',
#   'open': 335.31,
#   'high': 335.5,
#   'low': 330.8,
#   'close': 334.97,
#   'volume': 24761000,
#   'change': -0.34,
#   'changePercent': -0.1014,
#   'vwap': 334.145},
#  ...]

# %%
@mcp.tool()
async def earnings_call_transcript(symbol: str, year: int, quarter: int, limit: Optional[int] = None) -> Any:
    """Earnings Transcript API — full text of a company’s earnings call.

    Use this when:
      • You need the prepared remarks + Q&A text to analyze tone/strategy/risks.
      • You’re extracting quotes or doing NLP on management commentary.

    Don’t use when:
      • You want numeric KPIs (use statements/ratios).
      • You need 10-K/10-Q filings (use an SEC filings tool).

    Endpoint: `/stable/earning-call-transcript`

    What it provides:
      • **Full Transcript Text**: `content` covering prepared remarks + Q&A.
      • **Context**: `date`, `year`, `period` (e.g., Q3), and `symbol`.

    Example use:
      • Analyze management’s tone, strategy, and risk disclosures beyond numeric filings.

    Args:
      symbol: Ticker symbol (e.g., "AAPL").
      year: Fiscal year (e.g., 2020).
      quarter: Fiscal quarter number `1..4`.
      limit: Optional number of records (API may support a single record; kept for parity).

    Returns:
      A list containing one or more transcript objects with `content` and metadata.
    """
    params: Dict[str, Any] = {"symbol": symbol, "year": year, "quarter": quarter}
    if limit is not None:
        params["limit"] = limit
    return await fmp_api_request("earning-call-transcript", params)

# %%
await earnings_call_transcript("NVDA", 2025, "3")
# Out:
# [{'symbol': 'NVDA',
#   'period': 'Q3',
#   'year': 2025,
#   'date': '2024-11-20',
#   'content': "Operator: Good afternoon. My name is Joel, and I'll be your conference operator today. At this time, I would like to welcome everyone to NVIDIA's Third Quarter Earnings Call. All lines have been placed on mute to prevent any background noise. After the speakers' remarks, there will be a question-and-answer session. [Operator Instructions] Thank you. Stewart Stecker, you may begin your conference.\nStewart Stecker: Thank you. Good afternoon, everyone, and welcome to NVIDIA's conference call for the third quarter of fiscal 2025. With me today from NVIDIA are Jensen Huang, President and Chief Executive Officer; and Colette Kress, Executive Vice President and Chief Financial Officer. I'd like to remind you that our call is being webcast live on NVIDIA's Investor Relations website. The webcast will be available for replay until the conference call to discuss our financial results for the fourth quarter of fiscal 2025. The content of today's call is NVIDIA's property. It can't be reproduced or transcribed without our prior written consent. During this call, we may make forward-looking statements based on current expectations. These are subject to a number of significant risks and uncertainties and our actual results may differ materially. For a discussion of factors that could affect our future financial results and business, please refer to the disclosure in today's earnings release, our most recent Forms 10-K and 10-Q, and the reports that we may file on Form 8-K with the Securities and Exchange Commission. All our statements are made as of today, November 20, 2024, based on information currently available to us. Except as required by law, we assume no obligation to update any such statements. During this call, we will discuss non-GAAP financial measures. You can find a reconciliation of these non-GAAP financial measures to GAAP financial measures in our CFO commentary, which is posted on our website. With that, let me turn the call over to Colette.\nColette Kress: Thank you, Stewart. Q3 was another record quarter. We continued to deliver incredible growth. Revenue of $35.1 billion was up 17% sequentially and up 94% year-on-year and, well above our outlook of $32.5 billion. All market platforms posted strong sequential and year-over-year growth, fueled by the adoption of NVIDIA accelerated computing and AI. Starting with Data Center, another record was achieved in Data Center. Revenue of $30.8 billion, up 17% sequential and up 112% year-on-year. NVIDIA Hopper demand is exceptional and sequentially, NVIDIA H200 sales increased significantly to double-digit billions, the fastest product ramp in our company's history. The H200 delivers up to 2 times faster inference performance and up to 50% improved TCO. Cloud service providers were approximately half of our data center sales with revenue increasing more than 2 times year-on-year. CSPs deployed NVIDIA H200 infrastructure and high-speed networking with installations scaling to tens of thousands of GPUs to grow their business and serve rapidly rising demand for AI training and inference workloads. NVIDIA H200-powered cloud instances are now available from AWS, CoreWeave, and Microsoft Azure with Google Cloud and OCI coming soon. Alongside significant growth from our large CSPs, NVIDIA GPU regional cloud revenue jumped 2 times year-on-year as North America, EMEA, and Asia Pacific regions ramped NVIDIA cloud instances and sovereign cloud buildout. Consumer Internet revenue more than doubled year-on-year as companies scaled their NVIDIA Hopper infrastructure to support next-generation AI models, training, multimodal and agentic AI, deep learning recommender engines, and generative AI inference and content creation workloads. NVIDIA's Ampere and Hopper infrastructures are fueling inference revenue growth for customers. NVIDIA is the largest inference platform in the world. Our large installed base and rich software ecosystem encourage developers to optimize for NVIDIA and de ...

# %%
@mcp.tool()
async def economic_indicators(name: str, date_from: Optional[str] = None, date_to: Optional[str] = None) -> Any:
    """Economic Indicators API — real-time & historical macro indicators.

    Use this when:
      • You need macro time series like GDP, CPI, unemployment, or industrial production.
      • You’re correlating macro with sector/stock performance.

    Don’t use when:
      • You need event timing/releases (use economic_calendar).
      • You need equity fundamentals (use company/statement tools).

    Endpoint: `/stable/economic-indicators`

    What it provides:
      • **Macro Series**: Values for indicators like `GDP`, `unemploymentRate`, `CPI`,
        `inflationRate`, `industrialProductionTotalIndex`, etc.
      • **Windowed Queries**: Restrict by `from` / `to` date (max 90-day range per request).

    Example use:
      • Monitor GDP changes over time to align portfolio positioning with macro cycles.

    Args:
      name:   Indicator name (pick one of GDP,realGDP,nominalPotentialGDP,realGDPPerCapita,federalFunds,CPI,
              inflationRate,inflation,retailSales,consumerSentiment,durableGoods,unemploymentRate,
              totalNonfarmPayroll,initialClaims,industrialProductionTotalIndex,
              newPrivatelyOwnedHousingUnitsStartedTotalUnits,totalVehicleSales,
              retailMoneyFunds,smoothedUSRecessionProbabilities,3MonthOr90DayRatesAndYieldsCertificatesOfDeposit,
              commercialBankInterestRateOnCreditCardPlansAllAccounts,30YearFixedRateMortgageAverage,
              15YearFixedRateMortgageAverage)
              
      date_from: Optional start date `YYYY-MM-DD` (<= 90-day span when combined with `to`).
      date_to: Optional end date `YYYY-MM-DD`.


    Returns:
      A list of {name, date, value} tuples.
    """
    params: Dict[str, Any] = {"name": name}
    if date_from:
        params["from"] = date_from
    if date_to:
        params["to"] = date_to
    return await fmp_api_request("economic-indicators", params)

# %%
await economic_indicators("CPI")
# Out:
# [{'name': 'CPI', 'date': '2025-09-01', 'value': 324.368},
#  {'name': 'CPI', 'date': '2025-08-01', 'value': 323.364},
#  {'name': 'CPI', 'date': '2025-07-01', 'value': 322.132},
#  {'name': 'CPI', 'date': '2025-06-01', 'value': 321.5},
#  {'name': 'CPI', 'date': '2025-05-01', 'value': 320.58},
#  {'name': 'CPI', 'date': '2025-04-01', 'value': 320.321},
#  {'name': 'CPI', 'date': '2025-03-01', 'value': 319.615},
#  {'name': 'CPI', 'date': '2025-02-01', 'value': 319.775},
#  {'name': 'CPI', 'date': '2025-01-01', 'value': 319.086}]

# %%
await economic_indicators("unemploymentRate")
# Out:
# [{'name': 'unemploymentRate', 'date': '2025-09-01', 'value': 4.4},
#  {'name': 'unemploymentRate', 'date': '2025-08-01', 'value': 4.3},
#  {'name': 'unemploymentRate', 'date': '2025-07-01', 'value': 4.2},
#  {'name': 'unemploymentRate', 'date': '2025-06-01', 'value': 4.1},
#  {'name': 'unemploymentRate', 'date': '2025-05-01', 'value': 4.2},
#  {'name': 'unemploymentRate', 'date': '2025-04-01', 'value': 4.2},
#  {'name': 'unemploymentRate', 'date': '2025-03-01', 'value': 4.2},
#  {'name': 'unemploymentRate', 'date': '2025-02-01', 'value': 4.1},
#  {'name': 'unemploymentRate', 'date': '2025-01-01', 'value': 4}]

# %%
@mcp.tool()
async def economic_calendar(date_from: Optional[str] = None, date_to: Optional[str] = None) -> Any:
    """Economic Data Releases Calendar API — schedule of upcoming and past releases.

    Use this when:
      • You want release times and details (country, impact, actual/estimate/previous).
      • You’re planning around market-moving events (CPI, NFP, rates).

    Don’t use when:
      • You need long macro time series values (use economic_indicators).
      • You’re asking for equity-specific fundamentals (use company/statement tools).

    Endpoint: `/stable/economic-calendar`

    What it provides:
      • **Event Timing & Details**: `date`, `country`, `event`, `currency`, and
        actual/estimate/previous values with `impact` level where provided.
      • **Planning**: Helps anticipate potential market reactions around releases.

    Args:
      date_from: Optional start date `YYYY-MM-DD` (max 90-day range with `to`).
      date_to: Optional end date `YYYY-MM-DD`.

    Returns:
      A list of upcoming/past events within the requested window.
    """
    params: Dict[str, Any] = {}
    if date_from:
        params["from"] = date_from
    if date_to:
        params["to"] = date_to
    return await fmp_api_request("economic-calendar", params)

# %%
await economic_calendar()
# Out:
# [{'date': '2025-12-03 23:50:00',
#   'country': 'JP',
#   'event': 'Stock Investment by Foreigners (Nov/29)',
#   'currency': 'JPY',
#   'previous': -348.7,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-12-03 23:50:00',
#   'country': 'JP',
#   'event': 'Foreign Bond Investment (Nov/29)',
#   'currency': 'JPY',
#   'previous': 576.5,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-12-03 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Gold Speculative net positions',
#   'currency': 'USD',
#   'previous': 252.9,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': 'K'},
#  {'date': '2025-12-03 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Aluminium Speculative net positions',
#   'currency': 'USD',
#   'previous': 0.4,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'K'},
#  {'date': '2025-12-03 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Silver Speculative net positions',
#   'currency': 'USD',
#   'previous': 49.7,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'K'},
#  {'date': '2025-12-03 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Copper Speculative net positions',
#   'currency': 'USD',
#   'previous': 32.6,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'K'},
#  {'date': '2025-12-03 18:31:19',
#   'country': 'RU',
#   'event': 'Gross Domestic Product YoY (Oct)',
#   'currency': 'RUB',
#   'previous': 0.9,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 17:00:00',
#   'country': 'CA',
#   'event': '10-Year Bond Auction',
#   'currency': 'CAD',
#   'previous': 3.155,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 17:00:00',
#   'country': 'BE',
#   'event': 'New Car Registrations YoY (Nov)',
#   'currency': 'EUR',
#   'previous': -6.8,
#   'estimate': -3.2,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 17:00:00',
#   'country': 'UK',
#   'event': 'BoE Mann Speech',
#   'currency': 'GBP',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 16:30:00',
#   'country': 'IE',
#   'event': 'Irish Exchequer Returns (Nov)',
#   'currency': 'EUR',
#   'previous': -0.9,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-12-03 16:30:00',
#   'country': 'US',
#   'event': '17-Week Bill Auction',
#   'currency': 'USD',
#   'previous': 3.74,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 16:00:00',
#   'country': 'RU',
#   'event': 'Retail Sales YoY (Oct)',
#   'currency': 'RUB',
#   'previous': 1.8,
#   'estimate': 2.3,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 16:00:00',
#   'country': 'RU',
#   'event': 'Unemployment Rate (Oct)',
#   'currency': 'RUB',
#   'previous': 2.2,
#   'estimate': 2.2,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 16:00:00',
#   'country': 'RU',
#   'event': 'Business Confidence (Nov)',
#   'currency': 'RUB',
#   'previous': -1.1,
#   'estimate': -1.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 16:00:00',
#   'country': 'RU',
#   'event': 'Real Wage Growth YoY (Sep)',
#   'currency': 'RUB',
#   'previous': 3.8,
#   'estimate': 3.5,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Gasoline Stocks Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 2.513,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Weekly Refinery Utilization Rates WoW',
#   'currency': 'USD',
#   'previous': 2.3,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Crude Oil Stocks Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 2.774,
#   'estimate': -1.9,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'Imports',
#   'currency': 'USD',
#   'previous': 1.046,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Distillate Stocks Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 1.147,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Cushing Crude Oil Stocks Change (Nov/28)',
#   'currency': 'USD',
#   'previous': -0.068,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Refinery Crude Runs Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 0.211,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Heating Oil Stocks Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 0.057,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Crude Oil Imports Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 1.046,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Gasoline Production Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 0.286,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'US',
#   'event': 'EIA Distillate Fuel Production Change (Nov/28)',
#   'currency': 'USD',
#   'previous': 0.087,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 15:30:00',
#   'country': 'EU',
#   'event': 'ECB Lagarde Speech',
#   'currency': 'EUR',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Services New Orders (Nov)',
#   'currency': 'USD',
#   'previous': 56.2,
#   'estimate': 56.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Services Employment (Nov)',
#   'currency': 'USD',
#   'previous': 48.2,
#   'estimate': 48,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Services Business Activity (Nov)',
#   'currency': 'USD',
#   'previous': 54.3,
#   'estimate': 54.5,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Services Prices (Nov)',
#   'currency': 'USD',
#   'previous': 70,
#   'estimate': 70.3,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Non-Manufacturing Prices (Nov)',
#   'currency': 'USD',
#   'previous': 70,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Non-Manufacturing PMI (Nov)',
#   'currency': 'USD',
#   'previous': 52.4,
#   'estimate': 52,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Non-Manufacturing Employment (Nov)',
#   'currency': 'USD',
#   'previous': 48.2,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Non-Manufacturing Business Activity (Nov)',
#   'currency': 'USD',
#   'previous': 54.3,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Non-Manufacturing New Orders (Nov)',
#   'currency': 'USD',
#   'previous': 56.2,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 15:00:00',
#   'country': 'US',
#   'event': 'ISM Services PMI (Nov)',
#   'currency': 'USD',
#   'previous': 52.4,
#   'estimate': 52.1,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 14:45:00',
#   'country': 'US',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'USD',
#   'previous': 54.8,
#   'estimate': 55,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 14:45:00',
#   'country': 'US',
#   'event': 'S&P Global Composite PMI (Nov)',
#   'currency': 'USD',
#   'previous': 54.6,
#   'estimate': 54.8,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 14:30:00',
#   'country': 'CA',
#   'event': 'S&P Global Composite PMI (Nov)',
#   'currency': 'CAD',
#   'previous': 50.3,
#   'estimate': 50.7,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 14:30:00',
#   'country': 'CA',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'CAD',
#   'previous': 50.5,
#   'estimate': 50.6,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 14:30:00',
#   'country': 'CA',
#   'event': 'Services PMI (Nov)',
#   'currency': 'CAD',
#   'previous': 50.5,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 14:15:00',
#   'country': 'US',
#   'event': 'Capacity Utilization (Sep)',
#   'currency': 'USD',
#   'previous': 77.4,
#   'estimate': 77.3,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 14:15:00',
#   'country': 'US',
#   'event': 'Industrial Production YoY (Sep)',
#   'currency': 'USD',
#   'previous': 0.9,
#   'estimate': 1.6,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 14:15:00',
#   'country': 'US',
#   'event': 'Industrial Production MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.1,
#   'estimate': 0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 14:15:00',
#   'country': 'US',
#   'event': 'Manufacturing Production YoY (Sep)',
#   'currency': 'USD',
#   'previous': 0.9,
#   'estimate': 1.3,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 14:15:00',
#   'country': 'US',
#   'event': 'Manufacturing Production MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.2,
#   'estimate': 0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 14:00:00',
#   'country': 'PL',
#   'event': 'Interest Rate Decision (Dec)',
#   'currency': 'PLN',
#   'previous': 4.25,
#   'estimate': 4,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 13:30:00',
#   'country': 'CA',
#   'event': 'Labour Productivity QoQ (Q3)',
#   'currency': 'CAD',
#   'previous': -1,
#   'estimate': 0.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 13:30:00',
#   'country': 'US',
#   'event': 'Export Prices MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.3,
#   'estimate': 0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 13:30:00',
#   'country': 'US',
#   'event': 'Export Prices YoY (Sep)',
#   'currency': 'USD',
#   'previous': 3.4,
#   'estimate': 4.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 13:30:00',
#   'country': 'US',
#   'event': 'Import Prices YoY (Sep)',
#   'currency': 'USD',
#   'previous': 0,
#   'estimate': 0.6,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 13:30:00',
#   'country': 'US',
#   'event': 'Import Prices MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.3,
#   'estimate': 0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 13:30:00',
#   'country': 'EU',
#   'event': 'ECB President Lagarde Speech',
#   'currency': 'EUR',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 13:15:00',
#   'country': 'US',
#   'event': 'ADP Employment Change (Nov)',
#   'currency': 'USD',
#   'previous': 42,
#   'estimate': 5,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': 'K'},
#  {'date': '2025-12-03 13:00:00',
#   'country': 'BR',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'BRL',
#   'previous': 47.7,
#   'estimate': 48,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 13:00:00',
#   'country': 'BR',
#   'event': 'S&P Global Composite PMI (Nov)',
#   'currency': 'BRL',
#   'previous': 48.2,
#   'estimate': 48.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 13:00:00',
#   'country': 'HU',
#   'event': 'Monetary Policy Meeting Minutes',
#   'currency': 'HUF',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'US',
#   'event': 'MBA Purchase Index (Nov/28)',
#   'currency': 'USD',
#   'previous': 181.6,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'US',
#   'event': 'MBA Mortgage Refinance Index (Nov/28)',
#   'currency': 'USD',
#   'previous': 1090.4,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'MX',
#   'event': 'Gross Fixed Investment YoY (Sep)',
#   'currency': 'MXN',
#   'previous': -10.4,
#   'estimate': -7.7,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'UG',
#   'event': 'Balance of Trade (Oct)',
#   'currency': 'UGX',
#   'previous': -798.2,
#   'estimate': -840,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'US',
#   'event': 'MBA Mortgage Applications (Nov/28)',
#   'currency': 'USD',
#   'previous': 0.2,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'MX',
#   'event': 'Gross Fixed Investment MoM (Sep)',
#   'currency': 'MXN',
#   'previous': -2.7,
#   'estimate': -1.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'US',
#   'event': 'MBA Mortgage Market Index (Nov/28)',
#   'currency': 'USD',
#   'previous': 317.6,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'UG',
#   'event': 'Business Confidence (Nov)',
#   'currency': 'UGX',
#   'previous': 57.8,
#   'estimate': 59,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 12:00:00',
#   'country': 'US',
#   'event': 'MBA 30-Year Mortgage Rate (Nov/28)',
#   'currency': 'USD',
#   'previous': 6.4,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 11:30:00',
#   'country': 'PT',
#   'event': 'Budget Balance (Oct)',
#   'currency': 'EUR',
#   'previous': -1.3,
#   'estimate': -3.6,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-12-03 11:10:00',
#   'country': 'EU',
#   'event': '12-Month Bill Auction',
#   'currency': 'EUR',
#   'previous': 2.02,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 11:10:00',
#   'country': 'EU',
#   'event': '6-Month Bill Auction',
#   'currency': 'EUR',
#   'previous': 1.991,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 11:10:00',
#   'country': 'EU',
#   'event': '3-Month Bill Auction',
#   'currency': 'EUR',
#   'previous': 1.958,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 11:00:00',
#   'country': 'IL',
#   'event': 'Tourist Arrivals YoY (Nov)',
#   'currency': 'ILS',
#   'previous': 92.8,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 11:00:00',
#   'country': 'PT',
#   'event': 'Industrial Production MoM (Oct)',
#   'currency': 'EUR',
#   'previous': 0.6,
#   'estimate': -0.3,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 11:00:00',
#   'country': 'PT',
#   'event': 'Industrial Production YoY (Oct)',
#   'currency': 'EUR',
#   'previous': 2,
#   'estimate': 1.7,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 11:00:00',
#   'country': 'IE',
#   'event': 'Unemployment Rate (Nov)',
#   'currency': 'EUR',
#   'previous': 5,
#   'estimate': 5.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 10:30:00',
#   'country': 'EU',
#   'event': 'ECB Lane Speech',
#   'currency': 'EUR',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 10:15:00',
#   'country': 'GR',
#   'event': '52-Week Bill Auction',
#   'currency': 'EUR',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 10:00:00',
#   'country': 'LV',
#   'event': 'Current Account (Q3)',
#   'currency': 'EUR',
#   'previous': -4.5,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 10:00:00',
#   'country': 'EU',
#   'event': 'Producer Price Index YoY (Oct)',
#   'currency': 'EUR',
#   'previous': -0.2,
#   'estimate': -0.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 10:00:00',
#   'country': 'EU',
#   'event': 'Producer Price Index MoM (Oct)',
#   'currency': 'EUR',
#   'previous': -0.1,
#   'estimate': 0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 10:00:00',
#   'country': 'NO',
#   'event': 'House Price Index YoY (Nov)',
#   'currency': 'NOK',
#   'previous': 5.8,
#   'estimate': 5.9,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 10:00:00',
#   'country': 'ZA',
#   'event': 'Business Confidence (Q4)',
#   'currency': 'ZAR',
#   'previous': 39,
#   'estimate': 37,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 10:00:00',
#   'country': 'NO',
#   'event': 'House Price Index MoM (Nov)',
#   'currency': 'NOK',
#   'previous': 0.6,
#   'estimate': 0.5,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 09:40:00',
#   'country': 'ES',
#   'event': '6-Month Letras Auction',
#   'currency': 'EUR',
#   'previous': 1.944,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 09:30:00',
#   'country': 'UK',
#   'event': 'S&P Global Composite PMI (Nov)',
#   'currency': 'GBP',
#   'previous': 52.2,
#   'estimate': 50.5,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 09:30:00',
#   'country': 'UK',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'GBP',
#   'previous': 52.3,
#   'estimate': 50.5,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 09:25:00',
#   'country': 'DK',
#   'event': 'Bond Auction',
#   'currency': 'DKK',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'EU',
#   'event': 'PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 52.5,
#   'estimate': 52.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'NA',
#   'event': 'Interest Rate Decision (Dec)',
#   'currency': 'NAD',
#   'previous': 6.5,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'RU',
#   'event': 'Russian Forex Intervention (Dec)',
#   'currency': 'RUB',
#   'previous': -2.7,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'EU',
#   'event': 'Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 53,
#   'estimate': 53.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'EU',
#   'event': 'HCOB Composite PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 52.5,
#   'estimate': 52.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'EU',
#   'event': 'HCOB Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 53,
#   'estimate': 53.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'NA',
#   'event': 'Interest Rate Decision',
#   'currency': 'NAD',
#   'previous': 6.5,
#   'estimate': 6.25,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'EU',
#   'event': 'Consumer Inflation Expectation (Oct)',
#   'currency': 'EUR',
#   'previous': 2.7,
#   'estimate': 2.6,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 09:00:00',
#   'country': 'GH',
#   'event': 'PMI (Nov)',
#   'currency': 'GHS',
#   'previous': 50.3,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-12-03 08:55:00',
#   'country': 'DE',
#   'event': 'HCOB Composite PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 53.9,
#   'estimate': 52.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:55:00',
#   'country': 'DE',
#   'event': 'HCOB Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 54.6,
#   'estimate': 52.7,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:55:00',
#   'country': 'DE',
#   'event': 'PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 53.9,
#   'estimate': 52.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:55:00',
#   'country': 'DE',
#   'event': 'Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 54.6,
#   'estimate': 52.7,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:50:00',
#   'country': 'FR',
#   'event': 'PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 47.7,
#   'estimate': 49.9,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:50:00',
#   'country': 'FR',
#   'event': 'HCOB Composite PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 47.7,
#   'estimate': 49.9,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:50:00',
#   'country': 'FR',
#   'event': 'HCOB Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 48,
#   'estimate': 50.8,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:50:00',
#   'country': 'FR',
#   'event': 'Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 48,
#   'estimate': 50.8,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:45:00',
#   'country': 'IT',
#   'event': 'HCOB Composite PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 53.1,
#   'estimate': 53.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:45:00',
#   'country': 'IT',
#   'event': 'PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 53.1,
#   'estimate': 53.2,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:45:00',
#   'country': 'IT',
#   'event': 'Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 54,
#   'estimate': 53.9,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:45:00',
#   'country': 'IT',
#   'event': 'HCOB Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 54,
#   'estimate': 54.4,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 08:15:00',
#   'country': 'ES',
#   'event': 'Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 56.6,
#   'estimate': 56.3,
#   'actual': 55.6,
#   'change': -1,
#   'impact': 'Medium',
#   'changePercentage': -1.767,
#   'unit': None},
#  {'date': '2025-12-03 08:15:00',
#   'country': 'ES',
#   'event': 'HCOB Composite PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 56,
#   'estimate': 55.5,
#   'actual': 55.1,
#   'change': -0.9,
#   'impact': 'Low',
#   'changePercentage': -1.607,
#   'unit': None},
#  {'date': '2025-12-03 08:15:00',
#   'country': 'ES',
#   'event': 'HCOB Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 56.6,
#   'estimate': 56,
#   'actual': 55.6,
#   'change': -1,
#   'impact': 'High',
#   'changePercentage': -1.767,
#   'unit': None},
#  {'date': '2025-12-03 08:00:00',
#   'country': 'AM',
#   'event': 'Inflation Rate YoY (Nov)',
#   'currency': 'AMD',
#   'previous': 3.7,
#   'estimate': 3.5,
#   'actual': 3.1,
#   'change': -0.6,
#   'impact': 'Low',
#   'changePercentage': -16.216,
#   'unit': '%'},
#  {'date': '2025-12-03 08:00:00',
#   'country': 'ES',
#   'event': 'Tourist Arrivals YoY (Oct)',
#   'currency': 'EUR',
#   'previous': 0.8,
#   'estimate': 1.5,
#   'actual': 3.2,
#   'change': 2.4,
#   'impact': 'Low',
#   'changePercentage': 300,
#   'unit': '%'},
#  {'date': '2025-12-03 08:00:00',
#   'country': 'JO',
#   'event': 'Producer Price Index YoY (Oct)',
#   'currency': 'JOD',
#   'previous': -1.8,
#   'estimate': -0.4,
#   'actual': -0.87,
#   'change': 0.93,
#   'impact': 'Low',
#   'changePercentage': 51.667,
#   'unit': '%'},
#  {'date': '2025-12-03 07:30:00',
#   'country': 'CH',
#   'event': 'Inflation Rate MoM (Nov)',
#   'currency': 'CHF',
#   'previous': -0.3,
#   'estimate': -0.2,
#   'actual': -0.2,
#   'change': 0.1,
#   'impact': 'Low',
#   'changePercentage': 33.333,
#   'unit': '%'},
#  {'date': '2025-12-03 07:30:00',
#   'country': 'CH',
#   'event': 'CPI (Nov)',
#   'currency': 'CHF',
#   'previous': 0.1,
#   'estimate': 0.1,
#   'actual': 0,
#   'change': -0.1,
#   'impact': 'Low',
#   'changePercentage': -100,
#   'unit': '%'},
#  {'date': '2025-12-03 07:30:00',
#   'country': 'CH',
#   'event': 'Inflation Rate YoY (Nov)',
#   'currency': 'CHF',
#   'previous': 0.1,
#   'estimate': 0.1,
#   'actual': 0,
#   'change': -0.1,
#   'impact': 'Medium',
#   'changePercentage': -100,
#   'unit': '%'},
#  {'date': '2025-12-03 07:30:00',
#   'country': 'SE',
#   'event': 'Services PMI (Nov)',
#   'currency': 'SEK',
#   'previous': 55.9,
#   'estimate': 54.6,
#   'actual': 59.1,
#   'change': 3.2,
#   'impact': 'Low',
#   'changePercentage': 5.725,
#   'unit': None},
#  {'date': '2025-12-03 07:15:00',
#   'country': 'ZA',
#   'event': 'S&P Global Manufacturing PMI (Nov)',
#   'currency': 'ZAR',
#   'previous': 48.8,
#   'estimate': None,
#   'actual': 49,
#   'change': 0.2,
#   'impact': 'Low',
#   'changePercentage': 0.41,
#   'unit': None},
#  {'date': '2025-12-03 07:15:00',
#   'country': 'ZA',
#   'event': 'S&P Global PMI (Nov)',
#   'currency': 'ZAR',
#   'previous': 48.8,
#   'estimate': 50,
#   'actual': 49,
#   'change': 0.2,
#   'impact': 'Low',
#   'changePercentage': 0.41,
#   'unit': None},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'TR',
#   'event': 'Inflation Rate YoY (Nov)',
#   'currency': 'TRY',
#   'previous': 32.87,
#   'estimate': 31.6,
#   'actual': 31.07,
#   'change': -1.8,
#   'impact': 'Medium',
#   'changePercentage': -5.476,
#   'unit': '%'},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'TR',
#   'event': 'Producer Price Index MoM (Nov)',
#   'currency': 'TRY',
#   'previous': 1.63,
#   'estimate': 1.3,
#   'actual': 0.84,
#   'change': -0.79,
#   'impact': 'Low',
#   'changePercentage': -48.466,
#   'unit': '%'},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'RO',
#   'event': 'Producer Price Index YoY (Oct)',
#   'currency': 'RON',
#   'previous': 6.06,
#   'estimate': 5,
#   'actual': 8,
#   'change': 1.94,
#   'impact': 'Low',
#   'changePercentage': 32.013,
#   'unit': '%'},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'GE',
#   'event': 'Inflation Rate YoY (Nov)',
#   'currency': 'GEL',
#   'previous': 5.2,
#   'estimate': 5,
#   'actual': 4.8,
#   'change': -0.4,
#   'impact': 'Low',
#   'changePercentage': -7.692,
#   'unit': '%'},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'GE',
#   'event': 'Inflation Rate MoM (Nov)',
#   'currency': 'GEL',
#   'previous': 0.6,
#   'estimate': 0.5,
#   'actual': 0.4,
#   'change': -0.2,
#   'impact': 'Low',
#   'changePercentage': -33.333,
#   'unit': '%'},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'TR',
#   'event': 'CPI (Nov)',
#   'currency': 'TRY',
#   'previous': 32.87,
#   'estimate': 31.6,
#   'actual': 31.07,
#   'change': -1.8,
#   'impact': 'Medium',
#   'changePercentage': -5.476,
#   'unit': '%'},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'TR',
#   'event': 'Producer Price Index YoY (Nov)',
#   'currency': 'TRY',
#   'previous': 27,
#   'estimate': 28,
#   'actual': 27.23,
#   'change': 0.23,
#   'impact': 'Low',
#   'changePercentage': 0.852,
#   'unit': '%'},
#  {'date': '2025-12-03 07:00:00',
#   'country': 'TR',
#   'event': 'Inflation Rate MoM (Nov)',
#   'currency': 'TRY',
#   'previous': 2.55,
#   'estimate': 1.25,
#   'actual': 0.87,
#   'change': -1.68,
#   'impact': 'Medium',
#   'changePercentage': -65.882,
#   'unit': '%'},
#  {'date': '2025-12-03 06:00:00',
#   'country': 'RU',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'RUB',
#   'previous': 51.7,
#   'estimate': 52,
#   'actual': 52.2,
#   'change': 0.5,
#   'impact': 'Low',
#   'changePercentage': 0.967,
#   'unit': None},
#  {'date': '2025-12-03 06:00:00',
#   'country': 'RU',
#   'event': 'S&P Global Composite PMI (Nov)',
#   'currency': 'RUB',
#   'previous': 50.2,
#   'estimate': 50.5,
#   'actual': 50.1,
#   'change': -0.1,
#   'impact': 'Low',
#   'changePercentage': -0.199,
#   'unit': None},
#  {'date': '2025-12-03 05:15:00',
#   'country': 'EG',
#   'event': 'S&P Global PMI (Nov)',
#   'currency': 'EGP',
#   'previous': 49.2,
#   'estimate': 49.4,
#   'actual': 51.1,
#   'change': 1.9,
#   'impact': 'Low',
#   'changePercentage': 3.862,
#   'unit': None},
#  {'date': '2025-12-03 05:00:00',
#   'country': 'IN',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'INR',
#   'previous': 58.9,
#   'estimate': 59.5,
#   'actual': 59.8,
#   'change': 0.9,
#   'impact': 'Low',
#   'changePercentage': 1.528,
#   'unit': None},
#  {'date': '2025-12-03 05:00:00',
#   'country': 'IN',
#   'event': 'HSBC Services PMI (Nov)',
#   'currency': 'INR',
#   'previous': 58.9,
#   'estimate': 59.5,
#   'actual': 59.8,
#   'change': 0.9,
#   'impact': 'Low',
#   'changePercentage': 1.528,
#   'unit': None},
#  {'date': '2025-12-03 05:00:00',
#   'country': 'IN',
#   'event': 'HSBC Composite PMI (Nov)',
#   'currency': 'INR',
#   'previous': 60.4,
#   'estimate': 59.9,
#   'actual': 59.7,
#   'change': -0.7,
#   'impact': 'Low',
#   'changePercentage': -1.159,
#   'unit': None},
#  {'date': '2025-12-03 05:00:00',
#   'country': 'IN',
#   'event': 'Services PMI (Nov)',
#   'currency': 'INR',
#   'previous': 60.4,
#   'estimate': 59.9,
#   'actual': 59.7,
#   'change': -0.7,
#   'impact': 'Low',
#   'changePercentage': -1.159,
#   'unit': None},
#  {'date': '2025-12-03 04:30:00',
#   'country': 'TH',
#   'event': 'Core Inflation Rate YoY (Nov)',
#   'currency': 'THB',
#   'previous': 0.61,
#   'estimate': 0.57,
#   'actual': 0.66,
#   'change': 0.05,
#   'impact': 'Low',
#   'changePercentage': 8.197,
#   'unit': '%'},
#  {'date': '2025-12-03 04:30:00',
#   'country': 'TH',
#   'event': 'Inflation Rate YoY (Nov)',
#   'currency': 'THB',
#   'previous': -0.76,
#   'estimate': -0.6,
#   'actual': -0.49,
#   'change': 0.27,
#   'impact': 'Low',
#   'changePercentage': 35.526,
#   'unit': '%'},
#  {'date': '2025-12-03 04:15:00',
#   'country': 'SA',
#   'event': 'PMI (Nov)',
#   'currency': 'SAR',
#   'previous': 60.2,
#   'estimate': None,
#   'actual': 58.5,
#   'change': -1.7,
#   'impact': 'Low',
#   'changePercentage': -2.824,
#   'unit': None},
#  {'date': '2025-12-03 04:15:00',
#   'country': 'SA',
#   'event': 'Riyad Bank PMI (Nov)',
#   'currency': 'SAR',
#   'previous': 60.2,
#   'estimate': 60.6,
#   'actual': 58.5,
#   'change': -1.7,
#   'impact': 'Low',
#   'changePercentage': -2.824,
#   'unit': None},
#  {'date': '2025-12-03 03:00:00',
#   'country': 'TH',
#   'event': 'CPI (Nov)',
#   'currency': 'THB',
#   'previous': 0.61,
#   'estimate': 0.57,
#   'actual': 0.66,
#   'change': 0.05,
#   'impact': 'Low',
#   'changePercentage': 8.197,
#   'unit': '%'},
#  {'date': '2025-12-03 01:45:00',
#   'country': 'CN',
#   'event': 'Caixin Composite PMI (Nov)',
#   'currency': 'CNY',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-03 01:45:00',
#   'country': 'CN',
#   'event': 'PMI (Nov)',
#   'currency': 'CNY',
#   'previous': 51.8,
#   'estimate': 51.7,
#   'actual': 51.2,
#   'change': -0.6,
#   'impact': 'Low',
#   'changePercentage': -1.158,
#   'unit': None},
#  {'date': '2025-12-03 01:45:00',
#   'country': 'CN',
#   'event': 'Services PMI (Nov)',
#   'currency': 'CNY',
#   'previous': 52.6,
#   'estimate': 51.9,
#   'actual': 52.1,
#   'change': -0.5,
#   'impact': 'High',
#   'changePercentage': -0.951,
#   'unit': None},
#  {'date': '2025-12-03 01:45:00',
#   'country': 'CN',
#   'event': 'Caixin Services PMI (Nov)',
#   'currency': 'CNY',
#   'previous': 52.6,
#   'estimate': 52.1,
#   'actual': 52.1,
#   'change': -0.5,
#   'impact': 'Medium',
#   'changePercentage': -0.951,
#   'unit': None},
#  {'date': '2025-12-03 01:01:00',
#   'country': 'IE',
#   'event': 'AIB Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 56.7,
#   'estimate': 55.1,
#   'actual': 58.5,
#   'change': 1.8,
#   'impact': 'Low',
#   'changePercentage': 3.175,
#   'unit': None},
#  {'date': '2025-12-03 01:01:00',
#   'country': 'IE',
#   'event': 'Services PMI (Nov)',
#   'currency': 'EUR',
#   'previous': 56.7,
#   'estimate': None,
#   'actual': 58.5,
#   'change': 1.8,
#   'impact': 'Low',
#   'changePercentage': 3.175,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'GDP Final Consumption QoQ (Q3)',
#   'currency': 'AUD',
#   'previous': 0.9,
#   'estimate': None,
#   'actual': 0.6,
#   'change': -0.3,
#   'impact': 'Low',
#   'changePercentage': -33.333,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'JP',
#   'event': 'Services PMI (Nov)',
#   'currency': 'JPY',
#   'previous': 51.5,
#   'estimate': 52,
#   'actual': 52,
#   'change': 0.5,
#   'impact': 'Low',
#   'changePercentage': 0.971,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'JP',
#   'event': 'S&P Global Composite PMI (Nov)',
#   'currency': 'JPY',
#   'previous': 51.5,
#   'estimate': 52,
#   'actual': 52,
#   'change': 0.5,
#   'impact': 'Low',
#   'changePercentage': 0.971,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'JP',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'JPY',
#   'previous': 53.1,
#   'estimate': 53.1,
#   'actual': 53.2,
#   'change': 0.1,
#   'impact': 'Low',
#   'changePercentage': 0.188,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'GDP Chain Price Index QoQ (Q3)',
#   'currency': 'AUD',
#   'previous': -0.5,
#   'estimate': None,
#   'actual': 0.8,
#   'change': 1.3,
#   'impact': 'Low',
#   'changePercentage': 260,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'GDP Capital Expenditure (Q3)',
#   'currency': 'AUD',
#   'previous': -0.7,
#   'estimate': None,
#   'actual': 3,
#   'change': 3.7,
#   'impact': 'Low',
#   'changePercentage': 528.571,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'GDP Capital Expenditure QoQ (Q3)',
#   'currency': 'AUD',
#   'previous': -0.7,
#   'estimate': None,
#   'actual': 3,
#   'change': 3.7,
#   'impact': 'Low',
#   'changePercentage': 528.571,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'HK',
#   'event': 'S&P Global Manufacturing PMI (Nov)',
#   'currency': 'HKD',
#   'previous': 51.2,
#   'estimate': None,
#   'actual': 52.9,
#   'change': 1.7,
#   'impact': 'Low',
#   'changePercentage': 3.32,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'Gross Domestic Product YoY (Q3)',
#   'currency': 'AUD',
#   'previous': 2,
#   'estimate': 2.2,
#   'actual': 2.1,
#   'change': 0.1,
#   'impact': 'Medium',
#   'changePercentage': 5,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'GDP Growth Rate QoQ (Q3)',
#   'currency': 'AUD',
#   'previous': 0.7,
#   'estimate': 0.7,
#   'actual': 0.4,
#   'change': -0.3,
#   'impact': 'High',
#   'changePercentage': -42.857,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'JP',
#   'event': 'Jibun Bank Services PMI (Nov)',
#   'currency': 'JPY',
#   'previous': 53.1,
#   'estimate': 53.1,
#   'actual': 53.2,
#   'change': 0.1,
#   'impact': 'Medium',
#   'changePercentage': 0.188,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'Gross Domestic Product QoQ (Q3)',
#   'currency': 'AUD',
#   'previous': 0.7,
#   'estimate': 0.7,
#   'actual': 0.4,
#   'change': -0.3,
#   'impact': 'Medium',
#   'changePercentage': -42.857,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'GDP Consumption QoQ (Q3)',
#   'currency': 'AUD',
#   'previous': 0.9,
#   'estimate': None,
#   'actual': 0.6,
#   'change': -0.3,
#   'impact': 'Low',
#   'changePercentage': -33.333,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'AU',
#   'event': 'GDP Growth Rate YoY (Q3)',
#   'currency': 'AUD',
#   'previous': 2,
#   'estimate': 2.2,
#   'actual': 2.1,
#   'change': 0.1,
#   'impact': 'Medium',
#   'changePercentage': 5,
#   'unit': '%'},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'HK',
#   'event': 'S&P Global PMI (Nov)',
#   'currency': 'HKD',
#   'previous': 51.2,
#   'estimate': 51.5,
#   'actual': 52.9,
#   'change': 1.7,
#   'impact': 'Low',
#   'changePercentage': 3.32,
#   'unit': None},
#  {'date': '2025-12-03 00:30:00',
#   'country': 'SG',
#   'event': 'S&P Global PMI (Nov)',
#   'currency': 'SGD',
#   'previous': 57.4,
#   'estimate': 57.1,
#   'actual': 55.4,
#   'change': -2,
#   'impact': 'Low',
#   'changePercentage': -3.484,
#   'unit': None},
#  {'date': '2025-12-03 00:25:00',
#   'country': 'AO',
#   'event': 'GDP Growth Rate QoQ (Q3)',
#   'currency': 'AOA',
#   'previous': -0.1,
#   'estimate': 0.7,
#   'actual': 0.05,
#   'change': 0.15,
#   'impact': 'Low',
#   'changePercentage': 150,
#   'unit': '%'},
#  {'date': '2025-12-03 00:25:00',
#   'country': 'AO',
#   'event': 'GDP Growth Rate YoY (Q3)',
#   'currency': 'AOA',
#   'previous': 1.1,
#   'estimate': 3,
#   'actual': 1.8,
#   'change': 0.7,
#   'impact': 'Low',
#   'changePercentage': 63.636,
#   'unit': '%'},
#  {'date': '2025-12-03 00:00:00',
#   'country': 'NZ',
#   'event': 'ANZ Commodity Price Index MoM',
#   'currency': 'NZD',
#   'previous': -0.3,
#   'estimate': None,
#   'actual': -1.6,
#   'change': -1.3,
#   'impact': 'Low',
#   'changePercentage': -433.333,
#   'unit': '%'},
#  {'date': '2025-12-02 23:00:00',
#   'country': 'KR',
#   'event': 'Gross Domestic Product QoQ (Q3)',
#   'currency': 'KRW',
#   'previous': 0.7,
#   'estimate': 1.2,
#   'actual': 1.3,
#   'change': 0.6,
#   'impact': 'Low',
#   'changePercentage': 85.714,
#   'unit': '%'},
#  {'date': '2025-12-02 23:00:00',
#   'country': 'KR',
#   'event': 'GDP Growth Rate QoQ (Q3)',
#   'currency': 'KRW',
#   'previous': 0.7,
#   'estimate': 1.2,
#   'actual': 1.3,
#   'change': 0.6,
#   'impact': 'Low',
#   'changePercentage': 85.714,
#   'unit': '%'},
#  {'date': '2025-12-02 23:00:00',
#   'country': 'KR',
#   'event': 'GDP Growth Rate YoY (Q3)',
#   'currency': 'KRW',
#   'previous': 0.6,
#   'estimate': 1.7,
#   'actual': 1.8,
#   'change': 1.2,
#   'impact': 'Low',
#   'changePercentage': 200,
#   'unit': '%'},
#  {'date': '2025-12-02 23:00:00',
#   'country': 'KR',
#   'event': 'Gross Domestic Product YoY (Q3)',
#   'currency': 'KRW',
#   'previous': 0.6,
#   'estimate': 1.7,
#   'actual': 1.8,
#   'change': 1.2,
#   'impact': 'Low',
#   'changePercentage': 200,
#   'unit': '%'},
#  {'date': '2025-12-02 22:20:00',
#   'country': 'US',
#   'event': 'API Crude Oil Stock Change (Nov/28)',
#   'currency': 'USD',
#   'previous': -1.9,
#   'estimate': None,
#   'actual': -2.48,
#   'change': -0.58,
#   'impact': 'Medium',
#   'changePercentage': -30.526,
#   'unit': 'M'},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'S&P Global Services PMI (Nov)',
#   'currency': 'AUD',
#   'previous': 52.5,
#   'estimate': 52.7,
#   'actual': 52.8,
#   'change': 0.3,
#   'impact': 'High',
#   'changePercentage': 0.571,
#   'unit': None},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'Judo Bank Services PMI (Nov)',
#   'currency': 'AUD',
#   'previous': 52.5,
#   'estimate': 52.7,
#   'actual': 52.8,
#   'change': 0.3,
#   'impact': 'Low',
#   'changePercentage': 0.571,
#   'unit': None},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'RBA Gov Bullock Speaks',
#   'currency': 'AUD',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'US',
#   'event': 'Total Vehicle Sales (Nov)',
#   'currency': 'USD',
#   'previous': 15.3,
#   'estimate': 15.4,
#   'actual': 15.6,
#   'change': 0.3,
#   'impact': 'Low',
#   'changePercentage': 1.961,
#   'unit': 'M'},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'Ai Group Industry Index (Nov)',
#   'currency': 'AUD',
#   'previous': -11.2,
#   'estimate': -15,
#   'actual': -12.5,
#   'change': -1.3,
#   'impact': 'Medium',
#   'changePercentage': -11.607,
#   'unit': None},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'S&P Global Composite PMI (Nov)',
#   'currency': 'AUD',
#   'previous': 52.1,
#   'estimate': 52.6,
#   'actual': 52.6,
#   'change': 0.5,
#   'impact': 'Low',
#   'changePercentage': 0.96,
#   'unit': None},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'Services PMI (Nov)',
#   'currency': 'AUD',
#   'previous': 52.1,
#   'estimate': 52.6,
#   'actual': 52.6,
#   'change': 0.5,
#   'impact': 'Low',
#   'changePercentage': 0.96,
#   'unit': None},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'Ai Group Construction Index (Nov)',
#   'currency': 'AUD',
#   'previous': -7.1,
#   'estimate': -9,
#   'actual': -18.7,
#   'change': -11.6,
#   'impact': 'Low',
#   'changePercentage': -163.38,
#   'unit': None},
#  {'date': '2025-12-02 22:00:00',
#   'country': 'AU',
#   'event': 'Ai Group Manufacturing Index (Nov)',
#   'currency': 'AUD',
#   'previous': -22,
#   'estimate': -18,
#   'actual': -18,
#   'change': 4,
#   'impact': 'Low',
#   'changePercentage': 18.182,
#   'unit': None},
#  {'date': '2025-12-02 21:00:00',
#   'country': 'KR',
#   'event': 'Foreign Exchange Reserves (Nov)',
#   'currency': 'KRW',
#   'previous': 428.82,
#   'estimate': 430,
#   'actual': 430.66,
#   'change': 1.84,
#   'impact': 'Low',
#   'changePercentage': 0.429,
#   'unit': 'B'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'JP',
#   'event': 'CFTC JPY speculative net positions',
#   'currency': 'JPY',
#   'previous': 46.3,
#   'estimate': None,
#   'actual': 70.4,
#   'change': 24.1,
#   'impact': 'Medium',
#   'changePercentage': 52.052,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'AU',
#   'event': 'CFTC AUD speculative net positions',
#   'currency': 'AUD',
#   'previous': -57.8,
#   'estimate': None,
#   'actual': -65.8,
#   'change': -8,
#   'impact': 'Medium',
#   'changePercentage': -13.841,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Natural Gas speculative net positions',
#   'currency': 'USD',
#   'previous': -142,
#   'estimate': None,
#   'actual': -158.8,
#   'change': -16.8,
#   'impact': 'Low',
#   'changePercentage': -11.831,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Wheat speculative net positions',
#   'currency': 'USD',
#   'previous': -70.6,
#   'estimate': None,
#   'actual': -80.2,
#   'change': -9.6,
#   'impact': 'Low',
#   'changePercentage': -13.598,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Copper Speculative net positions',
#   'currency': 'USD',
#   'previous': 39.1,
#   'estimate': None,
#   'actual': 41.2,
#   'change': 2.1,
#   'impact': 'Low',
#   'changePercentage': 5.371,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'EU',
#   'event': 'CFTC EUR speculative net positions',
#   'currency': 'EUR',
#   'previous': 118.4,
#   'estimate': None,
#   'actual': 111.8,
#   'change': -6.6,
#   'impact': 'Medium',
#   'changePercentage': -5.574,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Corn speculative net positions',
#   'currency': 'USD',
#   'previous': -92.4,
#   'estimate': None,
#   'actual': -83.3,
#   'change': 9.1,
#   'impact': 'Low',
#   'changePercentage': 9.848,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'NZ',
#   'event': 'CFTC NZD speculative net positions',
#   'currency': 'NZD',
#   'previous': -24.4,
#   'estimate': None,
#   'actual': -36.3,
#   'change': -11.9,
#   'impact': 'Low',
#   'changePercentage': -48.77,
#   'unit': 'K'},
#  {'date': '2025-12-02 20:30:00',
#   'country': 'US',
#   'event': 'CFTC Crude Oil speculative net positions',
#   'currency': 'USD',
#   'previous': 74.3,
#   'estimate': None,
#   'actual': 39.8,
#   'change': -34.5,
#   'impact': 'Medium',
# ...
#   'impact': 'Low',
#   'changePercentage': 283.333,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': '4-Week Bill Auction',
#   'currency': 'USD',
#   'previous': 3.89,
#   'estimate': None,
#   'actual': 3.905,
#   'change': 0.015,
#   'impact': 'Low',
#   'changePercentage': 0.386,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'PCE Price Index YoY (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 2.8,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Core PCE Price Index YoY (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 2.8,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Retail Inventories Ex Autos MoM (Sep)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 0.2,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'PCE Price Index MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 0.2,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Core PCE Price Index MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Core PCE Price Index MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.2,
#   'estimate': 0.2,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Personal Income MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 0.3,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': '8-Week Bill Auction',
#   'currency': 'USD',
#   'previous': 3.85,
#   'estimate': None,
#   'actual': 3.84,
#   'change': -0.01,
#   'impact': 'Low',
#   'changePercentage': -0.26,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'New Home Sales (Sep)',
#   'currency': 'USD',
#   'previous': 20.5,
#   'estimate': -13.8,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Personal Spending MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 0.2,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Personal Income MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.4,
#   'estimate': 0.4,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Core PCE Price Index YoY (Sep)',
#   'currency': 'USD',
#   'previous': 2.9,
#   'estimate': 2.9,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'PCE Price Index MoM',
#   'currency': 'USD',
#   'previous': 0.2,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'PCE Price Index YoY (Sep)',
#   'currency': 'USD',
#   'previous': 2.7,
#   'estimate': 2.8,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'Personal Spending MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.6,
#   'estimate': 0.4,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'New Home Sales (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 1.4,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 15:00:00',
#   'country': 'US',
#   'event': 'PCE Price Index MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.3,
#   'estimate': 0.3,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 14:45:00',
#   'country': 'US',
#   'event': 'Chicago PMI',
#   'currency': 'USD',
#   'previous': 43.8,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 14:45:00',
#   'country': 'US',
#   'event': 'Chicago PMI (Nov)',
#   'currency': 'USD',
#   'previous': 43.8,
#   'estimate': 44.3,
#   'actual': 36.3,
#   'change': -7.5,
#   'impact': 'Medium',
#   'changePercentage': -17.123,
#   'unit': None},
#  {'date': '2025-11-26 14:30:00',
#   'country': 'CO',
#   'event': 'Business Confidence (Oct)',
#   'currency': 'COP',
#   'previous': 9,
#   'estimate': 8,
#   'actual': 4.9,
#   'change': -4.1,
#   'impact': 'Low',
#   'changePercentage': -45.556,
#   'unit': None},
#  {'date': '2025-11-26 14:00:00',
#   'country': 'MZ',
#   'event': 'Interest Rate Decision',
#   'currency': 'MZN',
#   'previous': 9.75,
#   'estimate': 9.75,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Wholesale Inventories MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -0.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders Ex Transp MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0.5,
#   'estimate': 0.2,
#   'actual': 0.6,
#   'change': 0.1,
#   'impact': 'High',
#   'changePercentage': 20,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Real Consumer Spending QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 2.5,
#   'estimate': 2.2,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'GDP Price Index QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 2.1,
#   'estimate': 2.5,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Gross Domestic Product QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 3.8,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Building Permits (Sep)',
#   'currency': 'USD',
#   'previous': 1.33,
#   'estimate': 1.34,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': 'M'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders ex Defense MoM (Sep)',
#   'currency': 'USD',
#   'previous': 1.9,
#   'estimate': 1.9,
#   'actual': 0.1,
#   'change': -1.8,
#   'impact': 'High',
#   'changePercentage': -94.737,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Building Permits (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': 0.7,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders Ex Transp MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Corporate Profits QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 0.2,
#   'estimate': 1,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Wholesale Inventories MoM (Sep)',
#   'currency': 'USD',
#   'previous': 0,
#   'estimate': -0.2,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Core PCE Prices QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 2.6,
#   'estimate': 2.8,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Jobless Claims 4-Week Average (Nov/22)',
#   'currency': 'USD',
#   'previous': 224.75,
#   'estimate': 225,
#   'actual': 223.75,
#   'change': -1,
#   'impact': 'High',
#   'changePercentage': -0.445,
#   'unit': 'K'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders ex Defense MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -0.8,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Balance of Trade',
#   'currency': 'USD',
#   'previous': -85.5,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Non Defense Goods Orders Ex Air (Sep)',
#   'currency': 'USD',
#   'previous': 0.9,
#   'estimate': 0.1,
#   'actual': 0.9,
#   'change': 0,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders MoM (Sep)',
#   'currency': 'USD',
#   'previous': 3,
#   'estimate': 0.3,
#   'actual': 0.5,
#   'change': -2.5,
#   'impact': 'High',
#   'changePercentage': -83.333,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders MoM',
#   'currency': 'USD',
#   'previous': 2.9,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders Ex Defense MoM',
#   'currency': 'USD',
#   'previous': 1.9,
#   'estimate': 1.9,
#   'actual': 0.1,
#   'change': -1.8,
#   'impact': 'Low',
#   'changePercentage': -94.737,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'PCE Prices QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 2.1,
#   'estimate': 2.3,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Goods Trade Balance (Sep)',
#   'currency': 'USD',
#   'previous': -85.5,
#   'estimate': -90,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Non Defense Goods Orders Ex Air (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Goods Trade Balance (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -89,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Initial Jobless Claims (Nov/22)',
#   'currency': 'USD',
#   'previous': 222,
#   'estimate': 225,
#   'actual': 216,
#   'change': -6,
#   'impact': 'High',
#   'changePercentage': -2.703,
#   'unit': 'K'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Durable Goods Orders MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -0.3,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Goods Trade Balance Adv (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -89,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': 'B'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'GDP Growth Rate QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 3.8,
#   'estimate': 1,
#   'actual': None,
#   'change': None,
#   'impact': 'High',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Continuing Jobless Claims (Nov/15)',
#   'currency': 'USD',
#   'previous': 1953,
#   'estimate': 1975,
#   'actual': 1960,
#   'change': 7,
#   'impact': 'High',
#   'changePercentage': 0.358,
#   'unit': 'K'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'GDP Sales QoQ (Q3)',
#   'currency': 'USD',
#   'previous': 7.5,
#   'estimate': 7.4,
#   'actual': None,
#   'change': None,
#   'impact': 'Low',
#   'changePercentage': 0,
#   'unit': '%'},
#  {'date': '2025-11-26 13:30:00',
#   'country': 'US',
#   'event': 'Retail Inventories Ex Autos MoM (Oct)',
#   'currency': 'USD',
#   'previous': None,
#   'estimate': -0.1,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 13:15:00',
#   'country': 'GH',
#   'event': 'Interest Rate Decision',
#   'currency': 'GHS',
#   'previous': 21.5,
#   'estimate': 18.25,
#   'actual': 18,
#   'change': -3.5,
#   'impact': 'Low',
#   'changePercentage': -16.279,
#   'unit': '%'},
#  {'date': '2025-11-26 12:50:00',
#   'country': 'XK',
#   'event': 'Producer Price Index YoY (Q3)',
#   'currency': 'EUR',
#   'previous': 11.3,
#   'estimate': 7.1,
#   'actual': 5.5,
#   'change': -5.8,
#   'impact': 'Low',
#   'changePercentage': -51.327,
#   'unit': '%'},
#  {'date': '2025-11-26 12:30:00',
#   'country': 'UK',
#   'event': 'Budget (2025)',
#   'currency': 'GBP',
#   'previous': None,
#   'estimate': None,
#   'actual': None,
#   'change': None,
#   'impact': 'Medium',
#   'changePercentage': 0,
#   'unit': None},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'US',
#   'event': 'MBA 30-Year Mortgage Rate (Nov/21)',
#   'currency': 'USD',
#   'previous': 6.37,
#   'estimate': None,
#   'actual': 6.4,
#   'change': 0.03,
#   'impact': 'Medium',
#   'changePercentage': 0.471,
#   'unit': '%'},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'KW',
#   'event': 'M2 Money Supply YoY (Oct)',
#   'currency': 'KWD',
#   'previous': 4.09,
#   'estimate': None,
#   'actual': 3.49,
#   'change': -0.6,
#   'impact': 'Low',
#   'changePercentage': -14.67,
#   'unit': '%'},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'BR',
#   'event': 'CPI (Nov)',
#   'currency': 'BRL',
#   'previous': 4.94,
#   'estimate': 4.49,
#   'actual': 4.5,
#   'change': -0.44,
#   'impact': 'Low',
#   'changePercentage': -8.907,
#   'unit': '%'},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'BR',
#   'event': 'IPCA mid-month CPI YoY (Nov)',
#   'currency': 'BRL',
#   'previous': 4.94,
#   'estimate': 4.49,
#   'actual': 4.5,
#   'change': -0.44,
#   'impact': 'Low',
#   'changePercentage': -8.907,
#   'unit': '%'},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'KW',
#   'event': 'Bank Lending YoY (Oct)',
#   'currency': 'KWD',
#   'previous': 6.43,
#   'estimate': None,
#   'actual': 7.01,
#   'change': 0.58,
#   'impact': 'Low',
#   'changePercentage': 9.02,
#   'unit': '%'},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'US',
#   'event': 'MBA Mortgage Market Index (Nov/21)',
#   'currency': 'USD',
#   'previous': 316.9,
#   'estimate': None,
#   'actual': 317.6,
#   'change': 0.7,
#   'impact': 'Low',
#   'changePercentage': 0.221,
#   'unit': None},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'US',
#   'event': 'MBA Purchase Index (Nov/21)',
#   'currency': 'USD',
#   'previous': 168.7,
#   'estimate': None,
#   'actual': 181.6,
#   'change': 12.9,
#   'impact': 'Low',
#   'changePercentage': 7.647,
#   'unit': None},
#  {'date': '2025-11-26 12:00:00',
#   'country': 'BR',
#   'event': 'IPCA mid-month CPI MoM (Nov)',
#   'currency': 'BRL',
#   'previous': 0.18,
#   'estimate': 0.18,
#   'actual': 0.2,
#   'change': 0.02,
#   'impact': 'Low',
#   'changePercentage': 11.111,
#   'unit': '%'},
#  ...]

# %%
@mcp.tool()
async def stock_news_latest(page: int = 0, limit: int = 20, date_from: Optional[str] = None, date_to: Optional[str] = None) -> Any:
    """Stock News API — latest market/stock headlines and summaries.

    Use this when:
      • You want general/latest market or equity news (optionally date-bounded).
      • You need a scrolling feed for monitoring.

    Don’t use when:
      • You need ticker-filtered news (use stock_news_search with symbols).
      • You’re looking for transcripts or filings.

    Endpoint: `/stable/news/stock-latest`

    What it provides:
      • **Breaking & Recent Headlines**: `title`, `publisher`, `publishedDate`.
      • **Context**: `text` snippet, `image`, `url`, and sometimes mapped `symbol`.

    Args:
      page: Zero-based page index (max page typically 100).
      limit: Page size (max 250).
      date_from: Optional earliest date `YYYY-MM-DD`.
      date_to: Optional latest date `YYYY-MM-DD`.

    Returns:
      A list of news items; use paging to iterate.
    """
    params: Dict[str, Any] = {"page": page, "limit": limit}
    if date_from:
        params["from"] = date_from
    if date_to:
        params["to"] = date_to
    return await fmp_api_request("news/stock-latest", params)

# %%
await stock_news_latest()
# Out:
# [{'symbol': 'JVA',
#   'publishedDate': '2025-12-03 03:33:25',
#   'publisher': 'Seeking Alpha',
#   'title': 'Black Rock Coffee Bar, Inc. (BRCB) Presents at Morgan Stanley Global Consumer & Retail Conference 2025 Transcript',
#   'image': 'https://images.financialmodelingprep.com/news/black-rock-coffee-bar-inc-brcb-presents-at-morgan-20251203.jpg',
#   'site': 'seekingalpha.com',
#   'text': 'Black Rock Coffee Bar, Inc. (BRCB) Presents at Morgan Stanley Global Consumer & Retail Conference 2025 Transcript',
#   'url': 'https://seekingalpha.com/article/4849662-black-rock-coffee-bar-inc-brcb-presents-at-morgan-stanley-global-consumer-and-retail'},
#  {'symbol': 'FTI',
#   'publishedDate': '2025-12-03 03:30:00',
#   'publisher': 'GlobeNewsWire',
#   'title': 'FTI Consulting Continues Private Equity and Financial Services Investment With Addition of Four Senior Hires',
#   'image': 'https://images.financialmodelingprep.com/news/fti-consulting-continues-private-equity-and-financial-services-investment-20251203.jpg',
#   'site': 'globenewswire.com',
#   'text': 'LONDON, Dec. 03, 2025 (GLOBE NEWSWIRE) -- FTI Consulting, Inc. (NYSE: FCN) today announced the appointment of four senior hires in its Transformation practices in London. Jan Timmermann, Malvinder Singh and Rakhi Williams join the firm as Senior Managing Directors and Irina Bakanova joins as a Managing Director.',
#   'url': 'https://www.globenewswire.com/news-release/2025/12/03/3198597/33891/en/FTI-Consulting-Continues-Private-Equity-and-Financial-Services-Investment-With-Addition-of-Four-Senior-Hires.html'},
#  {'symbol': 'PMOMF',
#   'publishedDate': '2025-12-03 03:30:00',
#   'publisher': 'TheNewswire',
#   'title': 'Prismo Metals Announces Assay & IP Results at Silver King',
#   'image': 'https://images.financialmodelingprep.com/news/prismo-metals-announces-assay-ip-results-at-silver-king-20251203.jpg',
#   'site': 'thenewswire.com',
#   'text': 'Additional Financing Closes NOT FOR DISTRIBUTION TO UNITED STATES NEWS WIRE SERVICES OR FOR DISSEMINATION IN THE UNITED STATES',
#   'url': 'https://www.thenewswire.com/press-releases/1BglFNDG1-prismo-metals-announces-assay-ip-results-at-silver-king.html'},
#  {'symbol': 'INDA',
#   'publishedDate': '2025-12-03 03:29:22',
#   'publisher': 'CNBC',
#   'title': "India is set to host Russia's Putin, deepening trade ties, unfazed by punitive U.S. tariffs",
#   'image': 'https://images.financialmodelingprep.com/news/india-is-set-to-host-russias-putin-deepening-trade-20251203.jpg',
#   'site': 'cnbc.com',
#   'text': 'Russian President Vladimir Putin will be in India on Dec 4-5 for the 23rd India-Russia annual summit. The countries are likely to extend cooperation in defense and civil nuclear sector.',
#   'url': 'https://www.cnbc.com/2025/12/03/india-russia-putin-meeting-tariffs-new-delhi-moscow-trade.html'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-03 03:28:01',
#   'publisher': 'CNBC',
#   'title': 'iPhone 17 will drive record Apple shipments in 2025, IDC says',
#   'image': 'https://images.financialmodelingprep.com/news/iphone-17-will-drive-record-apple-shipments-in-2025-20251203.jpg',
#   'site': 'cnbc.com',
#   'text': 'Apple will ship 247.4 million iPhones in 2025, up just over 6% year-on-year, IDC has forecast. This is higher than its previous record year, 2021, when the iPhone 13 was released.',
#   'url': 'https://www.cnbc.com/2025/12/03/iphone-17-will-drive-record-apple-shipments-in-2025-idc.html'},
#  {'symbol': 'SMGZY',
#   'publishedDate': '2025-12-03 03:26:00',
#   'publisher': 'WSJ',
#   'title': 'Smiths Group to Sell Screening Technology Unit to CVC Capital Partners For $2.6 Billion',
#   'image': 'https://images.financialmodelingprep.com/news/smiths-group-to-sell-screening-technology-unit-to-cvc-20251203.jpg',
#   'site': 'wsj.com',
#   'text': 'The U.K. engineering company said that the completion is expected in the second half of 2026.',
#   'url': 'https://www.wsj.com/business/deals/smiths-group-to-sell-screening-technology-unit-to-cvc-capital-partners-for-2-6-billion-f11eeae1'},
#  {'symbol': 'LTUM',
#   'publishedDate': '2025-12-03 03:26:00',
#   'publisher': 'WSJ',
#   'title': 'Vulcan Energy Resources to Proceed With German Lithium Project',
#   'image': 'https://images.financialmodelingprep.com/news/vulcan-energy-resources-to-proceed-with-german-lithium-project-20251203.jpg',
#   'site': 'wsj.com',
#   'text': "Construction is to start in days after the company secured funds for the initial development of a sustainable lithium project for Europe's electric-vehicle battery industry.",
#   'url': 'https://www.wsj.com/business/energy-oil/vulcan-energy-resources-to-proceed-with-german-lithium-project-01667e95'},
#  {'symbol': 'AEO',
#   'publishedDate': '2025-12-03 03:23:28',
#   'publisher': 'Seeking Alpha',
#   'title': 'American Eagle Outfitters, Inc. (AEO) Q3 2026 Earnings Call Transcript',
#   'image': 'https://images.financialmodelingprep.com/news/american-eagle-outfitters-inc-aeo-q3-2026-earnings-call-20251203.jpg',
#   'site': 'seekingalpha.com',
#   'text': 'American Eagle Outfitters, Inc. ( AEO ) Q3 2026 Earnings Call December 2, 2025 4:30 PM EST Company Participants Judy Meehan - Senior Vice President of Corporate Communications & Investor Relations Jay Schottenstein - Executive Chairman of the Board & CEO Jennifer Foyle - President and Executive Creative Director of AE & Aerie Mike Mathias - Executive VP & CFO Conference Call Participants Jay Sole - UBS Investment Bank, Research Division Matthew Boss - JPMorgan Chase & Co, Research Division Kelly Crago - Citigroup Inc., Research Division Jungwon Kim - TD Cowen, Research Division Rakesh Patel - Raymond James & Associates, Inc., Research Division Christopher Nardone - BofA Securities, Research Division Alexandra Straton - Morgan Stanley, Research Division Janet Kloppenburg - JJK Research Associates, Inc. Janine Hoffman Stichter - BTIG, LLC, Research Division Corey Tarlowe - Jefferies LLC, Research Division Presentation Operator Welcome to the AEO Inc. Third Quarter 2025 Earnings Conference Call. [Operator Instructions] Please note this event is being recorded.',
#   'url': 'https://seekingalpha.com/article/4849672-american-eagle-outfitters-inc-aeo-q3-2026-earnings-call-transcript'},
#  {'symbol': 'VALE',
#   'publishedDate': '2025-12-03 03:23:26',
#   'publisher': 'Seeking Alpha',
#   'title': 'Vale S.A. (VALE) Analyst/Investor Day Transcript',
#   'image': 'https://images.financialmodelingprep.com/news/vale-sa-vale-analystinvestor-day-transcript-20251203.jpg',
#   'site': 'seekingalpha.com',
#   'text': 'Vale S.A. (VALE) Analyst/Investor Day Transcript',
#   'url': 'https://seekingalpha.com/article/4849327-vale-s-a-vale-analyst-investor-day-transcript'},
#  {'symbol': 'RIVN',
#   'publishedDate': '2025-12-03 03:21:09',
#   'publisher': 'Reuters',
#   'title': 'Rivian to recall nearly 35,000 US vehicles over seatbelt issue, says NHTSA',
#   'image': 'https://images.financialmodelingprep.com/news/rivian-to-recall-nearly-35000-us-vehicles-over-seatbelt-20251203.jpg',
#   'site': 'reuters.com',
#   'text': "Rivian Automotive plans to recall 34,824 U.S. vehicles due to a damaged seat belt pretension cable that may fail to properly restrain the driver's seat belt, increasing crash injury risk, the U.S. National Highway Traffic Safety Administration (NHTSA) said on Wednesday.",
#   'url': 'https://www.reuters.com/business/autos-transportation/rivian-recall-nearly-35000-us-vehicles-over-seatbelt-issue-says-nhtsa-2025-12-03/'},
#  {'symbol': 'SMGZY',
#   'publishedDate': '2025-12-03 03:18:24',
#   'publisher': 'Proactive Investors',
#   'title': 'Smiths Group shares rise after agreeing £2bn sale of Detection unit to CVC',
#   'image': 'https://images.financialmodelingprep.com/news/smiths-group-shares-rise-after-agreeing-2bn-sale-of-20251203.jpg',
#   'site': 'proactiveinvestors.co.uk',
#   'text': 'Smiths Group shares opened almost 3% higher at 2,494p this morning after the engineering group agreed to sell its security screening division, Smiths Detection, to funds advised by CVC Capital Partners for £2 billion. The deal values the business at 16.3 times its most recent annual operating profit of £122 million and 12.5 times EBITDA of £160 million for the year to the end of July 2025.',
#   'url': 'https://www.proactiveinvestors.co.uk/companies/news/1083662'},
#  {'symbol': 'LTUM',
#   'publishedDate': '2025-12-03 03:15:00',
#   'publisher': 'Business Wire',
#   'title': 'E3 Lithium Successfully Completes the Drilling Portion of Its Phase 2 Demonstration Program and Provides a Leadership Update',
#   'image': 'https://images.financialmodelingprep.com/news/e3-lithium-successfully-completes-the-drilling-portion-of-its-20251203.jpg',
#   'site': 'businesswire.com',
#   'text': "CALGARY, Alberta--(BUSINESS WIRE)--E3 LITHIUM LTD. (TSXV: ETL) (FSE: OW3) (OTCQX: EEMMF), (“E3 Lithium” or the “Company”) a leader in Canadian lithium development, has successfully drilled its brine production and injection wells at its Demonstration Facility in central Alberta. This achievement marks a milestone in Phase 2 of the Company's Demonstration Facility program. The vertical production and deviated injection wells are E3 Lithium's third and fourth wells into the Leduc Formation, and t.",
#   'url': 'https://www.businesswire.com/news/home/20251203932719/en/E3-Lithium-Successfully-Completes-the-Drilling-Portion-of-Its-Phase-2-Demonstration-Program-and-Provides-a-Leadership-Update/'},
#  {'symbol': 'RARE',
#   'publishedDate': '2025-12-03 03:13:27',
#   'publisher': 'Seeking Alpha',
#   'title': 'Ultragenyx Pharmaceutical Inc. (RARE) Presents at Citi Annual Global Healthcare Conference 2025 Transcript',
#   'image': 'https://images.financialmodelingprep.com/news/ultragenyx-pharmaceutical-inc-rare-presents-at-citi-annual-global-20251203.jpg',
#   'site': 'seekingalpha.com',
#   'text': 'Ultragenyx Pharmaceutical Inc. (RARE) Presents at Citi Annual Global Healthcare Conference 2025 Transcript',
#   'url': 'https://seekingalpha.com/article/4849530-ultragenyx-pharmaceutical-inc-rare-presents-at-citi-annual-global-healthcare-conference-2025'},
#  {'symbol': 'TSLL',
#   'publishedDate': '2025-12-03 03:12:44',
#   'publisher': 'Seeking Alpha',
#   'title': "TSLL: Less Favorite Active Play With Tesla's Sustained Volatility",
#   'image': 'https://images.financialmodelingprep.com/news/tsll-less-favorite-active-play-with-teslas-sustained-volatility-20251203.jpg',
#   'site': 'seekingalpha.com',
#   'text': 'Tesla leads AI-driven industrial automation, with rapid advances in autonomous driving, robotics, and manufacturing technology. TSLA\'s high valuation isn\'t justified by near-term earnings growth, causing the extreme volatility for its 2x leveraged ETF TSLL. Investing in TSLL will require heavy management overhead for investors to do a very difficult "timing" job, making it not suitable for individual investors.',
#   'url': 'https://seekingalpha.com/article/4849651-tsll-less-favorite-active-play-with-tesla-sustained-volatility'},
#  {'symbol': 'QMCO',
#   'publishedDate': '2025-12-03 03:12:00',
#   'publisher': 'Business Wire',
#   'title': 'Horizon Quantum Becomes First Quantum Software Company to Own and Operate a Quantum Computer',
#   'image': 'https://images.financialmodelingprep.com/news/horizon-quantum-becomes-first-quantum-software-company-to-own-20251203.jpg',
#   'site': 'businesswire.com',
#   'text': "SINGAPORE--(BUSINESS WIRE)--Horizon Quantum Computing Pte. Ltd. (“Horizon Quantum”), a pioneer of software infrastructure for quantum applications, today announced that it has completed the assembly and integration of a first quantum computer at its Singapore headquarters. The system is now fully operational. Assembled from components and operated directly by Horizon Quantum's team, this system makes Horizon Quantum the first quantum software company to own and run a quantum computer. Horizon Q.",
#   'url': 'https://www.businesswire.com/news/home/20251202828187/en/Horizon-Quantum-Becomes-First-Quantum-Software-Company-to-Own-and-Operate-a-Quantum-Computer/'},
#  {'symbol': 'EADSF',
#   'publishedDate': '2025-12-03 03:11:27',
#   'publisher': 'Reuters',
#   'title': "UK's Senior wins contract with Airbus for aerospace parts",
#   'image': 'https://images.financialmodelingprep.com/news/uks-senior-wins-contract-with-airbus-for-aerospace-parts-20251203.jpg',
#   'site': 'reuters.com',
#   'text': 'British engineering firm Senior said on Wednesday it had secured a multi-year contract from Airbus to design and manufacture highly engineered aerospace parts for fluid conveyance systems on aircraft.',
#   'url': 'https://www.reuters.com/business/aerospace-defense/uks-senior-wins-contract-with-airbus-aerospace-parts-2025-12-03/'},
#  {'symbol': 'HPE',
#   'publishedDate': '2025-12-03 03:10:00',
#   'publisher': 'Business Wire',
#   'title': 'Veeam and HPE Extend Strategic Partnership and Unveil Next-Gen Data Protection to Supercharge Enterprise Resilience',
#   'image': 'https://images.financialmodelingprep.com/news/veeam-and-hpe-extend-strategic-partnership-and-unveil-nextgen-20251203.jpg',
#   'site': 'businesswire.com',
#   'text': 'BARCELONA, Spain--(BUSINESS WIRE)-- #DataProtection--HPE and Veeam unleash transformative, integrated solutions designed to empower enterprises with simplified data resilience for the modern enterprise.',
#   'url': 'https://www.businesswire.com/news/home/20251203727868/en/Veeam-and-HPE-Extend-Strategic-Partnership-and-Unveil-Next-Gen-Data-Protection-to-Supercharge-Enterprise-Resilience/'},
#  {'symbol': 'YORW',
#   'publishedDate': '2025-12-03 03:06:00',
#   'publisher': 'The Motley Fool',
#   'title': "Wall Street's Greatest Dividend Stock -- Which 99% of Investors Have No Clue Exists -- Makes for a Screaming Buy in 2026",
#   'image': 'https://images.financialmodelingprep.com/news/wall-streets-greatest-dividend-stock-which-99-of-investors-20251203.jpg',
#   'site': 'fool.com',
#   'text': 'Dividend stocks have more than doubled the average annual return of non-payers over the previous 51 years. Only around two dozen public companies (out of more than 5,500 listings) have been paying a continuous dividend for at least 100 years.',
#   'url': 'https://www.fool.com/investing/2025/12/03/wall-street-greatest-dividend-stock-buy-in-2026/'},
#  {'symbol': 'JUBAF',
#   'publishedDate': '2025-12-03 03:05:00',
#   'publisher': 'TheNewswire',
#   'title': 'Giant Mining Corp. Advances Metallurgical Test Work at Majuba Hill Nevada Copper-Silver-Gold Project as Metal Prices Hit Records',
#   'image': 'https://images.financialmodelingprep.com/news/giant-mining-corp-advances-metallurgical-test-work-at-majuba-20251203.jpg',
#   'site': 'thenewswire.com',
#   'text': "VANCOUVER, BC — TheNewswire - December 3, 2025 — Giant Mining Corp. (CSE: BFG | OTC: BFGFF | FWB: YW5 | CSE: BFG.WT.A | CSE: BFG.WT.B.) (“Giant Mining” or the “Company”) is pleased to announce that it is planning to undertake additional metallurgical test work to update and expand upon historical metallurgy completed at its Majuba Hill Copper-Silver-Gold Project in Pershing County, Nevada. The additional metallurgical work will refine the Company's understanding of copper, silver, and gold recoveries across oxide, transition, and sulphide zones within the Majuba Hill porphyry system.",
#   'url': 'https://www.thenewswire.com/press-releases/1k49Fy1qg-giant-mining-corp-advances-metallurgical-test-work-at-majuba-hill-nevada-copper-silver-gold-project-as-metal-prices-hit-records.html'},
#  {'symbol': 'JBI',
#   'publishedDate': '2025-12-03 03:00:18',
#   'publisher': 'Seeking Alpha',
#   'title': 'Janus International: A Cash Flow Machine Priced For Liquidation',
#   'image': 'https://images.financialmodelingprep.com/news/janus-international-a-cash-flow-machine-priced-for-liquidation-20251203.jpg',
#   'site': 'seekingalpha.com',
#   'text': "Janus International is undervalued, with the market overly discounting past guidance misses and cyclical fears despite stabilising fundamentals. JBI's resilient cash flow, strong margins, and recent S&P credit upgrade highlight its capital-light model and balance sheet strength, even at cycle lows. International growth and Nokē's high-margin recurring revenue provide underappreciated upside, while core US self-storage finds a bottom.",
#   'url': 'https://seekingalpha.com/article/4849646-janus-international-cash-flow-machine-priced-for-liquidation'}]

# %%
@mcp.tool()
async def stock_news_search(symbols: str, page: int = 0, limit: int = 20, date_from: Optional[str] = None, date_to: Optional[str] = None) -> Any:
    """Search Stock News API — company-specific news by symbols.

    Use this when:
      • You need news filtered for specific tickers (e.g., AAPL, MSFT).
      • You’re building a per-company news panel.

    Don’t use when:
      • You want broad/latest headlines without filter (use stock_news_latest).
      • You’re seeking transcripts/filings.

    Endpoint: `/stable/news/stock`

    What it provides:
      • **Targeted News** filtered by `symbols` (comma-separated tickers), including headline,
        publisher, snippet, URL, and publish timestamp.

    Args:
      symbols: Comma-separated tickers (e.g., "AAPL,MSFT").
      page: Zero-based page index (max page ~100).
      limit: Page size (max 250).
      date_from: Optional start date `YYYY-MM-DD`.
      date_to: Optional end date `YYYY-MM-DD`.

    Returns:
      A list of news items for the requested symbols.
    """
    params: Dict[str, Any] = {"symbols": symbols, "page": page, "limit": limit}
    if date_from:
        params["from"] = date_from
    if date_to:
        params["to"] = date_to
    return await fmp_api_request("news/stock", params)

# %%
await stock_news_search("AAPL")
# Out:
# [{'symbol': 'AAPL',
#   'publishedDate': '2025-12-03 03:28:01',
#   'publisher': 'CNBC',
#   'title': 'iPhone 17 will drive record Apple shipments in 2025, IDC says',
#   'image': 'https://images.financialmodelingprep.com/news/iphone-17-will-drive-record-apple-shipments-in-2025-20251203.jpg',
#   'site': 'cnbc.com',
#   'text': 'Apple will ship 247.4 million iPhones in 2025, up just over 6% year-on-year, IDC has forecast. This is higher than its previous record year, 2021, when the iPhone 13 was released.',
#   'url': 'https://www.cnbc.com/2025/12/03/iphone-17-will-drive-record-apple-shipments-in-2025-idc.html'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 17:34:00',
#   'publisher': 'GuruFocus',
#   'title': 'Market Today: Deal Talks, Retail Wins, AI Chips, and Crypto Volatility',
#   'image': 'https://images.financialmodelingprep.com/news/market-today-deal-talks-retail-wins-ai-chips-and-20251202.png',
#   'site': 'gurufocus.com',
#   'text': "Stock News Dell family's $6.25B pledge to kids' accounts: Dell Technologies (DELL) founder Michael Dell (Trades, Portfolio) and Susan Dell committed $6.25 billi",
#   'url': 'https://www.gurufocus.com/news/3231020/market-today-deal-talks-retail-wins-ai-chips-and-crypto-volatility'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 16:15:15',
#   'publisher': 'Zacks Investment Research',
#   'title': 'The 3 Best Magnificent 7 Stocks for 2026 (GOOGL, AAPL, TSLA)',
#   'image': 'https://images.financialmodelingprep.com/news/the-3-best-magnificent-7-stocks-for-2026-googl-20251202.jpg',
#   'site': 'zacks.com',
#   'text': "Last month's volatility brought a bit more than a 5% decline in the major indices, but the real damage occurred beneath the surface, where speculative pockets of the market corrected sharply. For now, it appears that phase of selling has passed.",
#   'url': 'https://www.zacks.com/commentary/2798551/the-3-best-magnificent-7-stocks-for-2026-googl-aapl-tsla?cid=CS-STOCKNEWSAPI-FT-investment_ideas-2798551'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 16:11:20',
#   'publisher': 'CNBC Television',
#   'title': "Beyond time for Apple to go in new direction with AI leadership: Big Technology's Alex Kantrowitz",
#   'image': 'https://images.financialmodelingprep.com/news/beyond-time-for-apple-to-go-in-new-direction-20251202.jpg',
#   'site': 'youtube.com',
#   'text': "Big Technology's Alex Kantrowitz joins 'Closing Bell' to discuss Apple's AI position, its leadership shakeup and much more.",
#   'url': 'https://www.youtube.com/watch?v=dV_OkYYbkpQ'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 16:09:05',
#   'publisher': 'Proactive Investors',
#   'title': 'Apple shakes up AI leadership team ahead of mid-2026 Siri relaunch',
#   'image': 'https://images.financialmodelingprep.com/news/apple-shakes-up-ai-leadership-team-ahead-of-mid2026-20251202.jpg',
#   'site': 'proactiveinvestors.com',
#   'text': "Apple Inc (NASDAQ:AAPL, XETRA:APC) announced a major change to its AI leadership team with the departure of John Giannandrea, its senior vice president for Machine Learning and AI Strategy. Giannandrea, who spent seven years overseeing the company's AI roadmap, will remain in an advisory role through spring 2026 before retiring.",
#   'url': 'https://www.proactiveinvestors.com/companies/news/1083629'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 15:00:33',
#   'publisher': 'Schwab Network',
#   'title': 'Former GOOGL Gemini Engineer Heads AAPL A.I. Amid Lagging Position',
#   'image': 'https://images.financialmodelingprep.com/news/former-googl-gemini-engineer-heads-aapl-ai-amid-lagging-20251202.jpg',
#   'site': 'youtube.com',
#   'text': "John Giannandrea, Apple's (AAPL) A.I. chief, is stepping down and offering his seat to a former lead engineer for Alphabet's (GOOGL) Google Gemini.",
#   'url': 'https://www.youtube.com/watch?v=PYcTb7-pnic'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 14:06:42',
#   'publisher': 'New York Post',
#   'title': 'Apple shakes up AI team as top exec John Giannandrea steps down',
#   'image': 'https://images.financialmodelingprep.com/news/apple-shakes-up-ai-team-as-top-exec-john-20251202.jpg',
#   'site': 'nypost.com',
#   'text': "Apple's artificial intelligence chief John Giannandrea is stepping down from his role as part of a major shakeup of the troubled division, the company announced late Monday.",
#   'url': 'https://nypost.com/2025/12/02/business/apple-shakes-up-ai-team-as-exec-john-giannandrea-steps-down/'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 12:16:53',
#   'publisher': 'Invezz',
#   'title': 'Apple news may not be as big for Intel stock as markets are making it to be',
#   'image': 'https://images.financialmodelingprep.com/news/apple-news-may-not-be-as-big-for-intel-20251202.jpg',
#   'site': 'invezz.com',
#   'text': "Intel (NASDAQ: INTC) has been in a sharp uptrend in recent sessions following news that Apple (NASDAQ: AAPL) could become its foundry customer by early 2027. However, while symbolically important for sure, the expected agreement looks more like supply-chain hedging than a structural shift in the iPhone maker's broader silicon strategy.",
#   'url': 'https://invezz.com/news/2025/12/02/apple-news-may-not-be-as-big-for-intel-stock-as-markets-are-making-it-to-be/'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 12:16:00',
#   'publisher': 'GuruFocus',
#   'title': 'Apple Hires Google Veteran As New AI Leader',
#   'image': 'https://images.financialmodelingprep.com/news/apple-hires-google-veteran-as-new-ai-leader-20251202.png',
#   'site': 'gurufocus.com',
#   'text': 'Apple (AAPL) is reshaping its AI leadership team, bringing in longtime Google engineer Amar Subramanya as its new vice president of AI while announcing that Joh',
#   'url': 'https://www.gurufocus.com/news/3229842/apple-hires-google-veteran-as-new-ai-leader'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 11:51:45',
#   'publisher': '24/7 Wall Street',
#   'title': 'Peter Thiel Sells All His Nvidia Shares and Buys Microsoft and Apple Instead',
#   'image': 'https://images.financialmodelingprep.com/news/peter-thiel-sells-all-his-nvidia-shares-and-buys-20251202.jpg',
#   'site': '247wallst.com',
#   'text': 'Billionaire Peter Thiel runs the hedge fund Thiel Macro and is known for playing a significant role in identifying growth stocks.',
#   'url': 'https://247wallst.com/investing/2025/12/02/peter-thiel-sells-all-his-nvidia-shares-and-buys-microsoft-and-apple-instead/'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 11:37:14',
#   'publisher': '24/7 Wall Street',
#   'title': "Warren Buffett's 52% Portfolio Rests on These Three Dividend Giants",
#   'image': 'https://images.financialmodelingprep.com/news/warren-buffetts-52-portfolio-rests-on-these-three-dividend-20251202.jpg',
#   'site': '247wallst.com',
#   'text': 'A globally recognized investor, Warren Buffett is one of the greatest investors of all time.',
#   'url': 'https://247wallst.com/investing/2025/12/02/warren-buffetts-52-portfolio-rests-on-these-three-dividend-giants/'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 11:04:52',
#   'publisher': 'New York Post',
#   'title': 'Samsung unveils first triple-folding phone ahead of expected Apple launch — but it will cost you',
#   'image': 'https://images.financialmodelingprep.com/news/samsung-unveils-first-triplefolding-phone-ahead-of-expected-apple-20251202.jpg',
#   'site': 'nypost.com',
#   'text': "The device features\xa0Samsung's largest battery in its flagship models and supports super-fast charging that powers the phone to 50% in 30 minutes.",
#   'url': 'https://nypost.com/2025/12/02/business/samsung-unveils-galaxy-z-trifold-phone-as-competition-with-apple-heats-up/'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 11:01:00',
#   'publisher': 'Proactive Investors - Finance',
#   'title': 'Apple shakes up AI leadership team ahead of mid-2026 Siri relaunch',
#   'image': 'https://images.financialmodelingprep.com/news/apple-shakes-up-ai-leadership-team-ahead-of-mid2026-20251202.jpeg',
#   'site': 'proactiveinvestors.com',
#   'text': 'Apple Inc (NASDAQ:AAPL, XETRA:APC) announced a major change to its AI leadership team with the departure of John Giannandrea, its senior vice president for...',
#   'url': 'https://www.proactiveinvestors.com/companies/news/1083629/apple-shakes-up-ai-leadership-team-ahead-of-mid-2026-siri-relaunch-1083629.html'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 10:30:55',
#   'publisher': '24/7 Wall Street',
#   'title': 'Wall Street Bulls are Pounding the Table Over Amazon, Eli Lilly, and Apple',
#   'image': 'https://images.financialmodelingprep.com/news/wall-street-bulls-are-pounding-the-table-over-amazon-20251202.jpg',
#   'site': '247wallst.com',
#   'text': 'Analysts at Bernstein just reiterated an outperform rating on Apple (',
#   'url': 'https://247wallst.com/investing/2025/12/02/wall-street-bulls-are-pounding-the-table-over-amazon-eli-lilly-and-apple/'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 10:15:06',
#   'publisher': 'Schwab Network',
#   'title': "Bitcoin's Signal for High Beta Stock Trading, AAPL Strength in A.I. Shakedown",
#   'image': 'https://images.financialmodelingprep.com/news/bitcoins-signal-for-high-beta-stock-trading-aapl-strength-20251202.jpg',
#   'site': 'youtube.com',
#   'text': "Andrew Wang sees the Fed's December meeting next week as one of the final market catalysts of the year, urging investors to stay on their toes after rate cut chances spiked in the last couple week. Bitcoin's price action is another factor he believes will serve as a critical signal for high beta appetite.",
#   'url': 'https://www.youtube.com/watch?v=QXzCpmrAwgg'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 08:51:56',
#   'publisher': '24/7 Wall Street',
#   'title': '30% of the S&P 500 Is Mag 7 Tech Stocks, but This ETF Refuses to Own a Single One',
#   'image': 'https://images.financialmodelingprep.com/news/30-of-the-sp-500-is-mag-7-tech-20251202.jpg',
#   'site': '247wallst.com',
#   'text': 'The Magnificent 7 AI tech stocks have served as the rocket fuel propelling the S&P 500 on its bull run over the past few years.',
#   'url': 'https://247wallst.com/investing/2025/12/02/a-perfect-wide-moat-investment-without-any-mag7-exposure/'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 08:27:00',
#   'publisher': 'Barrons',
#   'title': 'Apple Plans a Folding Smartphone. Samsung Is Going One Better.',
#   'image': 'https://images.financialmodelingprep.com/news/apple-plans-a-folding-smartphone-samsung-is-going-one-20251202.jpg',
#   'site': 'barrons.com',
#   'text': 'Apple is reported to be planning its first foldable smartphone in 2026 but Samsung has a more dramatic innovation in mind.',
#   'url': 'https://www.barrons.com/articles/apple-stock-foldable-iphone-samsung-trifold-7d503a99'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 08:14:38',
#   'publisher': 'Benzinga',
#   'title': "Nike, Apple, Amazon And An Airline Stock: CNBC's 'Final Trades'",
#   'image': 'https://images.financialmodelingprep.com/news/nike-apple-amazon-and-an-airline-stock-cnbcs-final-20251202.jpeg',
#   'site': 'feeds.benzinga.com',
#   'text': 'Bryn Talkington of Requisite Capital Management picked Nike. Wells Fargo recently upgraded Nike from Equal-Weight to Overweight.',
#   'url': 'https://www.benzinga.com/analyst-stock-ratings/analyst-color/25/12/49157440/nike-apple-amazon-and-an-airline-stock-cnbcs-final-trades'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 08:02:34',
#   'publisher': 'CNBC',
#   'title': "Apple's AI leadership, Costco's tariff lawsuit, Cyber Monday Shopify outage and more in Morning Squawk",
#   'image': 'https://images.financialmodelingprep.com/news/apples-ai-leadership-costcos-tariff-lawsuit-cyber-monday-shopify-20251202.jpg',
#   'site': 'cnbc.com',
#   'text': "The three major indexes broke five-day winning streaks. Apple's head of artificial intelligence is stepping down.",
#   'url': 'https://www.cnbc.com/2025/12/02/5-things-to-know-before-the-stock-market-opens.html'},
#  {'symbol': 'AAPL',
#   'publishedDate': '2025-12-02 07:38:00',
#   'publisher': 'GuruFocus',
#   'title': 'First Look: Versace deal, crypto slump, WBD bids and Airbus woes',
#   'image': 'https://images.financialmodelingprep.com/news/first-look-versace-deal-crypto-slump-wbd-bids-and-20251202.png',
#   'site': 'gurufocus.com',
#   'text': 'Stock News Prada acquires Versace: Prada Group (HKG:1913) completed a â\x82¬1.25 billion deal to buy Versace from Capri Holdings (CPRI), bringing the brand under t',
#   'url': 'https://www.gurufocus.com/news/3229645/first-look-versace-deal-crypto-slump-wbd-bids-and-airbus-woes'}]

# %%
@mcp.tool()
async def insider_trading_latest(page: int = 0, limit: int = 100, date: Optional[str] = None) -> Any:
    """Latest Insider Trading API — recent buys/sells by corporate insiders.

    Use this when:
      • You want recent insider buys/sells with roles, amounts, and forms.
      • You’re screening for notable insider activity.

    Don’t use when:
      • You need ticker-filtered insider traders (use insider_trading_search with symbols).
      • You need ownership cap tables or institutional holders (different endpoints).
      • You want price series or ratios.
      

    Endpoint: `/stable/insider-trading/latest`

    What it provides:
      • **Recent Transactions**: Insider purchases/sales with `transactionDate`, `formType` (e.g., 4),
        share counts, and prices.
      • **Actor & Role**: Insider’s name and role (e.g., director, officer), direct/indirect ownership.
      • **Regulatory Links**: Direct links to SEC filing pages where available.

    Args:
      page: Zero-based page index (max page ~100).
      limit: Number of records per page (max 1000).
      date: Optional specific date `YYYY-MM-DD` to filter.

    Returns:
      A list of recent insider transactions across the market.
    """
    params: Dict[str, Any] = {"page": page, "limit": limit}
    if date:
        params["date"] = date
    return await fmp_api_request("insider-trading/latest", params)

# %%
await insider_trading_latest()
# Out:
# [{'symbol': 'HCWC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0002029546',
#   'companyCik': '0001948864',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 200000,
#   'reportingName': 'Lerman Michael Stuart',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 200000,
#   'price': 0,
#   'securityName': 'Restricted Class A Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1948864/000149315225025840/0001493152-25-025840-index.htm'},
#  {'symbol': 'HCWC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0001692547',
#   'companyCik': '0001948864',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 400000,
#   'reportingName': 'Ollet John',
#   'typeOfOwner': 'director, officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 400000,
#   'price': 0,
#   'securityName': 'Class A Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1948864/000149315225025842/0001493152-25-025842-index.htm'},
#  {'symbol': 'HCWC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0001512158',
#   'companyCik': '0001948864',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 800000,
#   'reportingName': 'Holman Jeffrey Elliot',
#   'typeOfOwner': 'director, officer: Chief Executive Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 800000,
#   'price': 0,
#   'securityName': 'Restricted Class A Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1948864/000149315225025839/0001493152-25-025839-index.htm'},
#  {'symbol': 'HCWC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0002029726',
#   'companyCik': '0001948864',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 200000,
#   'reportingName': 'Bodzin Gary',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 200000,
#   'price': 0,
#   'securityName': 'Restricted Class A Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1948864/000149315225025838/0001493152-25-025838-index.htm'},
#  {'symbol': 'HCWC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0001564870',
#   'companyCik': '0001948864',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 400000,
#   'reportingName': 'Santi Christopher',
#   'typeOfOwner': 'officer: President',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 400000,
#   'price': 0,
#   'securityName': 'Class A Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1948864/000149315225025843/0001493152-25-025843-index.htm'},
#  {'symbol': 'HCWC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0002029962',
#   'companyCik': '0001948864',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 200000,
#   'reportingName': 'Myers Behnam',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 200000,
#   'price': 0,
#   'securityName': 'Restricted Class A Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1948864/000149315225025841/0001493152-25-025841-index.htm'},
#  {'symbol': 'SKIL',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-15',
#   'reportingCik': '0002098591',
#   'companyCik': '0001774675',
#   'transactionType': '',
#   'securitiesOwned': 0,
#   'reportingName': 'Nikolaev Denis',
#   'typeOfOwner': '',
#   'acquisitionOrDisposition': '',
#   'directOrIndirect': None,
#   'formType': '3',
#   'securitiesTransacted': 0,
#   'price': 0,
#   'securityName': '',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1774675/000209859125000002/0002098591-25-000002-index.htm'},
#  {'symbol': 'IAC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001834403',
#   'companyCik': '0001800227',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 48776,
#   'reportingName': 'Handler Kendall',
#   'typeOfOwner': 'officer: EVP & CLO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 21618,
#   'price': 0,
#   'securityName': 'Common Stock, par value $0.0001',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1800227/000162828025054894/0001628280-25-054894-index.htm'},
#  {'symbol': 'IAC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001834403',
#   'companyCik': '0001800227',
#   'transactionType': 'F-InKind',
#   'securitiesOwned': 37740,
#   'reportingName': 'Handler Kendall',
#   'typeOfOwner': 'officer: EVP & CLO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 11036,
#   'price': 35.07,
#   'securityName': 'Common Stock, par value $0.0001',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1800227/000162828025054894/0001628280-25-054894-index.htm'},
#  {'symbol': 'IAC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001834403',
#   'companyCik': '0001800227',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 89134,
#   'reportingName': 'Handler Kendall',
#   'typeOfOwner': 'officer: EVP & CLO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 51394,
#   'price': 0,
#   'securityName': 'Common Stock, par value $0.0001',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1800227/000162828025054894/0001628280-25-054894-index.htm'},
#  {'symbol': 'IAC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001834403',
#   'companyCik': '0001800227',
#   'transactionType': 'F-InKind',
#   'securitiesOwned': 62897,
#   'reportingName': 'Handler Kendall',
#   'typeOfOwner': 'officer: EVP & CLO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 26237,
#   'price': 35.07,
#   'securityName': 'Common Stock, par value $0.0001',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1800227/000162828025054894/0001628280-25-054894-index.htm'},
#  {'symbol': 'IAC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001834403',
#   'companyCik': '0001800227',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'Handler Kendall',
#   'typeOfOwner': 'officer: EVP & CLO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 51394,
#   'price': 0,
#   'securityName': 'Restricted Stock Units',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1800227/000162828025054894/0001628280-25-054894-index.htm'},
#  {'symbol': 'NOW',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001831384',
#   'companyCik': '0001373715',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 323,
#   'reportingName': 'Jackson Lawrence',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 265,
#   'price': 810.22,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1373715/000183138425000006/0001831384-25-000006-index.htm'},
#  {'symbol': 'NOW',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001659774',
#   'companyCik': '0001373715',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 9586,
#   'reportingName': 'Chamberlain Paul Edward',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 300,
#   'price': 808,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1373715/000165977425000006/0001659774-25-000006-index.htm'},
#  {'symbol': 'NOW',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001465391',
#   'companyCik': '0001373715',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 12643,
#   'reportingName': 'Mastantuono Gina',
#   'typeOfOwner': 'officer: President and CFO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 417,
#   'price': 808,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1373715/000146539125000021/0001465391-25-000021-index.htm'},
#  {'symbol': 'SRZN',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0001614186',
#   'companyCik': '0001824893',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 852482,
#   'reportingName': 'Kutzkey Tim',
#   'typeOfOwner': 'director, 10 percent owner: ',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 148150,
#   'price': 12.65,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1824893/000119312525305738/0001193125-25-305738-index.htm'},
#  {'symbol': 'SRZN',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-13',
#   'reportingCik': '0001614186',
#   'companyCik': '0001824893',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 962718,
#   'reportingName': 'Kutzkey Tim',
#   'typeOfOwner': 'director, 10 percent owner: ',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 167307,
#   'price': 12.65,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1824893/000119312525305738/0001193125-25-305738-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001741453',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 171696,
#   'reportingName': 'Abbott Swati Bargotra',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 48222,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305731/0001193125-25-305731-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001495110',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 2031922,
#   'reportingName': 'Braunstein Douglas L',
#   'typeOfOwner': 'director, 10 percent owner: ',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 5725,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305730/0001193125-25-305730-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001495110',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 2080144,
#   'reportingName': 'Braunstein Douglas L',
#   'typeOfOwner': 'director, 10 percent owner: ',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 48222,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305730/0001193125-25-305730-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-02',
#   'reportingCik': '0001868782',
#   'companyCik': '0001803901',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 234813,
#   'reportingName': 'Margolin Gil',
#   'typeOfOwner': 'officer: Chief Technology Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3516,
#   'price': 0.88,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305729/0001193125-25-305729-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-02',
#   'reportingCik': '0001868782',
#   'companyCik': '0001803901',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 231297,
#   'reportingName': 'Margolin Gil',
#   'typeOfOwner': 'officer: Chief Technology Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3516,
#   'price': 3.15,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305729/0001193125-25-305729-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001868782',
#   'companyCik': '0001803901',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'Margolin Gil',
#   'typeOfOwner': 'officer: Chief Technology Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3516,
#   'price': 0.88,
#   'securityName': 'Stock Options',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305729/0001193125-25-305729-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001868683',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 337645,
#   'reportingName': 'Pawar Madhu',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3014,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305728/0001193125-25-305728-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001868683',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 385867,
#   'reportingName': 'Pawar Madhu',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 48222,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305728/0001193125-25-305728-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001318063',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 356812,
#   'reportingName': 'YEANEY JACQUELINE E',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 48222,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305727/0001193125-25-305727-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0002003709',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 156276,
#   'reportingName': 'Benzur Liat',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 48222,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305726/0001193125-25-305726-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001601099',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 373738,
#   'reportingName': 'Shachar Erez',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3768,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305725/0001193125-25-305725-index.htm'},
#  {'symbol': 'TALK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001601099',
#   'companyCik': '0001803901',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 421960,
#   'reportingName': 'Shachar Erez',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 48222,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1803901/000119312525305725/0001193125-25-305725-index.htm'},
#  {'symbol': 'TONX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001623811',
#   'companyCik': '0001566610',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 475387,
#   'reportingName': 'CUTAIA RORY J.',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 33543,
#   'price': 3.445,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1566610/000149315225025835/0001493152-25-025835-index.htm'},
#  {'symbol': 'TONX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001623811',
#   'companyCik': '0001566610',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 438904,
#   'reportingName': 'CUTAIA RORY J.',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 36483,
#   'price': 3.129,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1566610/000149315225025835/0001493152-25-025835-index.htm'},
#  {'symbol': 'TONX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-02',
#   'reportingCik': '0001623811',
#   'companyCik': '0001566610',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 331181,
#   'reportingName': 'CUTAIA RORY J.',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 107723,
#   'price': 3.081,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1566610/000149315225025835/0001493152-25-025835-index.htm'},
#  {'symbol': 'PLAB',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001367036',
#   'companyCik': '0000810136',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 190591,
#   'reportingName': 'Progler Christopher J',
#   'typeOfOwner': 'officer: EVP, Chief Technology Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 10000,
#   'price': 22.515,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/810136/000114036125044075/0001140361-25-044075-index.htm'},
#  {'symbol': 'ISSC',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-20',
#   'reportingCik': '0001546928',
#   'companyCik': '0000836690',
#   'transactionType': 'F-InKind',
#   'securitiesOwned': 484399,
#   'reportingName': 'Askarpour Shahram',
#   'typeOfOwner': 'director, officer: Chief Executive Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4/A',
#   'securitiesTransacted': 87918,
#   'price': 8.42,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/836690/000110465925117861/0001104659-25-117861-index.htm'},
#  {'symbol': 'SKAS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001236945',
#   'companyCik': '0001128281',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 261029,
#   'reportingName': 'WACHTEL WILLIAM B',
#   'typeOfOwner': 'director, 10 percent owner, officer: President and CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3333,
#   'price': 2.58,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1128281/000089183925000161/0000891839-25-000161-index.htm'},
#  {'symbol': 'SKAS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001236945',
#   'companyCik': '0001128281',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 264362,
#   'reportingName': 'WACHTEL WILLIAM B',
#   'typeOfOwner': 'director, 10 percent owner, officer: President and CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3333,
#   'price': 2.58,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1128281/000089183925000161/0000891839-25-000161-index.htm'},
#  {'symbol': 'SKAS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001236945',
#   'companyCik': '0001128281',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 267695,
#   'reportingName': 'WACHTEL WILLIAM B',
#   'typeOfOwner': 'director, 10 percent owner, officer: President and CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3333,
#   'price': 3.45,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1128281/000089183925000161/0000891839-25-000161-index.htm'},
#  {'symbol': 'SKAS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001236945',
#   'companyCik': '0001128281',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 271028,
#   'reportingName': 'WACHTEL WILLIAM B',
#   'typeOfOwner': 'director, 10 percent owner, officer: President and CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3333,
#   'price': 3.45,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1128281/000089183925000161/0000891839-25-000161-index.htm'},
#  {'symbol': 'SKAS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001236945',
#   'companyCik': '0001128281',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'WACHTEL WILLIAM B',
#   'typeOfOwner': 'director, 10 percent owner, officer: President and CEO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3333,
#   'price': 2.58,
#   'securityName': 'Stock Option (Right to Buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1128281/000089183925000161/0000891839-25-000161-index.htm'},
#  {'symbol': 'SKAS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001236945',
#   'companyCik': '0001128281',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'WACHTEL WILLIAM B',
#   'typeOfOwner': 'director, 10 percent owner, officer: President and CEO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3333,
#   'price': 3.45,
#   'securityName': 'Stock Option (Right to Buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1128281/000089183925000161/0000891839-25-000161-index.htm'},
#  {'symbol': 'SKAS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001236945',
#   'companyCik': '0001128281',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 3333,
#   'reportingName': 'WACHTEL WILLIAM B',
#   'typeOfOwner': 'director, 10 percent owner, officer: President and CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3333,
#   'price': 6.8,
#   'securityName': 'Stock Option (Right to Buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1128281/000089183925000161/0000891839-25-000161-index.htm'},
#  {'symbol': 'ATLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001608103',
#   'companyCik': '0001540684',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 277894,
#   'reportingName': 'Noriega Roger',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2307,
#   'price': 5.09,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1540684/000149315225025820/0001493152-25-025820-index.htm'},
#  {'symbol': 'ATLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001608103',
#   'companyCik': '0001540684',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 272894,
#   'reportingName': 'Noriega Roger',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 5000,
#   'price': 5.04,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1540684/000149315225025820/0001493152-25-025820-index.htm'},
#  {'symbol': 'ATLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001608103',
#   'companyCik': '0001540684',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 265201,
#   'reportingName': 'Noriega Roger',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 7693,
#   'price': 5,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1540684/000149315225025820/0001493152-25-025820-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001033331',
#   'companyCik': '0001065280',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 379410,
#   'reportingName': 'HASTINGS REED',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 375470,
#   'price': 10.57,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000472/0001065280-25-000472-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001033331',
#   'companyCik': '0001065280',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 342507,
#   'reportingName': 'HASTINGS REED',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 36903,
#   'price': 106.8509,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000472/0001065280-25-000472-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001033331',
#   'companyCik': '0001065280',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 201912,
#   'reportingName': 'HASTINGS REED',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 140595,
#   'price': 108.1975,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000472/0001065280-25-000472-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001033331',
#   'companyCik': '0001065280',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 3940,
#   'reportingName': 'HASTINGS REED',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 197972,
#   'price': 108.8906,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000472/0001065280-25-000472-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001033331',
#   'companyCik': '0001065280',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'HASTINGS REED',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 375470,
#   'price': 10.57,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000472/0001065280-25-000472-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001033331',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 576,
#   'reportingName': 'HASTINGS REED',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 576,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000472/0001065280-25-000472-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001370931',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 581,
#   'reportingName': 'Dopfner Mathias',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 581,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000471/0001065280-25-000471-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001735710',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 580,
#   'reportingName': 'RICE SUSAN E',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 580,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000470/0001065280-25-000470-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001938411',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 582,
#   'reportingName': 'Mertz Elinor',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 582,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000469/0001065280-25-000469-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001819156',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 636,
#   'reportingName': 'Karbowski Jeffrey William',
#   'typeOfOwner': 'officer: Chief Accounting Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 636,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000468/0001065280-25-000468-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001193119',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 581,
#   'reportingName': 'SMITH BRADFORD L',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 581,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000467/0001065280-25-000467-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001244892',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 581,
#   'reportingName': 'MATHER ANN',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 581,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000466/0001065280-25-000466-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001638276',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 581,
#   'reportingName': 'Sweeney Anne M',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 581,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000465/0001065280-25-000465-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001184230',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 581,
#   'reportingName': 'BARTON RICHARD N',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 581,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000464/0001065280-25-000464-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001218352',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 581,
#   'reportingName': 'KILGORE LESLIE J',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 581,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000463/0001065280-25-000463-index.htm'},
#  {'symbol': 'NFLX',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001837857',
#   'companyCik': '0001065280',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 581,
#   'reportingName': 'Masiyiwa Strive',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 581,
#   'price': 109.13,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1065280/000106528025000462/0001065280-25-000462-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001254635',
#   'companyCik': '0001032220',
#   'transactionType': 'G-Gift',
#   'securitiesOwned': 55500,
#   'reportingName': 'MONTONI RICHARD A',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 12000,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305694/0001193125-25-305694-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001993862',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 22641.129,
#   'reportingName': 'Martinez John Thomas',
#   'typeOfOwner': 'officer: Chief Legal Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 32.937,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305692/0001193125-25-305692-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001896008',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 31684.882,
#   'reportingName': 'Mutryn David',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 36.924,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305691/0001193125-25-305691-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001629769',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 18256.603,
#   'reportingName': 'Madsen Jan',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 50.14,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305689/0001193125-25-305689-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001698399',
#   'companyCik': '0001032220',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 14387.918,
#   'reportingName': 'RAJAN GAYATHRI',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 42.301,
#   'price': 86.112,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305688/0001193125-25-305688-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001698399',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 14395.512,
#   'reportingName': 'RAJAN GAYATHRI',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 7.594,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305688/0001193125-25-305688-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001808982',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 19541.073,
#   'reportingName': 'Link Michelle F.',
#   'typeOfOwner': 'officer: Chief of Human Resources',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 20.008,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305687/0001193125-25-305687-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001215018',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 39971.489,
#   'reportingName': 'HALEY JOHN J',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 104.144,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305686/0001193125-25-305686-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001054997',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 315939.624,
#   'reportingName': 'RUDDY RAYMOND B',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 693.707,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305685/0001193125-25-305685-index.htm'},
#  {'symbol': 'RS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001777542',
#   'companyCik': '0000861884',
#   'transactionType': 'F-InKind',
#   'securitiesOwned': 14726,
#   'reportingName': 'Ajemyan Arthur',
#   'typeOfOwner': 'officer: SVP, CFO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 574,
#   'price': 279.32,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/861884/000112329225000691/0001123292-25-000691-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001741289',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 12828.548,
#   'reportingName': 'GOLINVAUX THERESA D',
#   'typeOfOwner': 'officer: Principal Accounting Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 14.335,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305683/0001193125-25-305683-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001791080',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 21576.774,
#   'reportingName': 'Baylinson Ilene R.',
#   'typeOfOwner': 'officer: General Mgr - Health & Human',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 27.639,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305680/0001193125-25-305680-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001698331',
#   'companyCik': '0001032220',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 15485.275,
#   'reportingName': 'Warren Michael J.',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 14.403,
#   'price': 86.111,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305679/0001193125-25-305679-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001698331',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 15524.345,
#   'reportingName': 'Warren Michael J.',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 39.07,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305679/0001193125-25-305679-index.htm'},
#  {'symbol': 'RS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001408793',
#   'companyCik': '0000861884',
#   'transactionType': 'F-InKind',
#   'securitiesOwned': 22685,
#   'reportingName': 'Smith William A II',
#   'typeOfOwner': 'officer: SVP, General Counsel, Corp Sec',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 574,
#   'price': 279.32,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/861884/000112329225000689/0001123292-25-000689-index.htm'},
#  {'symbol': 'MMS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001637502',
#   'companyCik': '0001032220',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 32066.067,
#   'reportingName': 'Altman Anne K.',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 10.632,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1032220/000119312525305677/0001193125-25-305677-index.htm'},
#  {'symbol': 'RS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001256541',
#   'companyCik': '0000861884',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 86455,
#   'reportingName': 'Lewis Karla R',
#   'typeOfOwner': 'director, officer: President, CEO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3775,
#   'price': 283.29,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/861884/000112329225000688/0001123292-25-000688-index.htm'},
#  {'symbol': 'RS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001256541',
#   'companyCik': '0000861884',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 84421,
#   'reportingName': 'Lewis Karla R',
#   'typeOfOwner': 'director, officer: President, CEO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2034,
#   'price': 283.88,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/861884/000112329225000688/0001123292-25-000688-index.htm'},
#  {'symbol': 'RS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001488432',
#   'companyCik': '0000861884',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 15392,
#   'reportingName': 'Koch Stephen Paul',
#   'typeOfOwner': 'officer: Exec. VP, COO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1695,
#   'price': 283.26,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/861884/000112329225000687/0001123292-25-000687-index.htm'},
#  {'symbol': 'RS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001488432',
#   'companyCik': '0000861884',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 14101,
#   'reportingName': 'Koch Stephen Paul',
#   'typeOfOwner': 'officer: Exec. VP, COO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1291,
#   'price': 283.84,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/861884/000112329225000687/0001123292-25-000687-index.htm'},
#  {'symbol': 'RS',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-12-01',
#   'reportingCik': '0001488432',
#   'companyCik': '0000861884',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 14021,
#   'reportingName': 'Koch Stephen Paul',
#   'typeOfOwner': 'officer: Exec. VP, COO',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 80,
#   'price': 285.32,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/861884/000112329225000687/0001123292-25-000687-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001582882',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 68218,
#   'reportingName': 'Volpi Kirsten M',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1718,
#   'price': 0,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000158288225000005/0001582882-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001582882',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 69218,
#   'reportingName': 'Volpi Kirsten M',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1000,
#   'price': 9.59,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000158288225000005/0001582882-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-19',
#   'reportingCik': '0001582882',
#   'companyCik': '0000831641',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 1964,
#   'reportingName': 'Volpi Kirsten M',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1964,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000158288225000005/0001582882-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-28',
#   'reportingCik': '0001582882',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 9000,
#   'reportingName': 'Volpi Kirsten M',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1000,
#   'price': 9.59,
#   'securityName': 'STOCK OPTION (RIGHT TO BUY)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000158288225000005/0001582882-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001582882',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'Volpi Kirsten M',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1718,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000158288225000005/0001582882-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001450067',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 325846,
#   'reportingName': 'SHOEMAKER LESLIE L',
#   'typeOfOwner': 'officer: EVP, Chief Sustainability',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3035,
#   'price': 0,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000145006725000005/0001450067-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001450067',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 329528,
#   'reportingName': 'SHOEMAKER LESLIE L',
#   'typeOfOwner': 'officer: EVP, Chief Sustainability',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3682,
#   'price': 0,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000145006725000005/0001450067-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001450067',
#   'companyCik': '0000831641',
#   'transactionType': 'F-InKind',
#   'securitiesOwned': 325821,
#   'reportingName': 'SHOEMAKER LESLIE L',
#   'typeOfOwner': 'officer: EVP, Chief Sustainability',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3707,
#   'price': 34.74,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000145006725000005/0001450067-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-19',
#   'reportingCik': '0001450067',
#   'companyCik': '0000831641',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 19641,
#   'reportingName': 'SHOEMAKER LESLIE L',
#   'typeOfOwner': 'officer: EVP, Chief Sustainability',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 19641,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000145006725000005/0001450067-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001450067',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 6070,
#   'reportingName': 'SHOEMAKER LESLIE L',
#   'typeOfOwner': 'officer: EVP, Chief Sustainability',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3035,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000145006725000005/0001450067-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001450067',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 11046,
#   'reportingName': 'SHOEMAKER LESLIE L',
#   'typeOfOwner': 'officer: EVP, Chief Sustainability',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 3682,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000145006725000005/0001450067-25-000005-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001902712',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 9171,
#   'reportingName': 'Obiaya Christiana',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1718,
#   'price': 0,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000190271225000006/0001902712-25-000006-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-19',
#   'reportingCik': '0001902712',
#   'companyCik': '0000831641',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 1964,
#   'reportingName': 'Obiaya Christiana',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1964,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000190271225000006/0001902712-25-000006-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001902712',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'Obiaya Christiana',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1718,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000190271225000006/0001902712-25-000006-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001728969',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 5460,
#   'reportingName': 'Hopson Preston',
#   'typeOfOwner': 'officer: EVP, Chief Legal/Human Capital',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2735,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000172896925000006/0001728969-25-000006-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001728969',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 7363,
#   'reportingName': 'Hopson Preston',
#   'typeOfOwner': 'officer: EVP, Chief Legal/Human Capital',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2455,
#   'price': 0,
#   'securityName': 'RESTRICTED STOCK UNITS (RIGHT TO RECEIVE)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000172896925000006/0001728969-25-000006-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001728969',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 82731,
#   'reportingName': 'Hopson Preston',
#   'typeOfOwner': 'officer: EVP, Chief Legal/Human Capital',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2735,
#   'price': 0,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000172896925000006/0001728969-25-000006-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001728969',
#   'companyCik': '0000831641',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 85186,
#   'reportingName': 'Hopson Preston',
#   'typeOfOwner': 'officer: EVP, Chief Legal/Human Capital',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2455,
#   'price': 0,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000172896925000006/0001728969-25-000006-index.htm'},
#  {'symbol': 'TTEK',
#   'filingDate': '2025-12-02',
#   'transactionDate': '2025-11-30',
#   'reportingCik': '0001728969',
#   'companyCik': '0000831641',
#   'transactionType': 'F-InKind',
#   'securitiesOwned': 83142,
#   'reportingName': 'Hopson Preston',
#   'typeOfOwner': 'officer: EVP, Chief Legal/Human Capital',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2044,
#   'price': 34.74,
#   'securityName': 'COMMON STOCK',
#   'url': 'https://www.sec.gov/Archives/edgar/data/831641/000172896925000006/0001728969-25-000006-index.htm'}]

# %%
@mcp.tool()
async def insider_trading_search(
    symbol: str,
    page: int = 0,
    limit: int = 100,
    reporting_cik: Optional[str] = None,
    company_cik: Optional[str] = None,
    transaction_type: Optional[str] = None,
) -> Any:
    """Search Insider Trades API — filter insider activity by symbol or CIKs.

    Use this when:
      • You want insider trades for a specific company/symbol (e.g., AAPL).
      • You need to filter by reporting CIK, company CIK, or transaction type.
      • You’re drilling into detailed insider activity for one name instead of the whole market.

    Don’t use when:
      • You just want the latest market-wide insider trades (use `insider_trading_latest` instead).
      • You need ownership summaries or institutional holders (different endpoints).

    Endpoint: `/stable/insider-trading/search`

    What it provides:
      • **Symbol & Company**: `symbol`, `companyCik`, `securityName`.
      • **Transaction Details**: `filingDate`, `transactionDate`, `transactionType`
        (e.g., `P-Purchase`, `S-Sale`), `securitiesTransacted`, `securitiesOwned`, `price`.
      • **Insider Identity**: `reportingName`, `reportingCik`, `typeOfOwner`
        (e.g., director, officer), `directOrIndirect`, `acquisitionOrDisposition`.
      • **Regulatory Links**: Direct `url` to the SEC filing.

    Args:
      symbol:
        Ticker symbol to search for (e.g., `"AAPL"`). Required by the API.
      page:
        Zero-based page index (max page ~100). Use this to paginate through large result sets.
      limit:
        Number of records per page (max 1000). Higher values reduce the number of requests.
      reporting_cik:
        Optional CIK of the insider (e.g., `"0001496686"`) to filter trades by a specific insider.
      company_cik:
        Optional CIK of the company (e.g., `"0000320193"`) to filter trades for a specific issuer.
      transaction_type:
        Optional transaction type filter (e.g., `"P-Purchase"`, `"S-Sale"`).

    Returns:
      A list of insider trades matching the provided filters.
    """
    params: Dict[str, Any] = {
        "symbol": symbol,
        "page": page,
        "limit": limit,
    }

    if reporting_cik:
        params["reportingCik"] = reporting_cik
    if company_cik:
        params["companyCik"] = company_cik
    if transaction_type:
        params["transactionType"] = transaction_type

    return await fmp_api_request("insider-trading/search", params)

# %%
await insider_trading_search("TSLA")
# Out:
# [{'symbol': 'TSLA',
#   'filingDate': '2025-11-12',
#   'transactionDate': '2025-11-10',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'G-Gift',
#   'securitiesOwned': 1448435,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 14785,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925110597/0001104659-25-110597-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-11-10',
#   'transactionDate': '2025-11-06',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 519743904,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 423743904,
#   'price': 334.09,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925109263/0001104659-25-109263-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-17',
#   'transactionDate': '2025-09-15',
#   'reportingCik': '0001420590',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 637031,
#   'reportingName': 'MURDOCH JAMES R',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 60000,
#   'price': 422.68,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925090923/0001104659-25-090923-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 413362808,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 17536,
#   'price': 396.359,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 413345272,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 116948,
#   'price': 395.526,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 413228324,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 290501,
#   'price': 394.764,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 412937823,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 332908,
#   'price': 393.704,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 412604915,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 227384,
#   'price': 392.779,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 412377531,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 242112,
#   'price': 391.761,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 412135419,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 104079,
#   'price': 390.598,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 412031340,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 291221,
#   'price': 389.714,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411740119,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 206832,
#   'price': 388.749,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411533287,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 116841,
#   'price': 387.656,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411416446,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 133198,
#   'price': 386.612,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411283248,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 73712,
#   'price': 385.765,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411209536,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 27110,
#   'price': 384.586,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411182426,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 28271,
#   'price': 383.686,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411154155,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 18137,
#   'price': 382.489,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411136018,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 29410,
#   'price': 381.529,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411106608,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 18293,
#   'price': 380.43,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411088315,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 50334,
#   'price': 379.2,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 411037981,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 54526,
#   'price': 378.433,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 410983455,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 47384,
#   'price': 377.063,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 410936071,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 31019,
#   'price': 376.145,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 410905052,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 8000,
#   'price': 374.57,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 410897052,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 45909,
#   'price': 373.989,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 410851143,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 34530,
#   'price': 372.821,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-15',
#   'transactionDate': '2025-09-12',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'P-Purchase',
#   'securitiesOwned': 410816613,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 22537,
#   'price': 371.9,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925089693/0001104659-25-089693-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-12',
#   'transactionDate': '2025-09-11',
#   'reportingCik': '0001972928',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 47599.75,
#   'reportingName': 'Zhu Xiaotong',
#   'typeOfOwner': 'officer: SVP, APAC and',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 20000,
#   'price': 363.755,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000197292825000004/0001972928-25-000004-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-09',
#   'transactionDate': '2025-09-05',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 78458,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 6538,
#   'price': 0,
#   'securityName': 'Restricted Stock Unit',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925088703/0001104659-25-088703-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-09',
#   'transactionDate': '2025-09-05',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 12461.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 6538,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925088703/0001104659-25-088703-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-09-09',
#   'transactionDate': '2025-09-08',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 9856,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2605.5,
#   'price': 352.384,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925088703/0001104659-25-088703-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-08-28',
#   'transactionDate': '2025-08-26',
#   'reportingCik': '0001420590',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 697031,
#   'reportingName': 'MURDOCH JAMES R',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'I',
#   'formType': '4',
#   'securitiesTransacted': 120000,
#   'price': 350.286,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925084935/0001104659-25-084935-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-08-04',
#   'transactionDate': '2025-08-03',
#   'reportingCik': '0001494730',
#   'companyCik': '0001318605',
#   'transactionType': 'A-Award',
#   'securitiesOwned': 96000000,
#   'reportingName': 'Musk Elon',
#   'typeOfOwner': 'director, 10 percent owner, officer: CEO',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 96000000,
#   'price': 23.34,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925073753/0001104659-25-073753-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-15',
#   'transactionDate': '2025-07-11',
#   'reportingCik': '0001420590',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 90000,
#   'reportingName': 'MURDOCH JAMES R',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 90000,
#   'price': 17.47,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925068165/0001104659-25-068165-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-15',
#   'transactionDate': '2025-07-11',
#   'reportingCik': '0001420590',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'MURDOCH JAMES R',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 90000,
#   'price': 17.47,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925068165/0001104659-25-068165-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 715920,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 4000,
#   'price': 18.22,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-08',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 713920,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2000,
#   'price': 18.22,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 9923.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 4000,
#   'price': 18.22,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 9730.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 193,
#   'price': 289.948,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 9330.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 400,
#   'price': 291.178,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 8230.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1100,
#   'price': 291.999,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-08',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 7923.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2000,
#   'price': 18.22,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 7030.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1200,
#   'price': 293.255,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 6123.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 907,
#   'price': 294.348,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-08',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 5923.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2000,
#   'price': 300,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-07-09',
#   'transactionDate': '2025-07-07',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 5923.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 200,
#   'price': 295.175,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925066775/0001104659-25-066775-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-16',
#   'transactionDate': '2025-06-12',
#   'reportingCik': '0001972928',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 280650,
#   'reportingName': 'Zhu Xiaotong',
#   'typeOfOwner': 'officer: SVP, APAC',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 15000,
#   'price': 20.57,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000197292825000003/0001972928-25-000003-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-16',
#   'transactionDate': '2025-06-12',
#   'reportingCik': '0001972928',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 82599.75,
#   'reportingName': 'Zhu Xiaotong',
#   'typeOfOwner': 'officer: SVP, APAC',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 15000,
#   'price': 20.57,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000197292825000003/0001972928-25-000003-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-16',
#   'transactionDate': '2025-06-12',
#   'reportingCik': '0001972928',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 67599.75,
#   'reportingName': 'Zhu Xiaotong',
#   'typeOfOwner': 'officer: SVP, APAC',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 15000,
#   'price': 323.807,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000197292825000003/0001972928-25-000003-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-09',
#   'transactionDate': '2025-06-05',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 84996,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 6538,
#   'price': 0,
#   'securityName': 'Restricted Stock Unit',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925057932/0001104659-25-057932-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-09',
#   'transactionDate': '2025-06-05',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 8487.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 6538,
#   'price': 0,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925057932/0001104659-25-057932-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-09',
#   'transactionDate': '2025-06-09',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 5923.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2564,
#   'price': 285.715,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925057932/0001104659-25-057932-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 720920,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 6000,
#   'price': 18.22,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-03',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 719920,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1000,
#   'price': 18.22,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 7949.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 6000,
#   'price': 18.22,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 7849.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 100,
#   'price': 333.77,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 7449.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 400,
#   'price': 336.25,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 6249.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1200,
#   'price': 337.739,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 5649.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 600,
#   'price': 338.662,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 5149.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 500,
#   'price': 340.15,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 4749.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 400,
#   'price': 341.343,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 4449.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 300,
#   'price': 342.25,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-03',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 2949.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1000,
#   'price': 18.22,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 2349.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2100,
#   'price': 343.84,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 2049.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 300,
#   'price': 345.527,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-03',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1949.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1000,
#   'price': 350,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-02',
#   'reportingCik': '0001771340',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1949.5,
#   'reportingName': 'Taneja Vaibhav',
#   'typeOfOwner': 'officer: Chief Financial Officer',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 100,
#   'price': 347.22,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925056561/0001104659-25-056561-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-06-04',
#   'transactionDate': '2025-06-04',
#   'reportingCik': '0001350874',
#   'companyCik': '0001318605',
#   'transactionType': '',
#   'securitiesOwned': 0,
#   'reportingName': 'Hartung Jack',
#   'typeOfOwner': 'director: ',
#   'acquisitionOrDisposition': '',
#   'directOrIndirect': None,
#   'formType': '3',
#   'securitiesTransacted': 0,
#   'price': 0,
#   'securityName': '',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000177134025000012/0001771340-25-000012-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 1332966,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 401961,
#   'price': 24.73,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1328766,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 4200,
#   'price': 347.61,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1328366,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 400,
#   'price': 348.863,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1320366,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 8000,
#   'price': 350.556,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1303266,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 17100,
#   'price': 351.357,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1268724,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 34542,
#   'price': 352.278,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1248847,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 19877,
#   'price': 353.296,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1236291,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 12556,
#   'price': 354.264,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1177406,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 58885,
#   'price': 355.423,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1093016,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 84390,
#   'price': 356.32,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1058202,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 34814,
#   'price': 357.147,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1024003,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 34199,
#   'price': 358.566,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 970409,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 53594,
#   'price': 359.38,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 945313,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 25096,
#   'price': 360.517,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 931005,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 360000,
#   'price': 22.86,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 918503,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 26810,
#   'price': 361.427,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 877220,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 41283,
#   'price': 362.473,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 855394,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 21826,
#   'price': 363.236,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 360000,
#   'price': 22.86,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001412598',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 0,
#   'reportingName': 'Ehrenpreis Ira Matthew',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 401961,
#   'price': 24.73,
#   'securityName': 'Non-Qualified Stock Option (right to buy)',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054372/0001104659-25-054372-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'M-Exempt',
#   'securitiesOwned': 1554808,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'A',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 91588,
#   'price': 24.73,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1553708,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1100,
#   'price': 347.879,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1552508,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1200,
#   'price': 350.259,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1549608,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 2900,
#   'price': 351.133,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1542908,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 6700,
#   'price': 352.134,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1538908,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 4000,
#   'price': 353.104,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1537308,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 1600,
#   'price': 354.109,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1528410,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 8898,
#   'price': 355.31,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1512008,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 16402,
#   'price': 356.153,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1505008,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 7000,
#   'price': 357.032,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'},
#  {'symbol': 'TSLA',
#   'filingDate': '2025-05-29',
#   'transactionDate': '2025-05-27',
#   'reportingCik': '0001494731',
#   'companyCik': '0001318605',
#   'transactionType': 'S-Sale',
#   'securitiesOwned': 1499627,
#   'reportingName': 'Musk Kimbal',
#   'typeOfOwner': 'director',
#   'acquisitionOrDisposition': 'D',
#   'directOrIndirect': 'D',
#   'formType': '4',
#   'securitiesTransacted': 5381,
#   'price': 358.292,
#   'securityName': 'Common Stock',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1318605/000110465925054371/0001104659-25-054371-index.htm'}]

# %%
@mcp.tool()
async def when_should_i_use_fmp() -> dict:
    """Guidance tool — returns when this server is appropriate vs. other data sources."""
    return {
        "use_when": [
            "You need fundamentals/ratios/statements for a ticker",
            "You need OHLCV daily prices",
            "You need earnings transcripts text",
            "You need macro indicators or economic calendar",
            "You need latest stock news or insider trades"
        ],
        "avoid_when": [
            "Trading/execution actions",
            "Full SEC filings beyond transcripts",
            "Realtime tick/quote level market data"
        ],
        "quick_map": {
            "snapshot": "company_profile",
            "pnl": "income_statement",
            "balance": "balance_sheet",
            "cash": "cash_flow",
            "ratios": "financial_ratios",
            "prices": "historical_price_eod_full",
            "transcript": "earnings_call_transcript",
            "macro": "economic_indicators",
            "calendar": "economic_calendar",
            "news": "stock_news_latest / stock_news_search",
            "insiders": "insider_trading_latest"
        }
    }

# %%
# # Don't test this in notebbook
# # ======================== STREAMABLE HTTP ========================

# def main() -> None:
#     """Run the MCP server via stdio (default), SSE, or streamable HTTP.

#     - `--transport stdio` : blocking stdio transport.
#     - `--transport sse`   : FastMCP SSE transport (streaming HTTP); path is client-specific.
#     - `--transport streamable-http` : Starlette/Uvicorn app from FastMCP.
#     """
#     import argparse
#     import uvicorn
#     from starlette.responses import JSONResponse

#     parser = argparse.ArgumentParser(description="FMP MCP server")
#     parser.add_argument("--transport", choices=["stdio", "sse", "streamable-http"], default="stdio")
#     parser.add_argument("--host", default="127.0.0.1")
#     parser.add_argument("--port", type=int, default=8000)
#     parser.add_argument("--stateless", action="store_true")
#     parser.add_argument("--json-response", action="store_true")
#     parser.add_argument("--path", default="/mcp/")
#     args = parser.parse_args()

#     if args.transport == "streamable-http":
#         print(f"Starting FMP MCP Server (Streamable HTTP {'stateless' if args.stateless else 'stateful'}{' JSON' if args.json_response else ' SSE'} mode) on http://{args.host}:{args.port}")
#         print(f"API Key configured: {'Yes' if os.environ.get('FMP_API_KEY') else 'No - using demo mode'}")
#         print(f"Streamable HTTP endpoint (path hint): http://{args.host}:{args.port}{args.path}")
#         print("Note: Some clients require a trailing slash in the endpoint URL.")

#         # build a fresh FastMCP configured for HTTP
#         streamable_mcp = FastMCP(
#             "fmp",
#             dependencies=["httpx"],
#             stateless_http=args.stateless,
#             json_response=args.json_response,
#         )

#         # register the tools on the HTTP instance
#         streamable_mcp.tool()(company_profile)
#         streamable_mcp.tool()(income_statement)
#         streamable_mcp.tool()(balance_sheet)
#         streamable_mcp.tool()(cash_flow)
#         streamable_mcp.tool()(financial_ratios)
#         streamable_mcp.tool()(historical_price_eod_full)
#         streamable_mcp.tool()(earnings_call_transcript)
#         streamable_mcp.tool()(economic_indicators)
#         streamable_mcp.tool()(economic_calendar)
#         streamable_mcp.tool()(stock_news_latest)
#         streamable_mcp.tool()(stock_news_search)
#         streamable_mcp.tool()(insider_trading_latest)
#         streamable_mcp.tool()(when_should_i_use_fmp)

#         # ASGI app & health route
#         app = streamable_mcp.streamable_http_app()
#         from starlette.routing import Route

#         async def health_check(request):
#             return JSONResponse({"status": "healthy", "service": "fmp-mcp-server"})

#         app.router.routes.insert(0, Route("/health", health_check, methods=["GET"]))
#         uvicorn.run(app, host=args.host, port=args.port)
#         return

#     if args.transport == "sse":
#         print("[fmp-mcp] Transport: sse (streamable HTTP)")
#         print("[fmp-mcp] Try connecting to one of these paths: /mcp/  /sse/  /events/")
#         mcp.run(transport="sse")
#         return

#     print("[fmp-mcp] Transport: stdio")
#     mcp.run(transport="stdio")


# if __name__ == "__main__":
#     main()
